# %%
# %load_ext autoreload
# %autoreload 1
# %aimport bmc.utils.tex_variation
from bmc.utils.tex_variation import run_variation_parallel
import numpy as np
import torch

adc_time = 5e-3
webhook = False

low = -1e-3
high = 1e-3
n_iso = 100
z_pos = np.linspace(low, high, n_iso)
z_pos = torch.tensor(z_pos)
z_pos = torch.cat((z_pos, torch.tensor([0.0])))  # Füge 0 hinzu
z_pos = torch.sort(z_pos).values

config_path = 'sim_lib/config_1pool.yaml'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### No Phase Advance (1ETM, alpha=30°)

# %%
seq_on = 'seq_lib/30no_phasead.seq'
seq_off = 'seq_lib/30no_phasead_minus.seq'

print(f'n_iso: {len(z_pos)}')
_, singal, plot_data = run_variation_parallel(seq_on, seq_off, config_path, adc_time, z_pos, webhook, show_plot=False, save_plot=False, store_all=True)
# Out:
# n_iso: 101
# BMCTool simulation: 100%|██████████| 169/169 [00:28<00:00,  5.88it/s]
# === Debug: get_exact() ===
# Total time samples: 26061
# Time sampling sizes: tensor([ 20., 200., 200., 200.,  20., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200.])
# Events: ['delay at 0.0000s', 'rf at 0.0010s', 'gz at 0.0030s', 'rf at 0.0035s', 'delay at 0.0055s', 'rf at 0.0855s', 'gz at 0.0875s', 'delay at 0.0880s', 'gz at 0.1380s', 'rf at 0.1385s', 'gz at 0.1405s', 'delay at 0.1410s', 'gz at 0.1910s', 'rf at 0.1915s', 'gz at 0.1935s', 'delay at 0.1940s', 'gz at 0.2440s', 'rf at 0.2445s', 'gz at 0.2465s', 'delay at 0.2470s', 'gz at 0.2970s', 'rf at 0.2975s', 'gz at 0.2995s', 'delay at 0.3000s', 'gz at 0.3500s', 'rf at 0.3505s', 'gz at 0.3525s', 'delay at 0.3530s', 'gz at 0.4030s', 'rf at 0.4035s', 'gz at 0.4055s', 'delay at 0.4060s', 'gz at 0.4560s', 'rf at 0.4565s', 'gz at 0.4585s', 'delay at 0.4590s', 'gz at 0.5090s', 'rf at 0.5095s', 'gz at 0.5115s', 'delay at 0.5120s', 'gz at 0.5620s', 'rf at 0.5625s', 'gz at 0.5645s', 'delay at 0.5650s', 'gz at 0.6150s', 'rf at 0.6155s', 'gz at 0.6175s', 'delay at 0.6180s', 'gz at 0.6680s', 'rf at 0.6685s', 'gz at 0.6705s', 'delay at 0.6710s', 'gz at 0.7210s', 'rf at 0.7215s', 'gz at 0.7235s', 'delay at 0.7240s', 'gz at 0.7740s', 'rf at 0.7745s', 'gz at 0.7765s', 'delay at 0.7770s', 'gz at 0.8270s', 'rf at 0.8275s', 'gz at 0.8295s', 'delay at 0.8300s', 'gz at 0.8800s', 'rf at 0.8805s', 'gz at 0.8825s', 'delay at 0.8830s', 'gz at 0.9330s', 'rf at 0.9335s', 'gz at 0.9355s', 'delay at 0.9360s', 'gz at 0.9860s', 'rf at 0.9865s', 'gz at 0.9885s', 'delay at 0.9890s', 'gz at 1.0390s', 'rf at 1.0395s', 'gz at 1.0415s', 'delay at 1.0420s', 'gz at 1.0920s', 'rf at 1.0925s', 'gz at 1.0945s', 'delay at 1.0950s', 'gz at 1.1450s', 'rf at 1.1455s', 'gz at 1.1475s', 'delay at 1.1480s', 'gz at 1.1980s', 'rf at 1.1985s', 'gz at 1.2005s', 'delay at 1.2010s', 'gz at 1.2510s', 'rf at 1.2515s', 'gz at 1.2535s', 'delay at 1.2540s', 'gz at 1.3040s', 'rf at 1.3045s', 'gz at 1.3065s', 'delay at 1.3070s', 'gz at 1.3570s', 'rf at 1.3575s', 'gz at 1.3595s', 'delay at 1.3600s', 'gz at 1.4100s', 'rf at 1.4105s', 'gz at 1.4125s', 'delay at 1.4130s', 'gz at 1.4630s', 'rf at 1.4635s', 'gz at 1.4655s', 'delay at 1.4660s', 'gz at 1.5160s', 'rf at 1.5165s', 'gz at 1.5185s', 'delay at 1.5190s', 'gz at 1.5690s', 'rf at 1.5695s', 'gz at 1.5715s', 'delay at 1.5720s', 'gz at 1.6220s', 'rf at 1.6225s', 'gz at 1.6245s', 'delay at 1.6250s', 'gz at 1.6750s', 'rf at 1.6755s', 'gz at 1.6775s', 'delay at 1.6780s', 'gz at 1.7280s', 'rf at 1.7285s', 'gz at 1.7305s', 'delay at 1.7310s', 'gz at 1.7810s', 'rf at 1.7815s', 'gz at 1.7835s', 'delay at 1.7840s', 'gz at 1.8340s', 'rf at 1.8345s', 'gz at 1.8365s', 'delay at 1.8370s', 'gz at 1.8870s', 'rf at 1.8875s', 'gz at 1.8895s', 'delay at 1.8900s', 'gz at 1.9400s', 'rf at 1.9405s', 'gz at 1.9425s', 'delay at 1.9430s', 'gz at 1.9930s', 'rf at 1.9935s', 'gz at 1.9955s', 'delay at 1.9960s', 'gz at 2.0460s', 'rf at 2.0465s', 'gz at 2.0485s', 'delay at 2.0490s', 'gz at 2.0990s', 'rf at 2.0995s', 'gz at 2.1015s', 'delay at 2.1020s', 'gz at 2.1520s', 'rf at 2.1525s', 'gz at 2.1545s', 'delay at 2.1550s', 'gz at 2.2050s', 'rf at 2.2055s', 'gz at 2.2075s', 'delay at 2.2080s', 'adc at 2.2580s']
#
# Slice 0:
#   Event: delay at 0.0000s
#   Size: 20.0
#   Time range: 0.0000s - 0.0009s
#   Sample count: 20
#
# Slice 1:
#   Event: rf at 0.0010s
#   Size: 200.0
#   Time range: 0.0010s - 0.0030s
#   Sample count: 200
#
# Slice 2:
#   Event: gz at 0.0030s
#   Size: 200.0
#   Time range: 0.0030s - 0.0035s
#   Sample count: 200
#
# Slice 3:
#   Event: rf at 0.0035s
#   Size: 200.0
#   Time range: 0.0035s - 0.0055s
#   Sample count: 200
#
# Slice 4:
#   Event: delay at 0.0055s
#   Size: 20.0
#   Time range: 0.0055s - 0.0815s
#   Sample count: 20
#
# Slice 5:
#   Event: rf at 0.0855s
#   Size: 200.0
#   Time range: 0.0855s - 0.0875s
#   Sample count: 200
#
# Slice 6:
#   Event: gz at 0.0875s
#   Size: 200.0
#   Time range: 0.0875s - 0.0880s
#   Sample count: 200
#
# Slice 7:
#   Event: delay at 0.0880s
#   Size: 20.0
#   Time range: 0.0880s - 0.1355s
#   Sample count: 20
#
# Slice 8:
#   Event: gz at 0.1380s
#   Size: 200.0
#   Time range: 0.1380s - 0.1385s
#   Sample count: 200
#
# Slice 9:
#   Event: rf at 0.1385s
#   Size: 200.0
#   Time range: 0.1385s - 0.1405s
#   Sample count: 200
#
# Slice 10:
#   Event: gz at 0.1405s
#   Size: 200.0
#   Time range: 0.1405s - 0.1410s
#   Sample count: 200
#
# Slice 11:
#   Event: delay at 0.1410s
#   Size: 20.0
#   Time range: 0.1410s - 0.1885s
#   Sample count: 20
#
# Slice 12:
#   Event: gz at 0.1910s
#   Size: 200.0
#   Time range: 0.1910s - 0.1915s
#   Sample count: 200
#
# Slice 13:
#   Event: rf at 0.1915s
#   Size: 200.0
#   Time range: 0.1915s - 0.1935s
#   Sample count: 200
#
# Slice 14:
#   Event: gz at 0.1935s
#   Size: 200.0
#   Time range: 0.1935s - 0.1940s
#   Sample count: 200
#
# Slice 15:
#   Event: delay at 0.1940s
#   Size: 20.0
#   Time range: 0.1940s - 0.2415s
#   Sample count: 20
#
# Slice 16:
#   Event: gz at 0.2440s
#   Size: 200.0
#   Time range: 0.2440s - 0.2445s
#   Sample count: 200
#
# Slice 17:
#   Event: rf at 0.2445s
#   Size: 200.0
#   Time range: 0.2445s - 0.2465s
#   Sample count: 200
#
# Slice 18:
#   Event: gz at 0.2465s
#   Size: 200.0
#   Time range: 0.2465s - 0.2470s
#   Sample count: 200
#
# Slice 19:
#   Event: delay at 0.2470s
#   Size: 20.0
#   Time range: 0.2470s - 0.2945s
#   Sample count: 20
#
# Slice 20:
#   Event: gz at 0.2970s
#   Size: 200.0
#   Time range: 0.2970s - 0.2975s
#   Sample count: 200
#
# Slice 21:
#   Event: rf at 0.2975s
#   Size: 200.0
#   Time range: 0.2975s - 0.2995s
#   Sample count: 200
#
# Slice 22:
#   Event: gz at 0.2995s
#   Size: 200.0
#   Time range: 0.2995s - 0.3000s
#   Sample count: 200
#
# Slice 23:
#   Event: delay at 0.3000s
#   Size: 20.0
#   Time range: 0.3000s - 0.3475s
#   Sample count: 20
#
# Slice 24:
#   Event: gz at 0.3500s
#   Size: 200.0
#   Time range: 0.3500s - 0.3505s
#   Sample count: 200
#
# Slice 25:
#   Event: rf at 0.3505s
#   Size: 200.0
#   Time range: 0.3505s - 0.3525s
#   Sample count: 200
#
# Slice 26:
#   Event: gz at 0.3525s
#   Size: 200.0
#   Time range: 0.3525s - 0.3530s
#   Sample count: 200
#
# Slice 27:
#   Event: delay at 0.3530s
#   Size: 20.0
#   Time range: 0.3530s - 0.4005s
#   Sample count: 20
#
# Slice 28:
#   Event: gz at 0.4030s
#   Size: 200.0
#   Time range: 0.4030s - 0.4035s
#   Sample count: 200
#
# Slice 29:
#   Event: rf at 0.4035s
#   Size: 200.0
#   Time range: 0.4035s - 0.4055s
#   Sample count: 200
#
# Slice 30:
#   Event: gz at 0.4055s
#   Size: 200.0
#   Time range: 0.4055s - 0.4060s
#   Sample count: 200
#
# Slice 31:
#   Event: delay at 0.4060s
#   Size: 20.0
#   Time range: 0.4060s - 0.4535s
#   Sample count: 20
#
# Slice 32:
#   Event: gz at 0.4560s
#   Size: 200.0
#   Time range: 0.4560s - 0.4565s
#   Sample count: 200
#
# Slice 33:
#   Event: rf at 0.4565s
#   Size: 200.0
#   Time range: 0.4565s - 0.4585s
#   Sample count: 200
#
# Slice 34:
#   Event: gz at 0.4585s
#   Size: 200.0
#   Time range: 0.4585s - 0.4590s
#   Sample count: 200
#
# Slice 35:
#   Event: delay at 0.4590s
#   Size: 20.0
#   Time range: 0.4590s - 0.5065s
#   Sample count: 20
#
# Slice 36:
#   Event: gz at 0.5090s
#   Size: 200.0
#   Time range: 0.5090s - 0.5095s
#   Sample count: 200
#
# Slice 37:
#   Event: rf at 0.5095s
#   Size: 200.0
#   Time range: 0.5095s - 0.5115s
#   Sample count: 200
#
# Slice 38:
#   Event: gz at 0.5115s
#   Size: 200.0
#   Time range: 0.5115s - 0.5120s
#   Sample count: 200
#
# Slice 39:
#   Event: delay at 0.5120s
#   Size: 20.0
#   Time range: 0.5120s - 0.5595s
#   Sample count: 20
#
# Slice 40:
#   Event: gz at 0.5620s
#   Size: 200.0
#   Time range: 0.5620s - 0.5625s
#   Sample count: 200
#
# Slice 41:
#   Event: rf at 0.5625s
#   Size: 200.0
#   Time range: 0.5625s - 0.5645s
#   Sample count: 200
#
# Slice 42:
#   Event: gz at 0.5645s
#   Size: 200.0
#   Time range: 0.5645s - 0.5650s
#   Sample count: 200
#
# Slice 43:
#   Event: delay at 0.5650s
#   Size: 20.0
#   Time range: 0.5650s - 0.6125s
#   Sample count: 20
#
# Slice 44:
#   Event: gz at 0.6150s
#   Size: 200.0
#   Time range: 0.6150s - 0.6155s
#   Sample count: 200
#
# Slice 45:
#   Event: rf at 0.6155s
#   Size: 200.0
#   Time range: 0.6155s - 0.6175s
#   Sample count: 200
#
# Slice 46:
#   Event: gz at 0.6175s
#   Size: 200.0
#   Time range: 0.6175s - 0.6180s
#   Sample count: 200
#
# Slice 47:
#   Event: delay at 0.6180s
#   Size: 20.0
#   Time range: 0.6180s - 0.6655s
#   Sample count: 20
#
# Slice 48:
#   Event: gz at 0.6680s
#   Size: 200.0
#   Time range: 0.6680s - 0.6685s
#   Sample count: 200
#
# Slice 49:
#   Event: rf at 0.6685s
#   Size: 200.0
#   Time range: 0.6685s - 0.6705s
#   Sample count: 200
#
# Slice 50:
#   Event: gz at 0.6705s
#   Size: 200.0
#   Time range: 0.6705s - 0.6710s
#   Sample count: 200
#
# Slice 51:
#   Event: delay at 0.6710s
#   Size: 20.0
#   Time range: 0.6710s - 0.7185s
#   Sample count: 20
#
# Slice 52:
#   Event: gz at 0.7210s
#   Size: 200.0
#   Time range: 0.7210s - 0.7215s
#   Sample count: 200
#
# Slice 53:
#   Event: rf at 0.7215s
#   Size: 200.0
#   Time range: 0.7215s - 0.7235s
#   Sample count: 200
#
# Slice 54:
#   Event: gz at 0.7235s
#   Size: 200.0
#   Time range: 0.7235s - 0.7240s
#   Sample count: 200
#
# Slice 55:
#   Event: delay at 0.7240s
#   Size: 20.0
#   Time range: 0.7240s - 0.7715s
#   Sample count: 20
#
# Slice 56:
#   Event: gz at 0.7740s
#   Size: 200.0
#   Time range: 0.7740s - 0.7745s
#   Sample count: 200
#
# Slice 57:
#   Event: rf at 0.7745s
#   Size: 200.0
#   Time range: 0.7745s - 0.7765s
#   Sample count: 200
#
# Slice 58:
#   Event: gz at 0.7765s
#   Size: 200.0
#   Time range: 0.7765s - 0.7770s
#   Sample count: 200
#
# Slice 59:
#   Event: delay at 0.7770s
#   Size: 20.0
#   Time range: 0.7770s - 0.8245s
#   Sample count: 20
#
# Slice 60:
#   Event: gz at 0.8270s
#   Size: 200.0
#   Time range: 0.8270s - 0.8275s
#   Sample count: 200
#
# Slice 61:
#   Event: rf at 0.8275s
#   Size: 200.0
#   Time range: 0.8275s - 0.8295s
#   Sample count: 200
#
# Slice 62:
#   Event: gz at 0.8295s
#   Size: 200.0
#   Time range: 0.8295s - 0.8300s
#   Sample count: 200
#
# Slice 63:
#   Event: delay at 0.8300s
#   Size: 20.0
#   Time range: 0.8300s - 0.8775s
#   Sample count: 20
#
# Slice 64:
#   Event: gz at 0.8800s
#   Size: 200.0
#   Time range: 0.8800s - 0.8805s
#   Sample count: 200
#
# Slice 65:
#   Event: rf at 0.8805s
#   Size: 200.0
#   Time range: 0.8805s - 0.8825s
#   Sample count: 200
#
# Slice 66:
#   Event: gz at 0.8825s
#   Size: 200.0
#   Time range: 0.8825s - 0.8830s
#   Sample count: 200
#
# Slice 67:
#   Event: delay at 0.8830s
#   Size: 20.0
#   Time range: 0.8830s - 0.9305s
#   Sample count: 20
#
# Slice 68:
#   Event: gz at 0.9330s
#   Size: 200.0
#   Time range: 0.9330s - 0.9335s
#   Sample count: 200
#
# Slice 69:
#   Event: rf at 0.9335s
#   Size: 200.0
#   Time range: 0.9335s - 0.9355s
#   Sample count: 200
#
# Slice 70:
#   Event: gz at 0.9355s
#   Size: 200.0
#   Time range: 0.9355s - 0.9360s
#   Sample count: 200
#
# Slice 71:
#   Event: delay at 0.9360s
#   Size: 20.0
#   Time range: 0.9360s - 0.9835s
#   Sample count: 20
#
# Slice 72:
#   Event: gz at 0.9860s
#   Size: 200.0
#   Time range: 0.9860s - 0.9865s
#   Sample count: 200
#
# Slice 73:
#   Event: rf at 0.9865s
#   Size: 200.0
#   Time range: 0.9865s - 0.9885s
#   Sample count: 200
#
# Slice 74:
#   Event: gz at 0.9885s
#   Size: 200.0
#   Time range: 0.9885s - 0.9890s
#   Sample count: 200
#
# Slice 75:
#   Event: delay at 0.9890s
#   Size: 20.0
#   Time range: 0.9890s - 1.0365s
#   Sample count: 20
#
# Slice 76:
#   Event: gz at 1.0390s
#   Size: 200.0
#   Time range: 1.0390s - 1.0395s
#   Sample count: 200
#
# Slice 77:
#   Event: rf at 1.0395s
#   Size: 200.0
#   Time range: 1.0395s - 1.0415s
#   Sample count: 200
#
# Slice 78:
#   Event: gz at 1.0415s
#   Size: 200.0
#   Time range: 1.0415s - 1.0420s
#   Sample count: 200
#
# Slice 79:
#   Event: delay at 1.0420s
#   Size: 20.0
#   Time range: 1.0420s - 1.0895s
#   Sample count: 20
#
# Slice 80:
#   Event: gz at 1.0920s
#   Size: 200.0
#   Time range: 1.0920s - 1.0925s
#   Sample count: 200
#
# Slice 81:
#   Event: rf at 1.0925s
#   Size: 200.0
#   Time range: 1.0925s - 1.0945s
#   Sample count: 200
#
# Slice 82:
#   Event: gz at 1.0945s
#   Size: 200.0
#   Time range: 1.0945s - 1.0950s
#   Sample count: 200
#
# Slice 83:
#   Event: delay at 1.0950s
#   Size: 20.0
#   Time range: 1.0950s - 1.1425s
#   Sample count: 20
#
# Slice 84:
#   Event: gz at 1.1450s
#   Size: 200.0
#   Time range: 1.1450s - 1.1455s
#   Sample count: 200
#
# Slice 85:
#   Event: rf at 1.1455s
#   Size: 200.0
#   Time range: 1.1455s - 1.1475s
#   Sample count: 200
#
# Slice 86:
#   Event: gz at 1.1475s
#   Size: 200.0
#   Time range: 1.1475s - 1.1480s
#   Sample count: 200
#
# Slice 87:
#   Event: delay at 1.1480s
#   Size: 20.0
#   Time range: 1.1480s - 1.1955s
#   Sample count: 20
#
# Slice 88:
#   Event: gz at 1.1980s
#   Size: 200.0
#   Time range: 1.1980s - 1.1985s
#   Sample count: 200
#
# Slice 89:
#   Event: rf at 1.1985s
#   Size: 200.0
#   Time range: 1.1985s - 1.2005s
#   Sample count: 200
#
# Slice 90:
#   Event: gz at 1.2005s
#   Size: 200.0
#   Time range: 1.2005s - 1.2010s
#   Sample count: 200
#
# Slice 91:
#   Event: delay at 1.2010s
#   Size: 20.0
#   Time range: 1.2010s - 1.2485s
#   Sample count: 20
#
# Slice 92:
#   Event: gz at 1.2510s
#   Size: 200.0
#   Time range: 1.2510s - 1.2515s
#   Sample count: 200
#
# Slice 93:
#   Event: rf at 1.2515s
#   Size: 200.0
#   Time range: 1.2515s - 1.2535s
#   Sample count: 200
#
# Slice 94:
#   Event: gz at 1.2535s
#   Size: 200.0
#   Time range: 1.2535s - 1.2540s
#   Sample count: 200
#
# Slice 95:
#   Event: delay at 1.2540s
#   Size: 20.0
#   Time range: 1.2540s - 1.3015s
#   Sample count: 20
#
# Slice 96:
#   Event: gz at 1.3040s
#   Size: 200.0
#   Time range: 1.3040s - 1.3045s
#   Sample count: 200
#
# Slice 97:
#   Event: rf at 1.3045s
#   Size: 200.0
#   Time range: 1.3045s - 1.3065s
#   Sample count: 200
#
# Slice 98:
#   Event: gz at 1.3065s
#   Size: 200.0
#   Time range: 1.3065s - 1.3070s
#   Sample count: 200
#
# Slice 99:
#   Event: delay at 1.3070s
#   Size: 20.0
#   Time range: 1.3070s - 1.3545s
#   Sample count: 20
#
# Slice 100:
#   Event: gz at 1.3570s
#   Size: 200.0
#   Time range: 1.3570s - 1.3575s
#   Sample count: 200
#
# Slice 101:
#   Event: rf at 1.3575s
#   Size: 200.0
#   Time range: 1.3575s - 1.3595s
#   Sample count: 200
#
# Slice 102:
#   Event: gz at 1.3595s
#   Size: 200.0
#   Time range: 1.3595s - 1.3600s
#   Sample count: 200
#
# Slice 103:
#   Event: delay at 1.3600s
#   Size: 20.0
#   Time range: 1.3600s - 1.4075s
#   Sample count: 20
#
# Slice 104:
#   Event: gz at 1.4100s
#   Size: 200.0
#   Time range: 1.4100s - 1.4105s
#   Sample count: 200
#
# Slice 105:
#   Event: rf at 1.4105s
#   Size: 200.0
#   Time range: 1.4105s - 1.4125s
#   Sample count: 200
#
# Slice 106:
#   Event: gz at 1.4125s
#   Size: 200.0
#   Time range: 1.4125s - 1.4130s
#   Sample count: 200
#
# Slice 107:
#   Event: delay at 1.4130s
#   Size: 20.0
#   Time range: 1.4130s - 1.4605s
#   Sample count: 20
#
# Slice 108:
#   Event: gz at 1.4630s
#   Size: 200.0
#   Time range: 1.4630s - 1.4635s
#   Sample count: 200
#
# Slice 109:
#   Event: rf at 1.4635s
#   Size: 200.0
#   Time range: 1.4635s - 1.4655s
#   Sample count: 200
#
# Slice 110:
#   Event: gz at 1.4655s
#   Size: 200.0
#   Time range: 1.4655s - 1.4660s
#   Sample count: 200
#
# Slice 111:
#   Event: delay at 1.4660s
#   Size: 20.0
#   Time range: 1.4660s - 1.5135s
#   Sample count: 20
#
# Slice 112:
#   Event: gz at 1.5160s
#   Size: 200.0
#   Time range: 1.5160s - 1.5165s
#   Sample count: 200
#
# Slice 113:
#   Event: rf at 1.5165s
#   Size: 200.0
#   Time range: 1.5165s - 1.5185s
#   Sample count: 200
#
# Slice 114:
#   Event: gz at 1.5185s
#   Size: 200.0
#   Time range: 1.5185s - 1.5190s
#   Sample count: 200
#
# Slice 115:
#   Event: delay at 1.5190s
#   Size: 20.0
#   Time range: 1.5190s - 1.5665s
#   Sample count: 20
#
# Slice 116:
#   Event: gz at 1.5690s
#   Size: 200.0
#   Time range: 1.5690s - 1.5695s
#   Sample count: 200
#
# Slice 117:
#   Event: rf at 1.5695s
#   Size: 200.0
#   Time range: 1.5695s - 1.5715s
#   Sample count: 200
#
# Slice 118:
#   Event: gz at 1.5715s
#   Size: 200.0
#   Time range: 1.5715s - 1.5720s
#   Sample count: 200
#
# Slice 119:
#   Event: delay at 1.5720s
#   Size: 20.0
#   Time range: 1.5720s - 1.6195s
#   Sample count: 20
#
# Slice 120:
#   Event: gz at 1.6220s
#   Size: 200.0
#   Time range: 1.6220s - 1.6225s
#   Sample count: 200
#
# Slice 121:
#   Event: rf at 1.6225s
#   Size: 200.0
#   Time range: 1.6225s - 1.6245s
#   Sample count: 200
#
# Slice 122:
#   Event: gz at 1.6245s
#   Size: 200.0
#   Time range: 1.6245s - 1.6250s
#   Sample count: 200
#
# Slice 123:
#   Event: delay at 1.6250s
#   Size: 20.0
#   Time range: 1.6250s - 1.6725s
#   Sample count: 20
#
# Slice 124:
#   Event: gz at 1.6750s
#   Size: 200.0
#   Time range: 1.6750s - 1.6755s
#   Sample count: 200
#
# Slice 125:
#   Event: rf at 1.6755s
#   Size: 200.0
#   Time range: 1.6755s - 1.6775s
#   Sample count: 200
#
# Slice 126:
#   Event: gz at 1.6775s
#   Size: 200.0
#   Time range: 1.6775s - 1.6780s
#   Sample count: 200
#
# Slice 127:
#   Event: delay at 1.6780s
#   Size: 20.0
#   Time range: 1.6780s - 1.7255s
#   Sample count: 20
#
# Slice 128:
#   Event: gz at 1.7280s
#   Size: 200.0
#   Time range: 1.7280s - 1.7285s
#   Sample count: 200
#
# Slice 129:
#   Event: rf at 1.7285s
#   Size: 200.0
#   Time range: 1.7285s - 1.7305s
#   Sample count: 200
#
# Slice 130:
#   Event: gz at 1.7305s
#   Size: 200.0
#   Time range: 1.7305s - 1.7310s
#   Sample count: 200
#
# Slice 131:
#   Event: delay at 1.7310s
#   Size: 20.0
#   Time range: 1.7310s - 1.7785s
#   Sample count: 20
#
# Slice 132:
#   Event: gz at 1.7810s
#   Size: 200.0
#   Time range: 1.7810s - 1.7815s
#   Sample count: 200
#
# Slice 133:
#   Event: rf at 1.7815s
#   Size: 200.0
#   Time range: 1.7815s - 1.7835s
#   Sample count: 200
#
# Slice 134:
#   Event: gz at 1.7835s
#   Size: 200.0
#   Time range: 1.7835s - 1.7840s
#   Sample count: 200
#
# Slice 135:
#   Event: delay at 1.7840s
#   Size: 20.0
#   Time range: 1.7840s - 1.8315s
#   Sample count: 20
#
# Slice 136:
#   Event: gz at 1.8340s
#   Size: 200.0
#   Time range: 1.8340s - 1.8345s
#   Sample count: 200
#
# Slice 137:
#   Event: rf at 1.8345s
#   Size: 200.0
#   Time range: 1.8345s - 1.8365s
#   Sample count: 200
#
# Slice 138:
#   Event: gz at 1.8365s
#   Size: 200.0
#   Time range: 1.8365s - 1.8370s
#   Sample count: 200
#
# Slice 139:
#   Event: delay at 1.8370s
#   Size: 20.0
#   Time range: 1.8370s - 1.8845s
#   Sample count: 20
#
# Slice 140:
#   Event: gz at 1.8870s
#   Size: 200.0
#   Time range: 1.8870s - 1.8875s
#   Sample count: 200
#
# Slice 141:
#   Event: rf at 1.8875s
#   Size: 200.0
#   Time range: 1.8875s - 1.8895s
#   Sample count: 200
#
# Slice 142:
#   Event: gz at 1.8895s
#   Size: 200.0
#   Time range: 1.8895s - 1.8900s
#   Sample count: 200
#
# Slice 143:
#   Event: delay at 1.8900s
#   Size: 20.0
#   Time range: 1.8900s - 1.9375s
#   Sample count: 20
#
# Slice 144:
#   Event: gz at 1.9400s
#   Size: 200.0
#   Time range: 1.9400s - 1.9405s
#   Sample count: 200
#
# Slice 145:
#   Event: rf at 1.9405s
#   Size: 200.0
#   Time range: 1.9405s - 1.9425s
#   Sample count: 200
#
# Slice 146:
#   Event: gz at 1.9425s
#   Size: 200.0
#   Time range: 1.9425s - 1.9430s
#   Sample count: 200
#
# Slice 147:
#   Event: delay at 1.9430s
#   Size: 20.0
#   Time range: 1.9430s - 1.9905s
#   Sample count: 20
#
# Slice 148:
#   Event: gz at 1.9930s
#   Size: 200.0
#   Time range: 1.9930s - 1.9935s
#   Sample count: 200
#
# Slice 149:
#   Event: rf at 1.9935s
#   Size: 200.0
#   Time range: 1.9935s - 1.9955s
#   Sample count: 200
#
# Slice 150:
#   Event: gz at 1.9955s
#   Size: 200.0
#   Time range: 1.9955s - 1.9960s
#   Sample count: 200
#
# Slice 151:
#   Event: delay at 1.9960s
#   Size: 20.0
#   Time range: 1.9960s - 2.0435s
#   Sample count: 20
#
# Slice 152:
#   Event: gz at 2.0460s
#   Size: 200.0
#   Time range: 2.0460s - 2.0465s
#   Sample count: 200
#
# Slice 153:
#   Event: rf at 2.0465s
#   Size: 200.0
#   Time range: 2.0465s - 2.0485s
#   Sample count: 200
#
# Slice 154:
#   Event: gz at 2.0485s
#   Size: 200.0
#   Time range: 2.0485s - 2.0490s
#   Sample count: 200
#
# Slice 155:
#   Event: delay at 2.0490s
#   Size: 20.0
#   Time range: 2.0490s - 2.0965s
#   Sample count: 20
#
# Slice 156:
#   Event: gz at 2.0990s
#   Size: 200.0
#   Time range: 2.0990s - 2.0995s
#   Sample count: 200
#
# Slice 157:
#   Event: rf at 2.0995s
#   Size: 200.0
#   Time range: 2.0995s - 2.1015s
#   Sample count: 200
#
# Slice 158:
#   Event: gz at 2.1015s
#   Size: 200.0
#   Time range: 2.1015s - 2.1020s
#   Sample count: 200
#
# Slice 159:
#   Event: delay at 2.1020s
#   Size: 20.0
#   Time range: 2.1020s - 2.1495s
#   Sample count: 20
#
# Slice 160:
#   Event: gz at 2.1520s
#   Size: 200.0
#   Time range: 2.1520s - 2.1525s
#   Sample count: 200
#
# Slice 161:
#   Event: rf at 2.1525s
#   Size: 200.0
#   Time range: 2.1525s - 2.1545s
#   Sample count: 200
#
# Slice 162:
#   Event: gz at 2.1545s
#   Size: 200.0
#   Time range: 2.1545s - 2.1550s
#   Sample count: 200
#
# Slice 163:
#   Event: delay at 2.1550s
#   Size: 20.0
#   Time range: 2.1550s - 2.2025s
#   Sample count: 20
#
# Slice 164:
#   Event: gz at 2.2050s
#   Size: 200.0
#   Time range: 2.2050s - 2.2055s
#   Sample count: 200
#
# Slice 165:
#   Event: rf at 2.2055s
#   Size: 200.0
#   Time range: 2.2055s - 2.2075s
#   Sample count: 200
#
# Slice 166:
#   Event: gz at 2.2075s
#   Size: 200.0
#   Time range: 2.2075s - 2.2080s
#   Sample count: 200
#
# Slice 167:
#   Event: delay at 2.2080s
#   Size: 20.0
#   Time range: 2.2080s - 2.2555s
#   Sample count: 20
#
# Slice 168:
#   Event: adc at 2.2580s
#   Size: 200.0
#   Time range: 2.2580s - 2.2630s
#   Sample count: 200
#
# === End Debug ===
# BMCTool simulation: 100%|██████████| 169/169 [00:32<00:00,  5.26it/s]
# === Debug: get_exact() ===
# Total time samples: 26061
# Time sampling sizes: tensor([ 20., 200., 200., 200.,  20., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200.])
# Events: ['delay at 0.0000s', 'rf at 0.0010s', 'gz at 0.0030s', 'rf at 0.0035s', 'delay at 0.0055s', 'rf at 0.0855s', 'gz at 0.0875s', 'delay at 0.0880s', 'gz at 0.1380s', 'rf at 0.1385s', 'gz at 0.1405s', 'delay at 0.1410s', 'gz at 0.1910s', 'rf at 0.1915s', 'gz at 0.1935s', 'delay at 0.1940s', 'gz at 0.2440s', 'rf at 0.2445s', 'gz at 0.2465s', 'delay at 0.2470s', 'gz at 0.2970s', 'rf at 0.2975s', 'gz at 0.2995s', 'delay at 0.3000s', 'gz at 0.3500s', 'rf at 0.3505s', 'gz at 0.3525s', 'delay at 0.3530s', 'gz at 0.4030s', 'rf at 0.4035s', 'gz at 0.4055s', 'delay at 0.4060s', 'gz at 0.4560s', 'rf at 0.4565s', 'gz at 0.4585s', 'delay at 0.4590s', 'gz at 0.5090s', 'rf at 0.5095s', 'gz at 0.5115s', 'delay at 0.5120s', 'gz at 0.5620s', 'rf at 0.5625s', 'gz at 0.5645s', 'delay at 0.5650s', 'gz at 0.6150s', 'rf at 0.6155s', 'gz at 0.6175s', 'delay at 0.6180s', 'gz at 0.6680s', 'rf at 0.6685s', 'gz at 0.6705s', 'delay at 0.6710s', 'gz at 0.7210s', 'rf at 0.7215s', 'gz at 0.7235s', 'delay at 0.7240s', 'gz at 0.7740s', 'rf at 0.7745s', 'gz at 0.7765s', 'delay at 0.7770s', 'gz at 0.8270s', 'rf at 0.8275s', 'gz at 0.8295s', 'delay at 0.8300s', 'gz at 0.8800s', 'rf at 0.8805s', 'gz at 0.8825s', 'delay at 0.8830s', 'gz at 0.9330s', 'rf at 0.9335s', 'gz at 0.9355s', 'delay at 0.9360s', 'gz at 0.9860s', 'rf at 0.9865s', 'gz at 0.9885s', 'delay at 0.9890s', 'gz at 1.0390s', 'rf at 1.0395s', 'gz at 1.0415s', 'delay at 1.0420s', 'gz at 1.0920s', 'rf at 1.0925s', 'gz at 1.0945s', 'delay at 1.0950s', 'gz at 1.1450s', 'rf at 1.1455s', 'gz at 1.1475s', 'delay at 1.1480s', 'gz at 1.1980s', 'rf at 1.1985s', 'gz at 1.2005s', 'delay at 1.2010s', 'gz at 1.2510s', 'rf at 1.2515s', 'gz at 1.2535s', 'delay at 1.2540s', 'gz at 1.3040s', 'rf at 1.3045s', 'gz at 1.3065s', 'delay at 1.3070s', 'gz at 1.3570s', 'rf at 1.3575s', 'gz at 1.3595s', 'delay at 1.3600s', 'gz at 1.4100s', 'rf at 1.4105s', 'gz at 1.4125s', 'delay at 1.4130s', 'gz at 1.4630s', 'rf at 1.4635s', 'gz at 1.4655s', 'delay at 1.4660s', 'gz at 1.5160s', 'rf at 1.5165s', 'gz at 1.5185s', 'delay at 1.5190s', 'gz at 1.5690s', 'rf at 1.5695s', 'gz at 1.5715s', 'delay at 1.5720s', 'gz at 1.6220s', 'rf at 1.6225s', 'gz at 1.6245s', 'delay at 1.6250s', 'gz at 1.6750s', 'rf at 1.6755s', 'gz at 1.6775s', 'delay at 1.6780s', 'gz at 1.7280s', 'rf at 1.7285s', 'gz at 1.7305s', 'delay at 1.7310s', 'gz at 1.7810s', 'rf at 1.7815s', 'gz at 1.7835s', 'delay at 1.7840s', 'gz at 1.8340s', 'rf at 1.8345s', 'gz at 1.8365s', 'delay at 1.8370s', 'gz at 1.8870s', 'rf at 1.8875s', 'gz at 1.8895s', 'delay at 1.8900s', 'gz at 1.9400s', 'rf at 1.9405s', 'gz at 1.9425s', 'delay at 1.9430s', 'gz at 1.9930s', 'rf at 1.9935s', 'gz at 1.9955s', 'delay at 1.9960s', 'gz at 2.0460s', 'rf at 2.0465s', 'gz at 2.0485s', 'delay at 2.0490s', 'gz at 2.0990s', 'rf at 2.0995s', 'gz at 2.1015s', 'delay at 2.1020s', 'gz at 2.1520s', 'rf at 2.1525s', 'gz at 2.1545s', 'delay at 2.1550s', 'gz at 2.2050s', 'rf at 2.2055s', 'gz at 2.2075s', 'delay at 2.2080s', 'adc at 2.2580s']
#
# Slice 0:
#   Event: delay at 0.0000s
#   Size: 20.0
#   Time range: 0.0000s - 0.0009s
#   Sample count: 20
#
# Slice 1:
#   Event: rf at 0.0010s
#   Size: 200.0
#   Time range: 0.0010s - 0.0030s
#   Sample count: 200
#
# Slice 2:
#   Event: gz at 0.0030s
#   Size: 200.0
#   Time range: 0.0030s - 0.0035s
#   Sample count: 200
#
# Slice 3:
#   Event: rf at 0.0035s
#   Size: 200.0
#   Time range: 0.0035s - 0.0055s
#   Sample count: 200
#
# Slice 4:
#   Event: delay at 0.0055s
#   Size: 20.0
#   Time range: 0.0055s - 0.0815s
#   Sample count: 20
#
# Slice 5:
#   Event: rf at 0.0855s
#   Size: 200.0
#   Time range: 0.0855s - 0.0875s
#   Sample count: 200
#
# Slice 6:
#   Event: gz at 0.0875s
#   Size: 200.0
#   Time range: 0.0875s - 0.0880s
#   Sample count: 200
#
# Slice 7:
#   Event: delay at 0.0880s
#   Size: 20.0
#   Time range: 0.0880s - 0.1355s
#   Sample count: 20
#
# Slice 8:
#   Event: gz at 0.1380s
#   Size: 200.0
#   Time range: 0.1380s - 0.1385s
#   Sample count: 200
#
# Slice 9:
#   Event: rf at 0.1385s
#   Size: 200.0
#   Time range: 0.1385s - 0.1405s
#   Sample count: 200
#
# Slice 10:
#   Event: gz at 0.1405s
#   Size: 200.0
#   Time range: 0.1405s - 0.1410s
#   Sample count: 200
#
# Slice 11:
#   Event: delay at 0.1410s
#   Size: 20.0
#   Time range: 0.1410s - 0.1885s
#   Sample count: 20
#
# Slice 12:
#   Event: gz at 0.1910s
#   Size: 200.0
#   Time range: 0.1910s - 0.1915s
#   Sample count: 200
#
# Slice 13:
#   Event: rf at 0.1915s
#   Size: 200.0
#   Time range: 0.1915s - 0.1935s
#   Sample count: 200
#
# Slice 14:
#   Event: gz at 0.1935s
#   Size: 200.0
#   Time range: 0.1935s - 0.1940s
#   Sample count: 200
#
# Slice 15:
#   Event: delay at 0.1940s
#   Size: 20.0
#   Time range: 0.1940s - 0.2415s
#   Sample count: 20
#
# Slice 16:
#   Event: gz at 0.2440s
#   Size: 200.0
#   Time range: 0.2440s - 0.2445s
#   Sample count: 200
#
# Slice 17:
#   Event: rf at 0.2445s
#   Size: 200.0
#   Time range: 0.2445s - 0.2465s
#   Sample count: 200
#
# Slice 18:
#   Event: gz at 0.2465s
#   Size: 200.0
#   Time range: 0.2465s - 0.2470s
#   Sample count: 200
#
# Slice 19:
#   Event: delay at 0.2470s
#   Size: 20.0
#   Time range: 0.2470s - 0.2945s
#   Sample count: 20
#
# Slice 20:
#   Event: gz at 0.2970s
#   Size: 200.0
#   Time range: 0.2970s - 0.2975s
#   Sample count: 200
#
# Slice 21:
#   Event: rf at 0.2975s
#   Size: 200.0
#   Time range: 0.2975s - 0.2995s
#   Sample count: 200
#
# Slice 22:
#   Event: gz at 0.2995s
#   Size: 200.0
#   Time range: 0.2995s - 0.3000s
#   Sample count: 200
#
# Slice 23:
#   Event: delay at 0.3000s
#   Size: 20.0
#   Time range: 0.3000s - 0.3475s
#   Sample count: 20
#
# Slice 24:
#   Event: gz at 0.3500s
#   Size: 200.0
#   Time range: 0.3500s - 0.3505s
#   Sample count: 200
#
# Slice 25:
#   Event: rf at 0.3505s
#   Size: 200.0
#   Time range: 0.3505s - 0.3525s
#   Sample count: 200
#
# Slice 26:
#   Event: gz at 0.3525s
#   Size: 200.0
#   Time range: 0.3525s - 0.3530s
#   Sample count: 200
#
# Slice 27:
#   Event: delay at 0.3530s
#   Size: 20.0
#   Time range: 0.3530s - 0.4005s
#   Sample count: 20
#
# Slice 28:
#   Event: gz at 0.4030s
#   Size: 200.0
#   Time range: 0.4030s - 0.4035s
#   Sample count: 200
#
# Slice 29:
#   Event: rf at 0.4035s
#   Size: 200.0
#   Time range: 0.4035s - 0.4055s
#   Sample count: 200
#
# Slice 30:
#   Event: gz at 0.4055s
#   Size: 200.0
#   Time range: 0.4055s - 0.4060s
#   Sample count: 200
#
# Slice 31:
#   Event: delay at 0.4060s
#   Size: 20.0
#   Time range: 0.4060s - 0.4535s
#   Sample count: 20
#
# Slice 32:
#   Event: gz at 0.4560s
#   Size: 200.0
#   Time range: 0.4560s - 0.4565s
#   Sample count: 200
#
# Slice 33:
#   Event: rf at 0.4565s
#   Size: 200.0
#   Time range: 0.4565s - 0.4585s
#   Sample count: 200
#
# Slice 34:
#   Event: gz at 0.4585s
#   Size: 200.0
#   Time range: 0.4585s - 0.4590s
#   Sample count: 200
#
# Slice 35:
#   Event: delay at 0.4590s
#   Size: 20.0
#   Time range: 0.4590s - 0.5065s
#   Sample count: 20
#
# Slice 36:
#   Event: gz at 0.5090s
#   Size: 200.0
#   Time range: 0.5090s - 0.5095s
#   Sample count: 200
#
# Slice 37:
#   Event: rf at 0.5095s
#   Size: 200.0
#   Time range: 0.5095s - 0.5115s
#   Sample count: 200
#
# Slice 38:
#   Event: gz at 0.5115s
#   Size: 200.0
#   Time range: 0.5115s - 0.5120s
#   Sample count: 200
#
# Slice 39:
#   Event: delay at 0.5120s
#   Size: 20.0
#   Time range: 0.5120s - 0.5595s
#   Sample count: 20
#
# Slice 40:
#   Event: gz at 0.5620s
#   Size: 200.0
#   Time range: 0.5620s - 0.5625s
#   Sample count: 200
#
# Slice 41:
#   Event: rf at 0.5625s
#   Size: 200.0
#   Time range: 0.5625s - 0.5645s
#   Sample count: 200
#
# Slice 42:
#   Event: gz at 0.5645s
#   Size: 200.0
#   Time range: 0.5645s - 0.5650s
#   Sample count: 200
#
# Slice 43:
#   Event: delay at 0.5650s
#   Size: 20.0
#   Time range: 0.5650s - 0.6125s
#   Sample count: 20
#
# Slice 44:
#   Event: gz at 0.6150s
#   Size: 200.0
#   Time range: 0.6150s - 0.6155s
#   Sample count: 200
#
# Slice 45:
#   Event: rf at 0.6155s
#   Size: 200.0
#   Time range: 0.6155s - 0.6175s
#   Sample count: 200
#
# Slice 46:
#   Event: gz at 0.6175s
#   Size: 200.0
#   Time range: 0.6175s - 0.6180s
#   Sample count: 200
#
# Slice 47:
#   Event: delay at 0.6180s
#   Size: 20.0
#   Time range: 0.6180s - 0.6655s
#   Sample count: 20
#
# Slice 48:
#   Event: gz at 0.6680s
#   Size: 200.0
#   Time range: 0.6680s - 0.6685s
#   Sample count: 200
#
# Slice 49:
#   Event: rf at 0.6685s
#   Size: 200.0
#   Time range: 0.6685s - 0.6705s
#   Sample count: 200
#
# Slice 50:
#   Event: gz at 0.6705s
#   Size: 200.0
#   Time range: 0.6705s - 0.6710s
#   Sample count: 200
#
# Slice 51:
#   Event: delay at 0.6710s
#   Size: 20.0
#   Time range: 0.6710s - 0.7185s
#   Sample count: 20
#
# Slice 52:
#   Event: gz at 0.7210s
#   Size: 200.0
#   Time range: 0.7210s - 0.7215s
#   Sample count: 200
#
# Slice 53:
#   Event: rf at 0.7215s
#   Size: 200.0
#   Time range: 0.7215s - 0.7235s
#   Sample count: 200
#
# Slice 54:
#   Event: gz at 0.7235s
#   Size: 200.0
#   Time range: 0.7235s - 0.7240s
#   Sample count: 200
#
# Slice 55:
#   Event: delay at 0.7240s
#   Size: 20.0
#   Time range: 0.7240s - 0.7715s
#   Sample count: 20
#
# Slice 56:
#   Event: gz at 0.7740s
#   Size: 200.0
#   Time range: 0.7740s - 0.7745s
#   Sample count: 200
#
# Slice 57:
#   Event: rf at 0.7745s
#   Size: 200.0
#   Time range: 0.7745s - 0.7765s
#   Sample count: 200
#
# Slice 58:
#   Event: gz at 0.7765s
#   Size: 200.0
#   Time range: 0.7765s - 0.7770s
#   Sample count: 200
#
# Slice 59:
#   Event: delay at 0.7770s
#   Size: 20.0
#   Time range: 0.7770s - 0.8245s
#   Sample count: 20
#
# Slice 60:
#   Event: gz at 0.8270s
#   Size: 200.0
#   Time range: 0.8270s - 0.8275s
#   Sample count: 200
#
# Slice 61:
#   Event: rf at 0.8275s
#   Size: 200.0
#   Time range: 0.8275s - 0.8295s
#   Sample count: 200
#
# Slice 62:
#   Event: gz at 0.8295s
#   Size: 200.0
#   Time range: 0.8295s - 0.8300s
#   Sample count: 200
#
# Slice 63:
#   Event: delay at 0.8300s
#   Size: 20.0
#   Time range: 0.8300s - 0.8775s
#   Sample count: 20
#
# Slice 64:
#   Event: gz at 0.8800s
#   Size: 200.0
#   Time range: 0.8800s - 0.8805s
#   Sample count: 200
#
# Slice 65:
#   Event: rf at 0.8805s
#   Size: 200.0
#   Time range: 0.8805s - 0.8825s
#   Sample count: 200
#
# Slice 66:
#   Event: gz at 0.8825s
#   Size: 200.0
#   Time range: 0.8825s - 0.8830s
#   Sample count: 200
#
# Slice 67:
#   Event: delay at 0.8830s
#   Size: 20.0
#   Time range: 0.8830s - 0.9305s
#   Sample count: 20
#
# Slice 68:
#   Event: gz at 0.9330s
#   Size: 200.0
#   Time range: 0.9330s - 0.9335s
#   Sample count: 200
#
# Slice 69:
#   Event: rf at 0.9335s
#   Size: 200.0
#   Time range: 0.9335s - 0.9355s
#   Sample count: 200
#
# Slice 70:
#   Event: gz at 0.9355s
#   Size: 200.0
#   Time range: 0.9355s - 0.9360s
#   Sample count: 200
#
# Slice 71:
#   Event: delay at 0.9360s
#   Size: 20.0
#   Time range: 0.9360s - 0.9835s
#   Sample count: 20
#
# Slice 72:
#   Event: gz at 0.9860s
#   Size: 200.0
#   Time range: 0.9860s - 0.9865s
#   Sample count: 200
#
# Slice 73:
#   Event: rf at 0.9865s
#   Size: 200.0
#   Time range: 0.9865s - 0.9885s
#   Sample count: 200
#
# Slice 74:
#   Event: gz at 0.9885s
#   Size: 200.0
#   Time range: 0.9885s - 0.9890s
#   Sample count: 200
#
# Slice 75:
#   Event: delay at 0.9890s
#   Size: 20.0
#   Time range: 0.9890s - 1.0365s
#   Sample count: 20
#
# Slice 76:
#   Event: gz at 1.0390s
#   Size: 200.0
#   Time range: 1.0390s - 1.0395s
#   Sample count: 200
#
# Slice 77:
#   Event: rf at 1.0395s
#   Size: 200.0
#   Time range: 1.0395s - 1.0415s
#   Sample count: 200
#
# Slice 78:
#   Event: gz at 1.0415s
#   Size: 200.0
#   Time range: 1.0415s - 1.0420s
#   Sample count: 200
#
# Slice 79:
#   Event: delay at 1.0420s
#   Size: 20.0
#   Time range: 1.0420s - 1.0895s
#   Sample count: 20
#
# Slice 80:
#   Event: gz at 1.0920s
#   Size: 200.0
#   Time range: 1.0920s - 1.0925s
#   Sample count: 200
#
# Slice 81:
#   Event: rf at 1.0925s
#   Size: 200.0
#   Time range: 1.0925s - 1.0945s
#   Sample count: 200
#
# Slice 82:
#   Event: gz at 1.0945s
#   Size: 200.0
#   Time range: 1.0945s - 1.0950s
#   Sample count: 200
#
# Slice 83:
#   Event: delay at 1.0950s
#   Size: 20.0
#   Time range: 1.0950s - 1.1425s
#   Sample count: 20
#
# Slice 84:
#   Event: gz at 1.1450s
#   Size: 200.0
#   Time range: 1.1450s - 1.1455s
#   Sample count: 200
#
# Slice 85:
#   Event: rf at 1.1455s
#   Size: 200.0
#   Time range: 1.1455s - 1.1475s
#   Sample count: 200
#
# Slice 86:
#   Event: gz at 1.1475s
#   Size: 200.0
#   Time range: 1.1475s - 1.1480s
#   Sample count: 200
#
# Slice 87:
#   Event: delay at 1.1480s
#   Size: 20.0
#   Time range: 1.1480s - 1.1955s
#   Sample count: 20
#
# Slice 88:
#   Event: gz at 1.1980s
#   Size: 200.0
#   Time range: 1.1980s - 1.1985s
#   Sample count: 200
#
# Slice 89:
#   Event: rf at 1.1985s
#   Size: 200.0
#   Time range: 1.1985s - 1.2005s
#   Sample count: 200
#
# Slice 90:
#   Event: gz at 1.2005s
#   Size: 200.0
#   Time range: 1.2005s - 1.2010s
#   Sample count: 200
#
# Slice 91:
#   Event: delay at 1.2010s
#   Size: 20.0
#   Time range: 1.2010s - 1.2485s
#   Sample count: 20
#
# Slice 92:
#   Event: gz at 1.2510s
#   Size: 200.0
#   Time range: 1.2510s - 1.2515s
#   Sample count: 200
#
# Slice 93:
#   Event: rf at 1.2515s
#   Size: 200.0
#   Time range: 1.2515s - 1.2535s
#   Sample count: 200
#
# Slice 94:
#   Event: gz at 1.2535s
#   Size: 200.0
#   Time range: 1.2535s - 1.2540s
#   Sample count: 200
#
# Slice 95:
#   Event: delay at 1.2540s
#   Size: 20.0
#   Time range: 1.2540s - 1.3015s
#   Sample count: 20
#
# Slice 96:
#   Event: gz at 1.3040s
#   Size: 200.0
#   Time range: 1.3040s - 1.3045s
#   Sample count: 200
#
# Slice 97:
#   Event: rf at 1.3045s
#   Size: 200.0
#   Time range: 1.3045s - 1.3065s
#   Sample count: 200
#
# Slice 98:
#   Event: gz at 1.3065s
#   Size: 200.0
#   Time range: 1.3065s - 1.3070s
#   Sample count: 200
#
# Slice 99:
#   Event: delay at 1.3070s
#   Size: 20.0
#   Time range: 1.3070s - 1.3545s
#   Sample count: 20
#
# Slice 100:
#   Event: gz at 1.3570s
#   Size: 200.0
#   Time range: 1.3570s - 1.3575s
#   Sample count: 200
#
# Slice 101:
#   Event: rf at 1.3575s
#   Size: 200.0
#   Time range: 1.3575s - 1.3595s
#   Sample count: 200
#
# Slice 102:
#   Event: gz at 1.3595s
#   Size: 200.0
#   Time range: 1.3595s - 1.3600s
#   Sample count: 200
#
# Slice 103:
#   Event: delay at 1.3600s
#   Size: 20.0
#   Time range: 1.3600s - 1.4075s
#   Sample count: 20
#
# Slice 104:
#   Event: gz at 1.4100s
#   Size: 200.0
#   Time range: 1.4100s - 1.4105s
#   Sample count: 200
#
# Slice 105:
#   Event: rf at 1.4105s
#   Size: 200.0
#   Time range: 1.4105s - 1.4125s
#   Sample count: 200
#
# Slice 106:
#   Event: gz at 1.4125s
#   Size: 200.0
#   Time range: 1.4125s - 1.4130s
#   Sample count: 200
#
# Slice 107:
#   Event: delay at 1.4130s
#   Size: 20.0
#   Time range: 1.4130s - 1.4605s
#   Sample count: 20
#
# Slice 108:
#   Event: gz at 1.4630s
#   Size: 200.0
#   Time range: 1.4630s - 1.4635s
#   Sample count: 200
#
# Slice 109:
#   Event: rf at 1.4635s
#   Size: 200.0
#   Time range: 1.4635s - 1.4655s
#   Sample count: 200
#
# Slice 110:
#   Event: gz at 1.4655s
#   Size: 200.0
#   Time range: 1.4655s - 1.4660s
#   Sample count: 200
#
# Slice 111:
#   Event: delay at 1.4660s
#   Size: 20.0
#   Time range: 1.4660s - 1.5135s
#   Sample count: 20
#
# Slice 112:
#   Event: gz at 1.5160s
#   Size: 200.0
#   Time range: 1.5160s - 1.5165s
#   Sample count: 200
#
# Slice 113:
#   Event: rf at 1.5165s
#   Size: 200.0
#   Time range: 1.5165s - 1.5185s
#   Sample count: 200
#
# Slice 114:
#   Event: gz at 1.5185s
#   Size: 200.0
#   Time range: 1.5185s - 1.5190s
#   Sample count: 200
#
# Slice 115:
#   Event: delay at 1.5190s
#   Size: 20.0
#   Time range: 1.5190s - 1.5665s
#   Sample count: 20
#
# Slice 116:
#   Event: gz at 1.5690s
#   Size: 200.0
#   Time range: 1.5690s - 1.5695s
#   Sample count: 200
#
# Slice 117:
#   Event: rf at 1.5695s
#   Size: 200.0
#   Time range: 1.5695s - 1.5715s
#   Sample count: 200
#
# Slice 118:
#   Event: gz at 1.5715s
#   Size: 200.0
#   Time range: 1.5715s - 1.5720s
#   Sample count: 200
#
# Slice 119:
#   Event: delay at 1.5720s
#   Size: 20.0
#   Time range: 1.5720s - 1.6195s
#   Sample count: 20
#
# Slice 120:
#   Event: gz at 1.6220s
#   Size: 200.0
#   Time range: 1.6220s - 1.6225s
#   Sample count: 200
#
# Slice 121:
#   Event: rf at 1.6225s
#   Size: 200.0
#   Time range: 1.6225s - 1.6245s
#   Sample count: 200
#
# Slice 122:
#   Event: gz at 1.6245s
#   Size: 200.0
#   Time range: 1.6245s - 1.6250s
#   Sample count: 200
#
# Slice 123:
#   Event: delay at 1.6250s
#   Size: 20.0
#   Time range: 1.6250s - 1.6725s
#   Sample count: 20
#
# Slice 124:
#   Event: gz at 1.6750s
#   Size: 200.0
#   Time range: 1.6750s - 1.6755s
#   Sample count: 200
#
# Slice 125:
#   Event: rf at 1.6755s
#   Size: 200.0
#   Time range: 1.6755s - 1.6775s
#   Sample count: 200
#
# Slice 126:
#   Event: gz at 1.6775s
#   Size: 200.0
#   Time range: 1.6775s - 1.6780s
#   Sample count: 200
#
# Slice 127:
#   Event: delay at 1.6780s
#   Size: 20.0
#   Time range: 1.6780s - 1.7255s
#   Sample count: 20
#
# Slice 128:
#   Event: gz at 1.7280s
#   Size: 200.0
#   Time range: 1.7280s - 1.7285s
#   Sample count: 200
#
# Slice 129:
#   Event: rf at 1.7285s
#   Size: 200.0
#   Time range: 1.7285s - 1.7305s
#   Sample count: 200
#
# Slice 130:
#   Event: gz at 1.7305s
#   Size: 200.0
#   Time range: 1.7305s - 1.7310s
#   Sample count: 200
#
# Slice 131:
#   Event: delay at 1.7310s
#   Size: 20.0
#   Time range: 1.7310s - 1.7785s
#   Sample count: 20
#
# Slice 132:
#   Event: gz at 1.7810s
#   Size: 200.0
#   Time range: 1.7810s - 1.7815s
#   Sample count: 200
#
# Slice 133:
#   Event: rf at 1.7815s
#   Size: 200.0
#   Time range: 1.7815s - 1.7835s
#   Sample count: 200
#
# Slice 134:
#   Event: gz at 1.7835s
#   Size: 200.0
#   Time range: 1.7835s - 1.7840s
#   Sample count: 200
#
# Slice 135:
#   Event: delay at 1.7840s
#   Size: 20.0
#   Time range: 1.7840s - 1.8315s
#   Sample count: 20
#
# Slice 136:
#   Event: gz at 1.8340s
#   Size: 200.0
#   Time range: 1.8340s - 1.8345s
#   Sample count: 200
#
# Slice 137:
#   Event: rf at 1.8345s
#   Size: 200.0
#   Time range: 1.8345s - 1.8365s
#   Sample count: 200
#
# Slice 138:
#   Event: gz at 1.8365s
#   Size: 200.0
#   Time range: 1.8365s - 1.8370s
#   Sample count: 200
#
# Slice 139:
#   Event: delay at 1.8370s
#   Size: 20.0
#   Time range: 1.8370s - 1.8845s
#   Sample count: 20
#
# Slice 140:
#   Event: gz at 1.8870s
#   Size: 200.0
#   Time range: 1.8870s - 1.8875s
#   Sample count: 200
#
# Slice 141:
#   Event: rf at 1.8875s
#   Size: 200.0
#   Time range: 1.8875s - 1.8895s
#   Sample count: 200
#
# Slice 142:
#   Event: gz at 1.8895s
#   Size: 200.0
#   Time range: 1.8895s - 1.8900s
#   Sample count: 200
#
# Slice 143:
#   Event: delay at 1.8900s
#   Size: 20.0
#   Time range: 1.8900s - 1.9375s
#   Sample count: 20
#
# Slice 144:
#   Event: gz at 1.9400s
#   Size: 200.0
#   Time range: 1.9400s - 1.9405s
#   Sample count: 200
#
# Slice 145:
#   Event: rf at 1.9405s
#   Size: 200.0
#   Time range: 1.9405s - 1.9425s
#   Sample count: 200
#
# Slice 146:
#   Event: gz at 1.9425s
#   Size: 200.0
#   Time range: 1.9425s - 1.9430s
#   Sample count: 200
#
# Slice 147:
#   Event: delay at 1.9430s
#   Size: 20.0
#   Time range: 1.9430s - 1.9905s
#   Sample count: 20
#
# Slice 148:
#   Event: gz at 1.9930s
#   Size: 200.0
#   Time range: 1.9930s - 1.9935s
#   Sample count: 200
#
# Slice 149:
#   Event: rf at 1.9935s
#   Size: 200.0
#   Time range: 1.9935s - 1.9955s
#   Sample count: 200
#
# Slice 150:
#   Event: gz at 1.9955s
#   Size: 200.0
#   Time range: 1.9955s - 1.9960s
#   Sample count: 200
#
# Slice 151:
#   Event: delay at 1.9960s
#   Size: 20.0
#   Time range: 1.9960s - 2.0435s
#   Sample count: 20
#
# Slice 152:
#   Event: gz at 2.0460s
#   Size: 200.0
#   Time range: 2.0460s - 2.0465s
#   Sample count: 200
#
# Slice 153:
#   Event: rf at 2.0465s
#   Size: 200.0
#   Time range: 2.0465s - 2.0485s
#   Sample count: 200
#
# Slice 154:
#   Event: gz at 2.0485s
#   Size: 200.0
#   Time range: 2.0485s - 2.0490s
#   Sample count: 200
#
# Slice 155:
#   Event: delay at 2.0490s
#   Size: 20.0
#   Time range: 2.0490s - 2.0965s
#   Sample count: 20
#
# Slice 156:
#   Event: gz at 2.0990s
#   Size: 200.0
#   Time range: 2.0990s - 2.0995s
#   Sample count: 200
#
# Slice 157:
#   Event: rf at 2.0995s
#   Size: 200.0
#   Time range: 2.0995s - 2.1015s
#   Sample count: 200
#
# Slice 158:
#   Event: gz at 2.1015s
#   Size: 200.0
#   Time range: 2.1015s - 2.1020s
#   Sample count: 200
#
# Slice 159:
#   Event: delay at 2.1020s
#   Size: 20.0
#   Time range: 2.1020s - 2.1495s
#   Sample count: 20
#
# Slice 160:
#   Event: gz at 2.1520s
#   Size: 200.0
#   Time range: 2.1520s - 2.1525s
#   Sample count: 200
#
# Slice 161:
#   Event: rf at 2.1525s
#   Size: 200.0
#   Time range: 2.1525s - 2.1545s
#   Sample count: 200
#
# Slice 162:
#   Event: gz at 2.1545s
#   Size: 200.0
#   Time range: 2.1545s - 2.1550s
#   Sample count: 200
#
# Slice 163:
#   Event: delay at 2.1550s
#   Size: 20.0
#   Time range: 2.1550s - 2.2025s
#   Sample count: 20
#
# Slice 164:
#   Event: gz at 2.2050s
#   Size: 200.0
#   Time range: 2.2050s - 2.2055s
#   Sample count: 200
#
# Slice 165:
#   Event: rf at 2.2055s
#   Size: 200.0
#   Time range: 2.2055s - 2.2075s
#   Sample count: 200
#
# Slice 166:
#   Event: gz at 2.2075s
#   Size: 200.0
#   Time range: 2.2075s - 2.2080s
#   Sample count: 200
#
# Slice 167:
#   Event: delay at 2.2080s
#   Size: 20.0
#   Time range: 2.2080s - 2.2555s
#   Sample count: 20
#
# Slice 168:
#   Event: adc at 2.2580s
#   Size: 200.0
#   Time range: 2.2580s - 2.2630s
#   Sample count: 200
#
# === End Debug ===

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
print(f'Signal: {singal.item()}')
# fig

fig, ax = plt.subplots(dpi=150)
for index, t_val in enumerate(plot_data['t']):
    ax.plot(t_val, plot_data['signal_plot'][index], 'o', markersize=1)
ax.axhline(0, c='black')
ax.set_ylim(-0.0008, 0.0003)
plt.show()
# Out:
# Signal: 0.00012971795633683796
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Phase Advance 180° (1ETM, alpha=30°)

# %%
seq_on_phasead = 'seq_lib/30phasead.seq'
seq_off_phasead = 'seq_lib/30phasead_minus.seq'

print(f'n_iso: {len(z_pos)}')
_, singal_phasead, plot_data_phasead = run_variation_parallel(seq_on_phasead, seq_off_phasead, config_path, adc_time, z_pos, webhook, show_plot=False, save_plot=False, store_all=True)
# Out:
# n_iso: 101
# BMCTool simulation: 100%|██████████| 169/169 [00:30<00:00,  5.50it/s]
# BMCTool simulation: 100%|██████████| 169/169 [00:30<00:00,  5.50it/s]
# === Debug: get_exact() ===
# Total time samples: 26061
#
# === Debug: get_exact() ===
# Total time samples: 26061
# Time sampling sizes: tensor([ 20., 200., 200., 200.,  20., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200.])
# Time sampling sizes: tensor([ 20., 200., 200., 200.,  20., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200., 200., 200.,  20., 200., 200., 200.,  20., 200., 200., 200.,  20.,
#         200.])
# Events: ['delay at 0.0000s', 'rf at 0.0010s', 'gz at 0.0030s', 'rf at 0.0035s', 'delay at 0.0055s', 'rf at 0.0855s', 'gz at 0.0875s', 'delay at 0.0880s', 'gz at 0.1380s', 'rf at 0.1385s', 'gz at 0.1405s', 'delay at 0.1410s', 'gz at 0.1910s', 'rf at 0.1915s', 'gz at 0.1935s', 'delay at 0.1940s', 'gz at 0.2440s', 'rf at 0.2445s', 'gz at 0.2465s', 'delay at 0.2470s', 'gz at 0.2970s', 'rf at 0.2975s', 'gz at 0.2995s', 'delay at 0.3000s', 'gz at 0.3500s', 'rf at 0.3505s', 'gz at 0.3525s', 'delay at 0.3530s', 'gz at 0.4030s', 'rf at 0.4035s', 'gz at 0.4055s', 'delay at 0.4060s', 'gz at 0.4560s', 'rf at 0.4565s', 'gz at 0.4585s', 'delay at 0.4590s', 'gz at 0.5090s', 'rf at 0.5095s', 'gz at 0.5115s', 'delay at 0.5120s', 'gz at 0.5620s', 'rf at 0.5625s', 'gz at 0.5645s', 'delay at 0.5650s', 'gz at 0.6150s', 'rf at 0.6155s', 'gz at 0.6175s', 'delay at 0.6180s', 'gz at 0.6680s', 'rf at 0.6685s', 'gz at 0.6705s', 'delay at 0.6710s', 'gz at 0.7210s', 'rf at 0.7215s', 'gz at 0.7235s', 'delay at 0.7240s', 'gz at 0.7740s', 'rf at 0.7745s', 'gz at 0.7765s', 'delay at 0.7770s', 'gz at 0.8270s', 'rf at 0.8275s', 'gz at 0.8295s', 'delay at 0.8300s', 'gz at 0.8800s', 'rf at 0.8805s', 'gz at 0.8825s', 'delay at 0.8830s', 'gz at 0.9330s', 'rf at 0.9335s', 'gz at 0.9355s', 'delay at 0.9360s', 'gz at 0.9860s', 'rf at 0.9865s', 'gz at 0.9885s', 'delay at 0.9890s', 'gz at 1.0390s', 'rf at 1.0395s', 'gz at 1.0415s', 'delay at 1.0420s', 'gz at 1.0920s', 'rf at 1.0925s', 'gz at 1.0945s', 'delay at 1.0950s', 'gz at 1.1450s', 'rf at 1.1455s', 'gz at 1.1475s', 'delay at 1.1480s', 'gz at 1.1980s', 'rf at 1.1985s', 'gz at 1.2005s', 'delay at 1.2010s', 'gz at 1.2510s', 'rf at 1.2515s', 'gz at 1.2535s', 'delay at 1.2540s', 'gz at 1.3040s', 'rf at 1.3045s', 'gz at 1.3065s', 'delay at 1.3070s', 'gz at 1.3570s', 'rf at 1.3575s', 'gz at 1.3595s', 'delay at 1.3600s', 'gz at 1.4100s', 'rf at 1.4105s', 'gz at 1.4125s', 'delay at 1.4130s', 'gz at 1.4630s', 'rf at 1.4635s', 'gz at 1.4655s', 'delay at 1.4660s', 'gz at 1.5160s', 'rf at 1.5165s', 'gz at 1.5185s', 'delay at 1.5190s', 'gz at 1.5690s', 'rf at 1.5695s', 'gz at 1.5715s', 'delay at 1.5720s', 'gz at 1.6220s', 'rf at 1.6225s', 'gz at 1.6245s', 'delay at 1.6250s', 'gz at 1.6750s', 'rf at 1.6755s', 'gz at 1.6775s', 'delay at 1.6780s', 'gz at 1.7280s', 'rf at 1.7285s', 'gz at 1.7305s', 'delay at 1.7310s', 'gz at 1.7810s', 'rf at 1.7815s', 'gz at 1.7835s', 'delay at 1.7840s', 'gz at 1.8340s', 'rf at 1.8345s', 'gz at 1.8365s', 'delay at 1.8370s', 'gz at 1.8870s', 'rf at 1.8875s', 'gz at 1.8895s', 'delay at 1.8900s', 'gz at 1.9400s', 'rf at 1.9405s', 'gz at 1.9425s', 'delay at 1.9430s', 'gz at 1.9930s', 'rf at 1.9935s', 'gz at 1.9955s', 'delay at 1.9960s', 'gz at 2.0460s', 'rf at 2.0465s', 'gz at 2.0485s', 'delay at 2.0490s', 'gz at 2.0990s', 'rf at 2.0995s', 'gz at 2.1015s', 'delay at 2.1020s', 'gz at 2.1520s', 'rf at 2.1525s', 'gz at 2.1545s', 'delay at 2.1550s', 'gz at 2.2050s', 'rf at 2.2055s', 'gz at 2.2075s', 'delay at 2.2080s', 'adc at 2.2580s']
# Events: ['delay at 0.0000s', 'rf at 0.0010s', 'gz at 0.0030s', 'rf at 0.0035s', 'delay at 0.0055s', 'rf at 0.0855s', 'gz at 0.0875s', 'delay at 0.0880s', 'gz at 0.1380s', 'rf at 0.1385s', 'gz at 0.1405s', 'delay at 0.1410s', 'gz at 0.1910s', 'rf at 0.1915s', 'gz at 0.1935s', 'delay at 0.1940s', 'gz at 0.2440s', 'rf at 0.2445s', 'gz at 0.2465s', 'delay at 0.2470s', 'gz at 0.2970s', 'rf at 0.2975s', 'gz at 0.2995s', 'delay at 0.3000s', 'gz at 0.3500s', 'rf at 0.3505s', 'gz at 0.3525s', 'delay at 0.3530s', 'gz at 0.4030s', 'rf at 0.4035s', 'gz at 0.4055s', 'delay at 0.4060s', 'gz at 0.4560s', 'rf at 0.4565s', 'gz at 0.4585s', 'delay at 0.4590s', 'gz at 0.5090s', 'rf at 0.5095s', 'gz at 0.5115s', 'delay at 0.5120s', 'gz at 0.5620s', 'rf at 0.5625s', 'gz at 0.5645s', 'delay at 0.5650s', 'gz at 0.6150s', 'rf at 0.6155s', 'gz at 0.6175s', 'delay at 0.6180s', 'gz at 0.6680s', 'rf at 0.6685s', 'gz at 0.6705s', 'delay at 0.6710s', 'gz at 0.7210s', 'rf at 0.7215s', 'gz at 0.7235s', 'delay at 0.7240s', 'gz at 0.7740s', 'rf at 0.7745s', 'gz at 0.7765s', 'delay at 0.7770s', 'gz at 0.8270s', 'rf at 0.8275s', 'gz at 0.8295s', 'delay at 0.8300s', 'gz at 0.8800s', 'rf at 0.8805s', 'gz at 0.8825s', 'delay at 0.8830s', 'gz at 0.9330s', 'rf at 0.9335s', 'gz at 0.9355s', 'delay at 0.9360s', 'gz at 0.9860s', 'rf at 0.9865s', 'gz at 0.9885s', 'delay at 0.9890s', 'gz at 1.0390s', 'rf at 1.0395s', 'gz at 1.0415s', 'delay at 1.0420s', 'gz at 1.0920s', 'rf at 1.0925s', 'gz at 1.0945s', 'delay at 1.0950s', 'gz at 1.1450s', 'rf at 1.1455s', 'gz at 1.1475s', 'delay at 1.1480s', 'gz at 1.1980s', 'rf at 1.1985s', 'gz at 1.2005s', 'delay at 1.2010s', 'gz at 1.2510s', 'rf at 1.2515s', 'gz at 1.2535s', 'delay at 1.2540s', 'gz at 1.3040s', 'rf at 1.3045s', 'gz at 1.3065s', 'delay at 1.3070s', 'gz at 1.3570s', 'rf at 1.3575s', 'gz at 1.3595s', 'delay at 1.3600s', 'gz at 1.4100s', 'rf at 1.4105s', 'gz at 1.4125s', 'delay at 1.4130s', 'gz at 1.4630s', 'rf at 1.4635s', 'gz at 1.4655s', 'delay at 1.4660s', 'gz at 1.5160s', 'rf at 1.5165s', 'gz at 1.5185s', 'delay at 1.5190s', 'gz at 1.5690s', 'rf at 1.5695s', 'gz at 1.5715s', 'delay at 1.5720s', 'gz at 1.6220s', 'rf at 1.6225s', 'gz at 1.6245s', 'delay at 1.6250s', 'gz at 1.6750s', 'rf at 1.6755s', 'gz at 1.6775s', 'delay at 1.6780s', 'gz at 1.7280s', 'rf at 1.7285s', 'gz at 1.7305s', 'delay at 1.7310s', 'gz at 1.7810s', 'rf at 1.7815s', 'gz at 1.7835s', 'delay at 1.7840s', 'gz at 1.8340s', 'rf at 1.8345s', 'gz at 1.8365s', 'delay at 1.8370s', 'gz at 1.8870s', 'rf at 1.8875s', 'gz at 1.8895s', 'delay at 1.8900s', 'gz at 1.9400s', 'rf at 1.9405s', 'gz at 1.9425s', 'delay at 1.9430s', 'gz at 1.9930s', 'rf at 1.9935s', 'gz at 1.9955s', 'delay at 1.9960s', 'gz at 2.0460s', 'rf at 2.0465s', 'gz at 2.0485s', 'delay at 2.0490s', 'gz at 2.0990s', 'rf at 2.0995s', 'gz at 2.1015s', 'delay at 2.1020s', 'gz at 2.1520s', 'rf at 2.1525s', 'gz at 2.1545s', 'delay at 2.1550s', 'gz at 2.2050s', 'rf at 2.2055s', 'gz at 2.2075s', 'delay at 2.2080s', 'adc at 2.2580s']
#
# Slice 0:
#   Event: delay at 0.0000s
#   Size: 20.0
#   Time range: 0.0000s - 0.0009s
#   Sample count: 20
#
# Slice 1:
#   Event: rf at 0.0010s
#   Size: 200.0
#   Time range: 0.0010s - 0.0030s
#   Sample count: 200
#
# Slice 2:
#   Event: gz at 0.0030s
#   Size: 200.0
#   Time range: 0.0030s - 0.0035s
#   Sample count: 200
#
# Slice 3:
#   Event: rf at 0.0035s
#   Size: 200.0
#   Time range: 0.0035s - 0.0055s
#   Sample count: 200
#
# Slice 4:
#   Event: delay at 0.0055s
#   Size: 20.0
#   Time range: 0.0055s - 0.0815s
#   Sample count: 20
#
# Slice 5:
#   Event: rf at 0.0855s
#   Size: 200.0
#   Time range: 0.0855s - 0.0875s
#   Sample count: 200
#
# Slice 6:
#   Event: gz at 0.0875s
#   Size: 200.0
#   Time range: 0.0875s - 0.0880s
#   Sample count: 200
#
# Slice 7:
#   Event: delay at 0.0880s
#   Size: 20.0
#   Time range: 0.0880s - 0.1355s
#   Sample count: 20
#
# Slice 8:
#   Event: gz at 0.1380s
#   Size: 200.0
#   Time range: 0.1380s - 0.1385s
#   Sample count: 200
#
# Slice 9:
#   Event: rf at 0.1385s
#   Size: 200.0
#   Time range: 0.1385s - 0.1405s
#   Sample count: 200
#
# Slice 10:
#   Event: gz at 0.1405s
#   Size: 200.0
#   Time range: 0.1405s - 0.1410s
#   Sample count: 200
#
# Slice 11:
#   Event: delay at 0.1410s
#   Size: 20.0
#   Time range: 0.1410s - 0.1885s
#   Sample count: 20
#
# Slice 12:
#   Event: gz at 0.1910s
#   Size: 200.0
#   Time range: 0.1910s - 0.1915s
#   Sample count: 200
#
# Slice 13:
#   Event: rf at 0.1915s
#   Size: 200.0
#   Time range: 0.1915s - 0.1935s
#   Sample count: 200
#
# Slice 14:
#   Event: gz at 0.1935s
#   Size: 200.0
#   Time range: 0.1935s - 0.1940s
#   Sample count: 200
#
# Slice 15:
#   Event: delay at 0.1940s
#   Size: 20.0
#   Time range: 0.1940s - 0.2415s
#   Sample count: 20
#
# Slice 16:
#   Event: gz at 0.2440s
#   Size: 200.0
#   Time range: 0.2440s - 0.2445s
#   Sample count: 200
#
# Slice 17:
#   Event: rf at 0.2445s
#   Size: 200.0
#   Time range: 0.2445s - 0.2465s
#   Sample count: 200
#
# Slice 18:
#   Event: gz at 0.2465s
#   Size: 200.0
#   Time range: 0.2465s - 0.2470s
#   Sample count: 200
#
# Slice 19:
#   Event: delay at 0.2470s
#   Size: 20.0
#   Time range: 0.2470s - 0.2945s
#   Sample count: 20
#
# Slice 20:
#   Event: gz at 0.2970s
#   Size: 200.0
#   Time range: 0.2970s - 0.2975s
#   Sample count: 200
#
# Slice 21:
#   Event: rf at 0.2975s
#   Size: 200.0
#   Time range: 0.2975s - 0.2995s
#   Sample count: 200
#
# Slice 22:
#   Event: gz at 0.2995s
#   Size: 200.0
#   Time range: 0.2995s - 0.3000s
#   Sample count: 200
#
# Slice 23:
#   Event: delay at 0.3000s
#   Size: 20.0
#   Time range: 0.3000s - 0.3475s
#   Sample count: 20
#
# Slice 24:
#   Event: gz at 0.3500s
#   Size: 200.0
#   Time range: 0.3500s - 0.3505s
#   Sample count: 200
#
# Slice 25:
#   Event: rf at 0.3505s
#   Size: 200.0
#   Time range: 0.3505s - 0.3525s
#   Sample count: 200
#
# Slice 26:
#   Event: gz at 0.3525s
#   Size: 200.0
#   Time range: 0.3525s - 0.3530s
#   Sample count: 200
#
# Slice 27:
#   Event: delay at 0.3530s
#   Size: 20.0
#   Time range: 0.3530s - 0.4005s
#   Sample count: 20
#
# Slice 28:
#   Event: gz at 0.4030s
#   Size: 200.0
#   Time range: 0.4030s - 0.4035s
#   Sample count: 200
#
# Slice 29:
#   Event: rf at 0.4035s
#   Size: 200.0
#   Time range: 0.4035s - 0.4055s
#   Sample count: 200
#
# Slice 30:
#   Event: gz at 0.4055s
#   Size: 200.0
#   Time range: 0.4055s - 0.4060s
#   Sample count: 200
#
# Slice 31:
#   Event: delay at 0.4060s
#   Size: 20.0
#   Time range: 0.4060s - 0.4535s
#   Sample count: 20
#
# Slice 32:
#   Event: gz at 0.4560s
#   Size: 200.0
#   Time range: 0.4560s - 0.4565s
#   Sample count: 200
#
# Slice 33:
#   Event: rf at 0.4565s
#   Size: 200.0
#   Time range: 0.4565s - 0.4585s
#   Sample count: 200
#
# Slice 34:
#   Event: gz at 0.4585s
#   Size: 200.0
#   Time range: 0.4585s - 0.4590s
#   Sample count: 200
#
# Slice 35:
#   Event: delay at 0.4590s
#   Size: 20.0
#   Time range: 0.4590s - 0.5065s
#   Sample count: 20
#
# Slice 36:
#   Event: gz at 0.5090s
#   Size: 200.0
#   Time range: 0.5090s - 0.5095s
#   Sample count: 200
#
# Slice 37:
#   Event: rf at 0.5095s
#   Size: 200.0
#   Time range: 0.5095s - 0.5115s
#   Sample count: 200
#
# Slice 38:
#   Event: gz at 0.5115s
#   Size: 200.0
#   Time range: 0.5115s - 0.5120s
#   Sample count: 200
#
# Slice 39:
#   Event: delay at 0.5120s
#   Size: 20.0
#   Time range: 0.5120s - 0.5595s
#   Sample count: 20
#
# Slice 40:
#   Event: gz at 0.5620s
#   Size: 200.0
#   Time range: 0.5620s - 0.5625s
#   Sample count: 200
#
# Slice 41:
#   Event: rf at 0.5625s
#   Size: 200.0
#   Time range: 0.5625s - 0.5645s
#   Sample count: 200
#
# Slice 42:
#   Event: gz at 0.5645s
#   Size: 200.0
#   Time range: 0.5645s - 0.5650s
#   Sample count: 200
#
# Slice 43:
#   Event: delay at 0.5650s
#   Size: 20.0
#   Time range: 0.5650s - 0.6125s
#   Sample count: 20
#
# Slice 44:
#   Event: gz at 0.6150s
#   Size: 200.0
#   Time range: 0.6150s - 0.6155s
#   Sample count: 200
#
# Slice 45:
#   Event: rf at 0.6155s
#   Size: 200.0
#   Time range: 0.6155s - 0.6175s
#   Sample count: 200
#
# Slice 46:
#   Event: gz at 0.6175s
#   Size: 200.0
#   Time range: 0.6175s - 0.6180s
#   Sample count: 200
#
# Slice 47:
#   Event: delay at 0.6180s
#   Size: 20.0
#   Time range: 0.6180s - 0.6655s
#   Sample count: 20
#
# Slice 48:
#   Event: gz at 0.6680s
#   Size: 200.0
#   Time range: 0.6680s - 0.6685s
#   Sample count: 200
#
# Slice 49:
#   Event: rf at 0.6685s
#   Size: 200.0
#   Time range: 0.6685s - 0.6705s
#   Sample count: 200
#
# Slice 50:
#   Event: gz at 0.6705s
#   Size: 200.0
#   Time range: 0.6705s - 0.6710s
#   Sample count: 200
#
# Slice 51:
#   Event: delay at 0.6710s
#   Size: 20.0
#   Time range: 0.6710s - 0.7185s
#   Sample count: 20
#
# Slice 52:
#   Event: gz at 0.7210s
#   Size: 200.0
#   Time range: 0.7210s - 0.7215s
#   Sample count: 200
#
# Slice 53:
#   Event: rf at 0.7215s
#   Size: 200.0
#   Time range: 0.7215s - 0.7235s
#   Sample count: 200
#
# Slice 54:
#   Event: gz at 0.7235s
#   Size: 200.0
#   Time range: 0.7235s - 0.7240s
#   Sample count: 200
#
# Slice 55:
#   Event: delay at 0.7240s
#   Size: 20.0
#   Time range: 0.7240s - 0.7715s
#   Sample count: 20
#
# Slice 56:
#   Event: gz at 0.7740s
#   Size: 200.0
#   Time range: 0.7740s - 0.7745s
#   Sample count: 200
#
# Slice 57:
#   Event: rf at 0.7745s
#   Size: 200.0
#   Time range: 0.7745s - 0.7765s
#   Sample count: 200
#
# Slice 58:
#   Event: gz at 0.7765s
#   Size: 200.0
#   Time range: 0.7765s - 0.7770s
#   Sample count: 200
#
# Slice 59:
#   Event: delay at 0.7770s
#   Size: 20.0
#   Time range: 0.7770s - 0.8245s
#   Sample count: 20
#
# Slice 60:
#   Event: gz at 0.8270s
#   Size: 200.0
#   Time range: 0.8270s - 0.8275s
#   Sample count: 200
#
# Slice 61:
#   Event: rf at 0.8275s
#   Size: 200.0
#   Time range: 0.8275s - 0.8295s
#   Sample count: 200
#
# Slice 62:
#   Event: gz at 0.8295s
#   Size: 200.0
#   Time range: 0.8295s - 0.8300s
#   Sample count: 200
#
# Slice 63:
#   Event: delay at 0.8300s
#   Size: 20.0
#   Time range: 0.8300s - 0.8775s
#   Sample count: 20
#
# Slice 64:
#   Event: gz at 0.8800s
#   Size: 200.0
#   Time range: 0.8800s - 0.8805s
#   Sample count: 200
#
# Slice 65:
#   Event: rf at 0.8805s
#   Size: 200.0
#   Time range: 0.8805s - 0.8825s
#   Sample count: 200
#
# Slice 66:
#   Event: gz at 0.8825s
#   Size: 200.0
#   Time range: 0.8825s - 0.8830s
#   Sample count: 200
#
# Slice 67:
#   Event: delay at 0.8830s
#   Size: 20.0
#   Time range: 0.8830s - 0.9305s
#   Sample count: 20
#
# Slice 68:
#   Event: gz at 0.9330s
#   Size: 200.0
#   Time range: 0.9330s - 0.9335s
#   Sample count: 200
#
# Slice 69:
#   Event: rf at 0.9335s
#   Size: 200.0
#   Time range: 0.9335s - 0.9355s
#   Sample count: 200
#
# Slice 70:
#   Event: gz at 0.9355s
#   Size: 200.0
#   Time range: 0.9355s - 0.9360s
#   Sample count: 200
#
# Slice 71:
#   Event: delay at 0.9360s
#   Size: 20.0
#   Time range: 0.9360s - 0.9835s
#   Sample count: 20
#
# Slice 72:
#   Event: gz at 0.9860s
#   Size: 200.0
#   Time range: 0.9860s - 0.9865s
#   Sample count: 200
#
# Slice 73:
#   Event: rf at 0.9865s
#   Size: 200.0
#   Time range: 0.9865s - 0.9885s
#   Sample count: 200
#
# Slice 74:
#   Event: gz at 0.9885s
#   Size: 200.0
#   Time range: 0.9885s - 0.9890s
#   Sample count: 200
#
# Slice 75:
#   Event: delay at 0.9890s
#   Size: 20.0
#   Time range: 0.9890s - 1.0365s
#   Sample count: 20
#
# Slice 76:
#   Event: gz at 1.0390s
#   Size: 200.0
#   Time range: 1.0390s - 1.0395s
#   Sample count: 200
#
# Slice 77:
#   Event: rf at 1.0395s
#   Size: 200.0
#   Time range: 1.0395s - 1.0415s
#   Sample count: 200
#
# Slice 78:
#   Event: gz at 1.0415s
#   Size: 200.0
#   Time range: 1.0415s - 1.0420s
#   Sample count: 200
#
# Slice 79:
#   Event: delay at 1.0420s
#   Size: 20.0
#   Time range: 1.0420s - 1.0895s
#   Sample count: 20
#
# Slice 80:
#   Event: gz at 1.0920s
#   Size: 200.0
#   Time range: 1.0920s - 1.0925s
#   Sample count: 200
#
# Slice 81:
#   Event: rf at 1.0925s
#   Size: 200.0
#   Time range: 1.0925s - 1.0945s
#   Sample count: 200
#
# Slice 82:
#   Event: gz at 1.0945s
#   Size: 200.0
#   Time range: 1.0945s - 1.0950s
#   Sample count: 200
#
# Slice 83:
#   Event: delay at 1.0950s
#   Size: 20.0
#   Time range: 1.0950s - 1.1425s
#   Sample count: 20
#
# Slice 0:
#   Event: delay at 0.0000s
#
# Slice 84:
#   Event: gz at 1.1450s
#   Size: 20.0  Size: 200.0
#
#   Time range: 1.1450s - 1.1455s
#   Sample count: 200
#
# Slice 85:
#   Time range: 0.0000s - 0.0009s
#   Event: rf at 1.1455s
#   Size: 200.0
#   Sample count: 20
#   Time range: 1.1455s - 1.1475s
#   Sample count: 200
#
# Slice 1:
# Slice 86:
#
#   Event: gz at 1.1475s
#   Size: 200.0
#   Time range: 1.1475s - 1.1480s
#   Sample count: 200
#
# Slice 87:
#   Event: delay at 1.1480s
#   Size: 20.0
#   Time range: 1.1480s - 1.1955s
#   Sample count: 20
#
# Slice 88:
#   Event: rf at 0.0010s  Event: gz at 1.1980s
#   Size: 200.0
#
#   Time range: 1.1980s - 1.1985s
#   Sample count: 200
#   Size: 200.0
#
# Slice 89:
#   Event: rf at 1.1985s
#   Size: 200.0
#   Time range: 1.1985s - 1.2005s
#   Sample count: 200
#
# Slice 90:
#   Event: gz at 1.2005s
#   Size: 200.0
#   Time range: 1.2005s - 1.2010s
#   Sample count: 200
#
# Slice 91:
#   Event: delay at 1.2010s
#   Size: 20.0
#   Time range: 1.2010s - 1.2485s
#   Sample count: 20
#
# Slice 92:
#   Time range: 0.0010s - 0.0030s  Event: gz at 1.2510s
#   Size: 200.0
#   Sample count: 200
#
#
# Slice 2:  Time range: 1.2510s - 1.2515s
#
#   Event: gz at 0.0030s
#   Sample count: 200  Size: 200.0
#
#   Time range: 0.0030s - 0.0035s
#   Sample count: 200
#
# Slice 93:
# Slice 3:
#   Event: rf at 0.0035s
#   Size: 200.0
#   Time range: 0.0035s - 0.0055s
#
#   Sample count: 200  Event: rf at 1.2515s
#
#   Size: 200.0
#
# Slice 4:
#   Event: delay at 0.0055s
#   Size: 20.0
#   Time range: 1.2515s - 1.2535s  Time range: 0.0055s - 0.0815s
#   Sample count: 20
#
#   Sample count: 200
#
# Slice 5:
#   Event: rf at 0.0855s
#   Size: 200.0
#   Time range: 0.0855s - 0.0875s
#
# Slice 94:
#   Sample count: 200
#   Event: gz at 1.2535s
#   Size: 200.0
#
# Slice 6:  Time range: 1.2535s - 1.2540s
#
#   Event: gz at 0.0875s
#   Sample count: 200
#   Size: 200.0
#   Time range: 0.0875s - 0.0880s
#   Sample count: 200
#
# Slice 95:
#   Event: delay at 1.2540s
#   Size: 20.0
#   Time range: 1.2540s - 1.3015s
#   Sample count: 20
#
# Slice 96:
#   Event: gz at 1.3040s
#   Size: 200.0
#   Time range: 1.3040s - 1.3045s
#   Sample count: 200
#
# Slice 97:
#   Event: rf at 1.3045s
#   Size: 200.0
#
# Slice 7:
#   Event: delay at 0.0880s
#   Time range: 1.3045s - 1.3065s
#   Size: 20.0  Sample count: 200
#
#   Time range: 0.0880s - 0.1355s
#   Sample count: 20
# Slice 98:
#
#   Event: gz at 1.3065s
#   Size: 200.0
#   Time range: 1.3065s - 1.3070s
# Slice 8:
#   Event: gz at 0.1380s
#   Size: 200.0
#   Time range: 0.1380s - 0.1385s
#   Sample count: 200
#
#
# Slice 9:
#   Event: rf at 0.1385s
#   Size: 200.0  Sample count: 200
#
#   Time range: 0.1385s - 0.1405s
#   Sample count: 200
#
# Slice 99:
#   Event: delay at 1.3070s
#
# Slice 10:
#   Event: gz at 0.1405s  Size: 20.0
#
#   Size: 200.0
#   Time range: 1.3070s - 1.3545s  Time range: 0.1405s - 0.1410s
#   Sample count: 200
#
# Slice 11:
#
#   Event: delay at 0.1410s
#   Size: 20.0
#   Sample count: 20
#   Time range: 0.1410s - 0.1885s
# Slice 100:
#   Event: gz at 1.3570s
#
#   Size: 200.0
#   Sample count: 20
#   Time range: 1.3570s - 1.3575s
#   Sample count: 200
#
# Slice 101:
#   Event: rf at 1.3575s
#   Size: 200.0
#   Time range: 1.3575s - 1.3595s
#   Sample count: 200
#
# Slice 12:
#   Event: gz at 0.1910s
#
# Slice 102:
#   Size: 200.0
#   Event: gz at 1.3595s
#   Size: 200.0
#   Time range: 0.1910s - 0.1915s
#   Time range: 1.3595s - 1.3600s
#   Sample count: 200
#   Sample count: 200
#
# Slice 103:
# Slice 13:
#
#   Event: delay at 1.3600s  Event: rf at 0.1915s
#
#   Size: 20.0
#   Size: 200.0
#   Time range: 1.3600s - 1.4075s
#   Sample count: 20
#   Time range: 0.1915s - 0.1935s
# Slice 104:
#
#   Event: gz at 1.4100s
#   Sample count: 200
#   Size: 200.0
#
# Slice 14:
#   Time range: 1.4100s - 1.4105s  Event: gz at 0.1935s
#
#   Sample count: 200
#   Size: 200.0
#
# Slice 105:
#   Event: rf at 1.4105s
#   Time range: 0.1935s - 0.1940s
#   Size: 200.0
#   Time range: 1.4105s - 1.4125s
#   Sample count: 200
#   Sample count: 200
#
# Slice 106:
#   Event: gz at 1.4125s
#   Size: 200.0
#
# Slice 15:  Time range: 1.4125s - 1.4130s
#   Sample count: 200
#
#   Event: delay at 0.1940s
#   Size: 20.0
# Slice 107:
#
#   Event: delay at 1.4130s
#   Size: 20.0
#   Time range: 0.1940s - 0.2415s
#   Sample count: 20  Time range: 1.4130s - 1.4605s
#
#   Sample count: 20
#
# Slice 108:
#   Event: gz at 1.4630s
#   Size: 200.0
#
# Slice 16:
#   Event: gz at 0.2440s
#   Time range: 1.4630s - 1.4635s
#   Size: 200.0
#   Sample count: 200
#   Time range: 0.2440s - 0.2445s
#   Sample count: 200
#
# Slice 17:
#   Event: rf at 0.2445s
#   Size: 200.0
#
# Slice 109:
#   Event: rf at 1.4635s
#   Size: 200.0  Time range: 0.2445s - 0.2465s
#
#   Sample count: 200
#   Time range: 1.4635s - 1.4655s
#   Sample count: 200
#
# Slice 110:
#   Event: gz at 1.4655s
#   Size: 200.0
#
# Slice 18:
#   Event: gz at 0.2465s  Time range: 1.4655s - 1.4660s
#
#   Sample count: 200  Size: 200.0
#
#
# Slice 111:
#   Event: delay at 1.4660s
#   Size: 20.0
#   Time range: 0.2465s - 0.2470s
#   Sample count: 200
#   Time range: 1.4660s - 1.5135s
#   Sample count: 20
#
# Slice 19:
# Slice 112:
#
#   Event: delay at 0.2470s
#   Size: 20.0
#   Event: gz at 1.5160s
#   Size: 200.0
#   Time range: 0.2470s - 0.2945s
#   Sample count: 20
#   Time range: 1.5160s - 1.5165s
#   Sample count: 200
#
# Slice 20:
#   Event: gz at 0.2970s
# Slice 113:
#
#   Event: rf at 1.5165s  Size: 200.0
#
#   Size: 200.0
#   Time range: 0.2970s - 0.2975s
#   Time range: 1.5165s - 1.5185s
#   Sample count: 200
#   Sample count: 200
#
# Slice 21:
#   Event: rf at 0.2975s
#   Size: 200.0
#   Time range: 0.2975s - 0.2995s
#   Sample count: 200
#
# Slice 114:
#   Event: gz at 1.5185s
#   Size: 200.0
#
# Slice 22:
#   Event: gz at 0.2995s
#   Size: 200.0
#   Time range: 1.5185s - 1.5190s
#   Sample count: 200
#
# Slice 115:
#   Event: delay at 1.5190s
#   Size: 20.0
#   Time range: 0.2995s - 0.3000s
#   Sample count: 200
#   Time range: 1.5190s - 1.5665s
#   Sample count: 20
#
# Slice 23:
#   Event: delay at 0.3000s
#   Size: 20.0
#
# Slice 116:  Time range: 0.3000s - 0.3475s
#
#   Event: gz at 1.5690s
#   Sample count: 20
#   Size: 200.0
#   Time range: 1.5690s - 1.5695s
#
# Slice 24:
#   Event: gz at 0.3500s
#   Size: 200.0
#   Sample count: 200  Time range: 0.3500s - 0.3505s
#
#   Sample count: 200
#
# Slice 25:
#   Event: rf at 0.3505s
# Slice 117:
#
#   Event: rf at 1.5695s  Size: 200.0
#
#   Size: 200.0
#   Time range: 0.3505s - 0.3525s
#   Time range: 1.5695s - 1.5715s
#   Sample count: 200
#   Sample count: 200
#
# Slice 118:
#   Event: gz at 1.5715s
#   Size: 200.0
#   Time range: 1.5715s - 1.5720s
#   Sample count: 200
#
# Slice 26:
#   Event: gz at 0.3525s
#
# Slice 119:  Size: 200.0
#
#   Event: delay at 1.5720s
#   Size: 20.0
#   Time range: 1.5720s - 1.6195s
#   Sample count: 20
#   Time range: 0.3525s - 0.3530s
#
# Slice 120:  Sample count: 200
#
#   Event: gz at 1.6220s
#   Size: 200.0
#
# Slice 27:
#   Event: delay at 0.3530s
#   Time range: 1.6220s - 1.6225s  Size: 20.0
#
#   Sample count: 200
#   Time range: 0.3530s - 0.4005s
#   Sample count: 20
#
# Slice 121:
#   Event: rf at 1.6225s
#   Size: 200.0
#
# Slice 28:
#   Event: gz at 0.4030s  Time range: 1.6225s - 1.6245s
#
#   Size: 200.0  Sample count: 200
#
#   Time range: 0.4030s - 0.4035s
#   Sample count: 200
# Slice 122:
#
#   Event: gz at 1.6245s
#   Size: 200.0
#
# Slice 29:
#   Time range: 1.6245s - 1.6250s  Event: rf at 0.4035s
#
#   Sample count: 200
#   Size: 200.0
#   Time range: 0.4035s - 0.4055s
#
# Slice 123:  Sample count: 200
#
#   Event: delay at 1.6250s
#   Size: 20.0
#   Time range: 1.6250s - 1.6725s
# Slice 30:
#
#   Event: gz at 0.4055s  Sample count: 20
#
#   Size: 200.0
#   Time range: 0.4055s - 0.4060s
#
# Slice 124:
#   Sample count: 200  Event: gz at 1.6750s
#
#   Size: 200.0
#
# Slice 31:
#   Event: delay at 0.4060s
#   Size: 20.0
#   Time range: 0.4060s - 0.4535s
#   Sample count: 20
#
# Slice 32:
#   Event: gz at 0.4560s
#   Size: 200.0
#   Time range: 1.6750s - 1.6755s
#   Time range: 0.4560s - 0.4565s  Sample count: 200
#
#   Sample count: 200
#
# Slice 33:
#
# Slice 125:
#   Event: rf at 1.6755s
#   Size: 200.0  Event: rf at 0.4565s
#
#   Size: 200.0
#   Time range: 1.6755s - 1.6775s
#   Time range: 0.4565s - 0.4585s
#   Sample count: 200  Sample count: 200
#
#
# Slice 126:
#   Event: gz at 1.6775s
#   Size: 200.0
# Slice 34:
#   Event: gz at 0.4585s
#   Size: 200.0
#   Time range: 0.4585s - 0.4590s
#   Sample count: 200
#
#   Time range: 1.6775s - 1.6780s
#
# Slice 35:  Sample count: 200
#
#   Event: delay at 0.4590s
#   Size: 20.0
#   Time range: 0.4590s - 0.5065s
# Slice 127:
#   Event: delay at 1.6780s
#   Size: 20.0
#
#   Time range: 1.6780s - 1.7255s
#   Sample count: 20  Sample count: 20
#
#
# Slice 128:
#   Event: gz at 1.7280s
#
# Slice 36:  Size: 200.0
#
#   Event: gz at 0.5090s
#   Size: 200.0
#   Time range: 1.7280s - 1.7285s
#   Time range: 0.5090s - 0.5095s
#   Sample count: 200
#   Sample count: 200
#
# Slice 129:
#   Event: rf at 1.7285s
#   Size: 200.0
#   Time range: 1.7285s - 1.7305s
#   Sample count: 200
#
# Slice 130:
#   Event: gz at 1.7305s
#   Size: 200.0
#   Time range: 1.7305s - 1.7310s
#   Sample count: 200
#
# Slice 131:
#   Event: delay at 1.7310s
#   Size: 20.0
#   Time range: 1.7310s - 1.7785s
#   Sample count: 20
#
# Slice 37:
#   Event: rf at 0.5095s
# Slice 132:
#
#   Event: gz at 1.7810s
#   Size: 200.0
#   Size: 200.0
#   Time range: 0.5095s - 0.5115s
#   Sample count: 200  Time range: 1.7810s - 1.7815s
#
#   Sample count: 200
#
# Slice 133:
#   Event: rf at 1.7815s
#
# Slice 38:  Size: 200.0
#   Event: gz at 0.5115s
#   Size: 200.0
#   Time range: 0.5115s - 0.5120s
#   Sample count: 200
#
#
# Slice 39:
#   Event: delay at 0.5120s
#   Size: 20.0
#   Time range: 0.5120s - 0.5595s
#   Sample count: 20
#
# Slice 40:
#   Event: gz at 0.5620s
#   Size: 200.0
#   Time range: 1.7815s - 1.7835s
#   Sample count: 200
#   Time range: 0.5620s - 0.5625s
#   Sample count: 200
#
# Slice 134:
#   Event: gz at 1.7835s
#
# Slice 41:
#   Size: 200.0  Event: rf at 0.5625s
#
#   Size: 200.0
#   Time range: 1.7835s - 1.7840s
#   Sample count: 200  Time range: 0.5625s - 0.5645s
#
#   Sample count: 200
#
# Slice 42:
#   Event: gz at 0.5645s
#
# Slice 135:
#   Size: 200.0  Event: delay at 1.7840s
#   Size: 20.0
#   Time range: 1.7840s - 1.8315s
#
#   Sample count: 20
#
# Slice 136:
#   Event: gz at 1.8340s
#   Size: 200.0
#   Time range: 0.5645s - 0.5650s
#   Time range: 1.8340s - 1.8345s  Sample count: 200
#
#   Sample count: 200
#
# Slice 137:
#   Event: rf at 1.8345s
#   Size: 200.0
#
# Slice 43:
#   Event: delay at 0.5650s
#   Time range: 1.8345s - 1.8365s
#   Size: 20.0  Sample count: 200
#
#   Time range: 0.5650s - 0.6125s
#   Sample count: 20
# Slice 138:
#
#   Event: gz at 1.8365s
#   Size: 200.0
#   Time range: 1.8365s - 1.8370s
#   Sample count: 200
#
# Slice 44:
#   Event: gz at 0.6150s
#   Size: 200.0
#
# Slice 139:  Time range: 0.6150s - 0.6155s
#   Event: delay at 1.8370s
#
#   Size: 20.0
#   Sample count: 200
#   Time range: 1.8370s - 1.8845s
#   Sample count: 20
#
# Slice 45:
#   Event: rf at 0.6155s
#   Size: 200.0
#
# Slice 140:
#   Event: gz at 1.8870s
#   Time range: 0.6155s - 0.6175s  Size: 200.0
#
#   Sample count: 200
#   Time range: 1.8870s - 1.8875s
#   Sample count: 200
#
# Slice 46:
#   Event: gz at 0.6175s
#   Size: 200.0
#
# Slice 141:
#   Event: rf at 1.8875s
#   Time range: 0.6175s - 0.6180s
#   Size: 200.0  Sample count: 200
#
#   Time range: 1.8875s - 1.8895s
#   Sample count: 200
#
# Slice 47:
#   Event: delay at 0.6180s
# Slice 142:
#   Size: 20.0
#
#   Event: gz at 1.8895s
#   Size: 200.0
#   Time range: 1.8895s - 1.8900s  Time range: 0.6180s - 0.6655s
#   Sample count: 20
#
#   Sample count: 200
#
# Slice 143:
#   Event: delay at 1.8900s
#   Size: 20.0
#
# Slice 48:
#   Time range: 1.8900s - 1.9375s
#   Sample count: 20
#   Event: gz at 0.6680s
# Slice 144:
#
#   Event: gz at 1.9400s
#   Size: 200.0
#   Time range: 1.9400s - 1.9405s
#   Sample count: 200
#
# Slice 145:
#   Event: rf at 1.9405s
#   Size: 200.0
#   Time range: 1.9405s - 1.9425s
#   Sample count: 200
#
# Slice 146:
#   Event: gz at 1.9425s
#   Size: 200.0
#   Time range: 1.9425s - 1.9430s
#   Size: 200.0  Sample count: 200
#
#
# Slice 147:
#   Event: delay at 1.9430s  Time range: 0.6680s - 0.6685s
#
#   Size: 20.0
#   Sample count: 200
#   Time range: 1.9430s - 1.9905s
#   Sample count: 20
#
# Slice 148:
# Slice 49:
#   Event: rf at 0.6685s
#
#   Event: gz at 1.9930s  Size: 200.0
#
#   Size: 200.0
#   Time range: 0.6685s - 0.6705s
#   Time range: 1.9930s - 1.9935s  Sample count: 200
#
#   Sample count: 200
#
# Slice 50:
#   Event: gz at 0.6705s
# Slice 149:
#
#   Event: rf at 1.9935s
#   Size: 200.0
#   Size: 200.0
#   Time range: 0.6705s - 0.6710s
#   Time range: 1.9935s - 1.9955s
#   Sample count: 200
#   Sample count: 200
#
# Slice 150:
# Slice 51:
#
#   Event: gz at 1.9955s  Event: delay at 0.6710s
#
#   Size: 200.0  Size: 20.0
#
#   Time range: 1.9955s - 1.9960s  Time range: 0.6710s - 0.7185s
#
#   Sample count: 200  Sample count: 20
#
#
# Slice 151:
#
# Slice 52:  Event: delay at 1.9960s
#
#   Event: gz at 0.7210s
#   Size: 20.0
#   Size: 200.0
#   Time range: 1.9960s - 2.0435s
#   Time range: 0.7210s - 0.7215s
#   Sample count: 20
#   Sample count: 200
#
# Slice 152:
#   Event: gz at 2.0460s
#
# Slice 53:
#   Size: 200.0  Event: rf at 0.7215s
#
#   Size: 200.0
#   Time range: 2.0460s - 2.0465s
#   Sample count: 200
#   Time range: 0.7215s - 0.7235s
#
# Slice 153:
#   Event: rf at 2.0465s  Sample count: 200
#
#   Size: 200.0
#
# Slice 54:
#   Time range: 2.0465s - 2.0485s
#   Sample count: 200
#   Event: gz at 0.7235s
#   Size: 200.0
#
# Slice 154:
#   Event: gz at 2.0485s
#   Time range: 0.7235s - 0.7240s
#   Size: 200.0
#   Sample count: 200
#
# Slice 55:  Time range: 2.0485s - 2.0490s
#
#   Event: delay at 0.7240s
#   Sample count: 200
#   Size: 20.0
#   Time range: 0.7240s - 0.7715s
#   Sample count: 20
# Slice 155:
#
#   Event: delay at 2.0490s
#   Size: 20.0
#
# Slice 56:  Time range: 2.0490s - 2.0965s
#   Sample count: 20
#
#   Event: gz at 0.7740s
#   Size: 200.0
#
# Slice 156:
#   Event: gz at 2.0990s
#   Time range: 0.7740s - 0.7745s  Size: 200.0
#
#   Sample count: 200
#   Time range: 2.0990s - 2.0995s
#   Sample count: 200
#
# Slice 57:
#   Event: rf at 0.7745s
#   Size: 200.0
#
# Slice 157:
#   Event: rf at 2.0995s
#   Time range: 0.7745s - 0.7765s  Size: 200.0
#
#   Sample count: 200
#   Time range: 2.0995s - 2.1015s
#   Sample count: 200
#
# Slice 58:
#   Event: gz at 0.7765s
#   Size: 200.0
#
# Slice 158:
#   Time range: 0.7765s - 0.7770s
#   Sample count: 200
#
# Slice 59:
#   Event: delay at 0.7770s
#   Event: gz at 2.1015s  Size: 20.0
#
#   Time range: 0.7770s - 0.8245s
#   Size: 200.0
#   Sample count: 20
#   Time range: 2.1015s - 2.1020s
#
# Slice 60:
#   Sample count: 200  Event: gz at 0.8270s
#
#   Size: 200.0
#   Time range: 0.8270s - 0.8275s
#   Sample count: 200
#
# Slice 61:
#   Event: rf at 0.8275s
# Slice 159:
#
#   Size: 200.0  Event: delay at 2.1020s
#
#   Size: 20.0
#   Time range: 0.8275s - 0.8295s
#   Sample count: 200
#   Time range: 2.1020s - 2.1495s
#   Sample count: 20
#
# Slice 62:
#   Event: gz at 0.8295s
#   Size: 200.0
#   Time range: 0.8295s - 0.8300s
#
# Slice 160:
#   Sample count: 200  Event: gz at 2.1520s
#   Size: 200.0
#
#   Time range: 2.1520s - 2.1525s
#   Sample count: 200
# Slice 63:
#
#   Event: delay at 0.8300s
#   Size: 20.0
#   Time range: 0.8300s - 0.8775s
# Slice 161:
#
#   Event: rf at 2.1525s
#   Size: 200.0
#   Sample count: 20
#   Time range: 2.1525s - 2.1545s
#   Sample count: 200
#
# Slice 64:
#   Event: gz at 0.8800s
#   Size: 200.0
#
# Slice 162:
#   Event: gz at 2.1545s
#   Time range: 0.8800s - 0.8805s
#   Size: 200.0  Sample count: 200
#
#   Time range: 2.1545s - 2.1550s
#   Sample count: 200
#
# Slice 65:
#   Event: rf at 0.8805s
#
# Slice 163:  Size: 200.0
#
#   Event: delay at 2.1550s
#   Size: 20.0
#   Time range: 0.8805s - 0.8825s
#   Sample count: 200  Time range: 2.1550s - 2.2025s
#
#   Sample count: 20
#
# Slice 66:
#   Event: gz at 0.8825s
#
# Slice 164:
#   Size: 200.0
#   Event: gz at 2.2050s
#   Size: 200.0
#   Time range: 2.2050s - 2.2055s
#   Time range: 0.8825s - 0.8830s
#   Sample count: 200
#   Sample count: 200
#
# Slice 165:
#
# Slice 67:  Event: rf at 2.2055s
#
#   Event: delay at 0.8830s
#   Size: 200.0
#   Size: 20.0
#   Time range: 2.2055s - 2.2075s
#   Time range: 0.8830s - 0.9305s  Sample count: 200
#
#   Sample count: 20
#
# Slice 166:
#   Event: gz at 2.2075s
#   Size: 200.0
#
# Slice 68:
#   Event: gz at 0.9330s
#   Time range: 2.2075s - 2.2080s
#   Size: 200.0
#   Sample count: 200
#   Time range: 0.9330s - 0.9335s
#   Sample count: 200
#
# Slice 167:
#   Event: delay at 2.2080s
#   Size: 20.0
#
# Slice 69:
#   Event: rf at 0.9335s
#   Time range: 2.2080s - 2.2555s  Size: 200.0
#
#   Sample count: 20
#   Time range: 0.9335s - 0.9355s
#   Sample count: 200
#
# Slice 70:
#   Event: gz at 0.9355s
#   Size: 200.0
#   Time range: 0.9355s - 0.9360s
#   Sample count: 200
#
# Slice 71:
#   Event: delay at 0.9360s
#   Size: 20.0
#   Time range: 0.9360s - 0.9835s
#   Sample count: 20
#
# Slice 72:
#   Event: gz at 0.9860s
#   Size: 200.0
#   Time range: 0.9860s - 0.9865s
#   Sample count: 200
#
# Slice 73:
#   Event: rf at 0.9865s
#   Size: 200.0
#   Time range: 0.9865s - 0.9885s
#   Sample count: 200
#
# Slice 74:
#   Event: gz at 0.9885s
#   Size: 200.0
#   Time range: 0.9885s - 0.9890s
#   Sample count: 200
#
# Slice 75:
#   Event: delay at 0.9890s
#   Size: 20.0
#   Time range: 0.9890s - 1.0365s
#   Sample count: 20
#
# Slice 76:
#   Event: gz at 1.0390s
#   Size: 200.0
#   Time range: 1.0390s - 1.0395s
#   Sample count: 200
#
# Slice 77:
#   Event: rf at 1.0395s
#   Size: 200.0
#   Time range: 1.0395s - 1.0415s
#   Sample count: 200
#
# Slice 78:
#   Event: gz at 1.0415s
#   Size: 200.0
#   Time range: 1.0415s - 1.0420s
#   Sample count: 200
#
# Slice 79:
#   Event: delay at 1.0420s
#   Size: 20.0
#   Time range: 1.0420s - 1.0895s
#   Sample count: 20
#
# Slice 80:
#   Event: gz at 1.0920s
#   Size: 200.0
#   Time range: 1.0920s - 1.0925s
#   Sample count: 200
#
# Slice 81:
#   Event: rf at 1.0925s
#   Size: 200.0
#   Time range: 1.0925s - 1.0945s
#   Sample count: 200
#
# Slice 82:
#   Event: gz at 1.0945s
#   Size: 200.0
#   Time range: 1.0945s - 1.0950s
#   Sample count: 200
#
# Slice 83:
#   Event: delay at 1.0950s
#   Size: 20.0
#   Time range: 1.0950s - 1.1425s
#   Sample count: 20
#
# Slice 84:
#   Event: gz at 1.1450s
#   Size: 200.0
#   Time range: 1.1450s - 1.1455s
#   Sample count: 200
#
# Slice 85:
#   Event: rf at 1.1455s
#   Size: 200.0
#   Time range: 1.1455s - 1.1475s
#   Sample count: 200
#
# Slice 86:
#   Event: gz at 1.1475s
#   Size: 200.0
#   Time range: 1.1475s - 1.1480s
#   Sample count: 200
#
# Slice 87:
#   Event: delay at 1.1480s
#   Size: 20.0
#   Time range: 1.1480s - 1.1955s
#   Sample count: 20
#
# Slice 88:
#   Event: gz at 1.1980s
#   Size: 200.0
#   Time range: 1.1980s - 1.1985s
#   Sample count: 200
#
# Slice 89:
#   Event: rf at 1.1985s
#   Size: 200.0
#   Time range: 1.1985s - 1.2005s
#   Sample count: 200
#
# Slice 90:
#   Event: gz at 1.2005s
#   Size: 200.0
#   Time range: 1.2005s - 1.2010s
#   Sample count: 200
#
# Slice 91:
#   Event: delay at 1.2010s
#   Size: 20.0
#   Time range: 1.2010s - 1.2485s
#   Sample count: 20
#
# Slice 92:
#   Event: gz at 1.2510s
#   Size: 200.0
#   Time range: 1.2510s - 1.2515s
#   Sample count: 200
#
# Slice 93:
#   Event: rf at 1.2515s
#   Size: 200.0
#   Time range: 1.2515s - 1.2535s
#   Sample count: 200
#
# Slice 94:
#   Event: gz at 1.2535s
#   Size: 200.0
#   Time range: 1.2535s - 1.2540s
#   Sample count: 200
#
# Slice 95:
#   Event: delay at 1.2540s
#   Size: 20.0
#   Time range: 1.2540s - 1.3015s
#   Sample count: 20
#
# Slice 96:
#   Event: gz at 1.3040s
#   Size: 200.0
#   Time range: 1.3040s - 1.3045s
#   Sample count: 200
#
# Slice 97:
#   Event: rf at 1.3045s
#   Size: 200.0
#   Time range: 1.3045s - 1.3065s
#   Sample count: 200
#
# Slice 98:
#   Event: gz at 1.3065s
#   Size: 200.0
#   Time range: 1.3065s - 1.3070s
#   Sample count: 200
#
# Slice 99:
#   Event: delay at 1.3070s
#   Size: 20.0
#   Time range: 1.3070s - 1.3545s
#   Sample count: 20
#
# Slice 100:
#   Event: gz at 1.3570s
#   Size: 200.0
#   Time range: 1.3570s - 1.3575s
#   Sample count: 200
#
# Slice 101:
#   Event: rf at 1.3575s
#   Size: 200.0
#   Time range: 1.3575s - 1.3595s
#   Sample count: 200
#
# Slice 102:
#   Event: gz at 1.3595s
#   Size: 200.0
#   Time range: 1.3595s - 1.3600s
#   Sample count: 200
#
# Slice 103:
#   Event: delay at 1.3600s
#   Size: 20.0
#   Time range: 1.3600s - 1.4075s
#   Sample count: 20
#
# Slice 104:
#   Event: gz at 1.4100s
#   Size: 200.0
#   Time range: 1.4100s - 1.4105s
#   Sample count: 200
#
# Slice 105:
#   Event: rf at 1.4105s
#   Size: 200.0
#   Time range: 1.4105s - 1.4125s
#   Sample count: 200
#
# Slice 106:
#   Event: gz at 1.4125s
#   Size: 200.0
#   Time range: 1.4125s - 1.4130s
#   Sample count: 200
#
# Slice 107:
#   Event: delay at 1.4130s
#   Size: 20.0
#   Time range: 1.4130s - 1.4605s
#   Sample count: 20
#
# Slice 108:
#   Event: gz at 1.4630s
#   Size: 200.0
#   Time range: 1.4630s - 1.4635s
#   Sample count: 200
#
# Slice 109:
#   Event: rf at 1.4635s
#   Size: 200.0
#   Time range: 1.4635s - 1.4655s
#   Sample count: 200
#
# Slice 110:
#   Event: gz at 1.4655s
#   Size: 200.0
#   Time range: 1.4655s - 1.4660s
#   Sample count: 200
#
# Slice 111:
#   Event: delay at 1.4660s
#   Size: 20.0
#   Time range: 1.4660s - 1.5135s
#   Sample count: 20
#
# Slice 112:
#   Event: gz at 1.5160s
#   Size: 200.0
#   Time range: 1.5160s - 1.5165s
#   Sample count: 200
#
# Slice 113:
#   Event: rf at 1.5165s
#   Size: 200.0
#   Time range: 1.5165s - 1.5185s
#   Sample count: 200
#
# Slice 114:
#   Event: gz at 1.5185s
#   Size: 200.0
#   Time range: 1.5185s - 1.5190s
#   Sample count: 200
#
# Slice 115:
#   Event: delay at 1.5190s
#   Size: 20.0
#   Time range: 1.5190s - 1.5665s
#   Sample count: 20
#
# Slice 116:
#   Event: gz at 1.5690s
#   Size: 200.0
#   Time range: 1.5690s - 1.5695s
#   Sample count: 200
#
# Slice 117:
#   Event: rf at 1.5695s
#   Size: 200.0
#   Time range: 1.5695s - 1.5715s
#   Sample count: 200
#
# Slice 118:
#   Event: gz at 1.5715s
#   Size: 200.0
#   Time range: 1.5715s - 1.5720s
#   Sample count: 200
#
# Slice 119:
#   Event: delay at 1.5720s
#   Size: 20.0
#   Time range: 1.5720s - 1.6195s
#   Sample count: 20
#
# Slice 120:
#   Event: gz at 1.6220s
#   Size: 200.0
#   Time range: 1.6220s - 1.6225s
#   Sample count: 200
#
# Slice 121:
#   Event: rf at 1.6225s
#   Size: 200.0
#   Time range: 1.6225s - 1.6245s
#   Sample count: 200
#
# Slice 122:
#   Event: gz at 1.6245s
#   Size: 200.0
#   Time range: 1.6245s - 1.6250s
#   Sample count: 200
#
# Slice 123:
#   Event: delay at 1.6250s
#   Size: 20.0
#   Time range: 1.6250s - 1.6725s
#   Sample count: 20
#
# Slice 124:
#   Event: gz at 1.6750s
#   Size: 200.0
#   Time range: 1.6750s - 1.6755s
#   Sample count: 200
#
# Slice 125:
#   Event: rf at 1.6755s
#   Size: 200.0
#   Time range: 1.6755s - 1.6775s
#   Sample count: 200
#
# Slice 126:
#   Event: gz at 1.6775s
#   Size: 200.0
#   Time range: 1.6775s - 1.6780s
#   Sample count: 200
#
# Slice 127:
#   Event: delay at 1.6780s
#   Size: 20.0
#   Time range: 1.6780s - 1.7255s
#   Sample count: 20
#
# Slice 128:
#   Event: gz at 1.7280s
#   Size: 200.0
#   Time range: 1.7280s - 1.7285s
#   Sample count: 200
#
# Slice 129:
#   Event: rf at 1.7285s
#   Size: 200.0
#   Time range: 1.7285s - 1.7305s
#   Sample count: 200
#
# Slice 130:
#   Event: gz at 1.7305s
#   Size: 200.0
#   Time range: 1.7305s - 1.7310s
#   Sample count: 200
#
# Slice 131:
#   Event: delay at 1.7310s
#   Size: 20.0
#   Time range: 1.7310s - 1.7785s
#   Sample count: 20
#
# Slice 132:
#   Event: gz at 1.7810s
#   Size: 200.0
#   Time range: 1.7810s - 1.7815s
#   Sample count: 200
#
# Slice 133:
#   Event: rf at 1.7815s
#   Size: 200.0
#   Time range: 1.7815s - 1.7835s
#   Sample count: 200
#
# Slice 134:
#   Event: gz at 1.7835s
#   Size: 200.0
#   Time range: 1.7835s - 1.7840s
#   Sample count: 200
#
# Slice 135:
#   Event: delay at 1.7840s
#   Size: 20.0
#   Time range: 1.7840s - 1.8315s
#   Sample count: 20
#
# Slice 136:
#   Event: gz at 1.8340s
#   Size: 200.0
#   Time range: 1.8340s - 1.8345s
#   Sample count: 200
#
# Slice 137:
#   Event: rf at 1.8345s
#   Size: 200.0
#   Time range: 1.8345s - 1.8365s
#   Sample count: 200
#
# Slice 138:
#   Event: gz at 1.8365s
#   Size: 200.0
#   Time range: 1.8365s - 1.8370s
#   Sample count: 200
#
# Slice 139:
#   Event: delay at 1.8370s
#   Size: 20.0
#   Time range: 1.8370s - 1.8845s
#   Sample count: 20
#
# Slice 140:
#   Event: gz at 1.8870s
#   Size: 200.0
#   Time range: 1.8870s - 1.8875s
#   Sample count: 200
#
# Slice 141:
#   Event: rf at 1.8875s
#   Size: 200.0
#   Time range: 1.8875s - 1.8895s
#   Sample count: 200
#
# Slice 142:
#   Event: gz at 1.8895s
#   Size: 200.0
#   Time range: 1.8895s - 1.8900s
#   Sample count: 200
#
# Slice 143:
#   Event: delay at 1.8900s
#   Size: 20.0
#   Time range: 1.8900s - 1.9375s
#   Sample count: 20
#
# Slice 144:
#   Event: gz at 1.9400s
#   Size: 200.0
#   Time range: 1.9400s - 1.9405s
#   Sample count: 200
#
# Slice 145:
#   Event: rf at 1.9405s
#   Size: 200.0
#   Time range: 1.9405s - 1.9425s
#   Sample count: 200
#
# Slice 146:
#   Event: gz at 1.9425s
#   Size: 200.0
#   Time range: 1.9425s - 1.9430s
#   Sample count: 200
#
# Slice 147:
#   Event: delay at 1.9430s
#   Size: 20.0
#   Time range: 1.9430s - 1.9905s
#   Sample count: 20
#
# Slice 148:
#   Event: gz at 1.9930s
#   Size: 200.0
#   Time range: 1.9930s - 1.9935s
#   Sample count: 200
#
# Slice 149:
#   Event: rf at 1.9935s
#   Size: 200.0
#   Time range: 1.9935s - 1.9955s
#   Sample count: 200
#
# Slice 150:
#   Event: gz at 1.9955s
#   Size: 200.0
#   Time range: 1.9955s - 1.9960s
#   Sample count: 200
#
# Slice 151:
#   Event: delay at 1.9960s
#   Size: 20.0
#   Time range: 1.9960s - 2.0435s
#   Sample count: 20
#
# Slice 152:
#   Event: gz at 2.0460s
#   Size: 200.0
#   Time range: 2.0460s - 2.0465s
#   Sample count: 200
#
# Slice 153:
#   Event: rf at 2.0465s
#   Size: 200.0
#   Time range: 2.0465s - 2.0485s
#   Sample count: 200
#
# Slice 154:
#   Event: gz at 2.0485s
#   Size: 200.0
#   Time range: 2.0485s - 2.0490s
#   Sample count: 200
#
# Slice 155:
#   Event: delay at 2.0490s
#   Size: 20.0
#   Time range: 2.0490s - 2.0965s
#   Sample count: 20
#
# Slice 156:
#   Event: gz at 2.0990s
#   Size: 200.0
#   Time range: 2.0990s - 2.0995s
#   Sample count: 200
#
# Slice 157:
#   Event: rf at 2.0995s
#   Size: 200.0
#   Time range: 2.0995s - 2.1015s
#   Sample count: 200
#
# Slice 158:
#   Event: gz at 2.1015s
#   Size: 200.0
#   Time range: 2.1015s - 2.1020s
#   Sample count: 200
#
# Slice 159:
#   Event: delay at 2.1020s
#   Size: 20.0
#   Time range: 2.1020s - 2.1495s
#   Sample count: 20
#
# Slice 160:
#   Event: gz at 2.1520s
#   Size: 200.0
#   Time range: 2.1520s - 2.1525s
#   Sample count: 200
#
# Slice 161:
#   Event: rf at 2.1525s
#   Size: 200.0
#   Time range: 2.1525s - 2.1545s
#   Sample count: 200
#
# Slice 162:
#   Event: gz at 2.1545s
#   Size: 200.0
#   Time range: 2.1545s - 2.1550s
#   Sample count: 200
#
# Slice 163:
#   Event: delay at 2.1550s
#   Size: 20.0
#   Time range: 2.1550s - 2.2025s
#   Sample count: 20
#
# Slice 164:
#   Event: gz at 2.2050s
#   Size: 200.0
#   Time range: 2.2050s - 2.2055s
#   Sample count: 200
#
# Slice 165:
#   Event: rf at 2.2055s
#   Size: 200.0
#   Time range: 2.2055s - 2.2075s
#   Sample count: 200
#
# Slice 166:
#   Event: gz at 2.2075s
#   Size: 200.0
#   Time range: 2.2075s - 2.2080s
#   Sample count: 200
#
# Slice 167:
#   Event: delay at 2.2080s
#   Size: 20.0
#   Time range: 2.2080s - 2.2555s
#   Sample count: 20
#
# Slice 168:
#   Event: adc at 2.2580s
#   Size: 200.0
#   Time range: 2.2580s - 2.2630s
#   Sample count: 200
#
# === End Debug ===
#
#
# Slice 168:
#   Event: adc at 2.2580s
#   Size: 200.0
#   Time range: 2.2580s - 2.2630s
#   Sample count: 200
#
# === End Debug ===

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
print(f'Signal: {singal_phasead.item()}')
# fig

fig, ax = plt.subplots(dpi=150)
for index, t_val in enumerate(plot_data_phasead['t']):
    ax.plot(t_val, plot_data_phasead['signal_plot'][index], 'o', markersize=1)
ax.axhline(0, c='black')
ax.set_ylim(-0.0008, 0.0003)
plt.show()
# Out:
# Signal: 0.00012971795633683796
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Evaluation

# %%
# %matplotlib widget
import matplotlib.pyplot as plt

fig, ax = plt.subplots(dpi=150)

# No Phase Advance (blau)
for index, t_val in enumerate(plot_data['t']):
    ax.plot(t_val, plot_data['signal_plot'][index], 'o', markersize=1, color='blue', label='No Phase Advance' if index == 0 else None)

# Phase Advance 180° (rot)
for index, t_val in enumerate(plot_data_phasead['t']):
    ax.plot(t_val, plot_data_phasead['signal_plot'][index], 'o', markersize=1, color='red', label='Phase Advance 180°' if index == 0 else None)

ax.axhline(0, c='black', linewidth=0.5)
ax.set_ylim(0.0, 0.0002)
ax.set_xlabel('Time [s]')
ax.set_ylabel('Signal Difference')
ax.legend()
plt.tight_layout()
plt.show()

print(f'Signal (No Phase Advance): {singal.item():.6f}')
print(f'Signal (Phase Advance 180°): {singal_phasead.item():.6f}')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Signal (No Phase Advance): 0.000130
# Signal (Phase Advance 180°): 0.000130
