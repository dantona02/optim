# %%
from bmctool.simulate import simulate, sim_example

config_path = '/Users/danielmiksch/Downloads/config_1pool.yaml'  # can be a str or a Path
seq_path = '/Users/danielmiksch/Downloads/default_seqid.seq'  # can be a str or a Path

sim = simulate(config_file=config_path, seq_file=seq_path, show_plot=True, plot_mtr_asym=True)
# Out:
# BMCTool simulation: 100%|██████████| 492/492 [00:00<00:00, 13383.04it/s]

# %%
config_path = '/Users/danielmiksch/miniconda3/envs/simu/lib/python3.11/site-packages/bmctool/library/sim-library/config_wasabi.yaml'  # can be a str or a Path
seq_path = '/Users/danielmiksch/Downloads/default_seqid.seq'  # can be a str or a Path

sim = simulate(config_file=config_path, seq_file=seq_path, show_plot=True)
# Out:
# BMCTool simulation: 100%|██████████| 492/492 [00:05<00:00, 85.16it/s]

# %%
sim_example()
# Out:
# BMCTool simulation: 100%|██████████| 128/128 [00:00<00:00, 6782.27it/s]
