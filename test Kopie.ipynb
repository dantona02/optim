# %%
from bmc.simulate import simulate

# %%
seq_path = '/Users/danielmiksch/JupyterLab/optim/seq_init/default_seqid.seq'
config_path = '/Users/danielmiksch/JupyterLab/optim/seq_init/config_1pool.yaml'

seq_path_win = 'C:/Users/s436276/simulation/JupyterLab/optim/seq_init/default_seqid.seq'
config_path_win = 'C:/Users/s436276/simulation/JupyterLab/optim/seq_init/config_1pool.yaml'


#simulate(config_file=config_path, seq_file=seq_path, show_plot=True)
simulate(config_file=config_path_win, seq_file=seq_path_win, show_plot=True)  # simulation windows
# Out:
# BMCTool simulation:   0%|          | 0/328 [00:00<?, ?it/s]
# BMCTool simulation: 100%|██████████| 328/328 [00:00<00:00, 16048.95it/s]

# %%
from bmc.simulate import simulate_fid

# %%
seq_path_gauss = '/Users/danielmiksch/JupyterLab/optim/seq_init/simple_gauss.seq'
seq_path_gauss_win = 'C:/Users/s436276/simulation/JupyterLab/optim/seq_init/simple_gauss.seq'

#simulate_fid(config_file=config_path, seq_file=seq_path_gauss, adc_time=5.0, show_plot=False)
simulate_fid(config_file=config_path_win, seq_file=seq_path_gauss_win, adc_time=5.0, show_plot=False)  # simulation windows
# Out:
# BMCTool simulation: 100%|██████████| 2/2 [00:00<00:00, 40.84it/s]
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
# (3, 300)
