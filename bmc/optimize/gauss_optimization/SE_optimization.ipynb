# %% [markdown]
# # Spin-Echo-Puls-Optimierung
#
# Dieses Notebook implementiert eine Optimierung für die Spin-Echo-Sequenz (SE.seq). Anders als bei der ursprünglichen sinc_optimization.ipynb werden hier zwei Pulse (90° und 180° Pulse) gleichzeitig optimiert. Das Ziel ist die Maximierung des Signals am ADC-Ereignis.

# %% [markdown]
# ## Importieren der erforderlichen Bibliotheken

# %%
import os
import json
import torch
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from datetime import datetime

from bmc.fid.engine import BMCSim
# Importiere den SingleSimBMCWrapper für die Signaloptimierung
from bmc.optimize.gauss_optimization.single_sim_optimizer import SingleSimBMCWrapper
from bmc.bmc_tool import prep_rf_simulation, prep_grad_simulation
from bmc.set_params import load_params
from bmc.utils.global_device import GLOBAL_DEVICE

# Aktiviere interaktive Plots

# %% [markdown]
# ## Hilfsfunktionen definieren

# %%
def signal_objective_function(signal, rf_parameters=None, edge_penalty_weight=0.0, smoothness_weight=0.0, negative_penalty_weight=0.0):
    """
    Berechnet den Zielwert für die Optimierung des Signals.
    Wir maximieren das Signal, also ist das Ziel, den negativen Signalwert zu minimieren.
    Mit optionaler Strafe für Nicht-Null-Werte an den Enden des Pulses.
    
    Args:
        signal: Signal-Tensor
        rf_parameters: Liste der RF-Parameter [amp, phase] (optional)
        edge_penalty_weight: Gewichtung für die Strafe auf Nicht-Null-Enden (0.0 = deaktiviert)
        smoothness_weight: Gewichtung für die Glättung der Pulsform (0.0 = deaktiviert)
        negative_penalty_weight: Gewichtung für die Bestrafung negativer Amplitudenwerte (0.0 = deaktiviert)
        
    Returns:
        Verlust: Negatives Signal (+ ggf. Strafen)
    """
    # Bei der Optimierung wollen wir den Betrag des Signals maximieren
    signal_loss = -torch.abs(signal)
    
    total_penalty = 0.0
    
    # Wenn rf_parameters übergeben wurden, Strafen anwenden
    if rf_parameters is not None:
        # Strafe für Nicht-Null-Enden
        if edge_penalty_weight > 0:
            edge_penalty = 0.0
            for amp, _ in rf_parameters:
                # Berechne Strafe für die ersten und letzten N Samples
                n_samples = 1  # Anzahl der Samples am Anfang und Ende, die nahe bei 0 sein sollen
                first_samples = amp[:n_samples]  # Erste N Samples
                last_samples = amp[-n_samples:]  # Letzte N Samples
                
                # Strafe berechnen (quadratisch, um größere Abweichungen stärker zu bestrafen)
                edge_penalty += torch.sum(first_samples**2) + torch.sum(last_samples**2)
            
            total_penalty += edge_penalty_weight * edge_penalty
        
        # Strafe für nicht-glatte Übergänge
        if smoothness_weight > 0:
            smoothness_penalty = 0.0
            for amp, _ in rf_parameters:
                # Berechne die Differenzen zwischen aufeinanderfolgenden Samples
                diffs = amp[1:] - amp[:-1]
                
                # Bestrafe große Unterschiede (quadratisch)
                smoothness_penalty += torch.sum(diffs**2)
            
            total_penalty += smoothness_weight * smoothness_penalty
        
        # Strafe für negative Amplitudenwerte
        if negative_penalty_weight > 0:
            negative_penalty = 0.0
            for amp, _ in rf_parameters:
                # Finde alle negativen Werte (ReLU negiert)
                negative_values = torch.nn.functional.relu(-amp)
                # Quadratische Strafe für negative Werte
                negative_penalty += torch.sum(negative_values**2)
            
            total_penalty += negative_penalty_weight * negative_penalty
    
    return signal_loss + total_penalty

def save_checkpoint(checkpoint_dir, rf_parameters, optimizer, epoch, loss, signal, 
                  checkpoint_name=None, dtp_rf=None):
    """
    Speichert einen Checkpoint mit allen relevanten Trainingsparametern.
    
    Args:
        checkpoint_dir: Verzeichnis zum Speichern des Checkpoints
        rf_parameters: Liste der RF-Parameter [amp, phase]
        optimizer: Der Optimierer
        epoch: Aktuelle Epoche
        loss: Aktueller Verlustwert
        signal: Aktuelles Signal
        checkpoint_name: Optional, Name des Checkpoint-Files
        dtp_rf: Sampling-Zeit des RF-Pulses (wichtig für korrekte Rekonstruktion)
    """
    if checkpoint_name is None:
        checkpoint_name = f"checkpoint_epoch_{epoch}.pt"
    
    # Erstelle Checkpoint-Verzeichnis, falls es nicht existiert
    os.makedirs(checkpoint_dir, exist_ok=True)
    
    # Bereite RF-Parameter für die Speicherung vor
    rf_param_state = []
    for amp, phase in rf_parameters:
        rf_param_state.append([amp.detach().clone(), phase.detach().clone()])
    
    # Erstelle Checkpoint-Dictionary
    checkpoint = {
        'epoch': epoch,
        'rf_parameters': rf_param_state,
        'optimizer_state_dict': optimizer.state_dict(),
        'loss': loss,
        'signal': signal
    }
    
    # Speichere die Puls-Parameter, wenn vorhanden
    if dtp_rf is not None:
        checkpoint['parameters'] = {
            'dt': float(dtp_rf),  # Sampling-Zeit (sehr wichtig für die korrekte Verwendung des Pulses)
            'num_samples': len(rf_parameters[0][0]) if rf_parameters else 0  # Anzahl der Samples im Puls
        }
    
    # Speichere Checkpoint
    checkpoint_path = os.path.join(checkpoint_dir, checkpoint_name)
    torch.save(checkpoint, checkpoint_path)
    
    # Speichere zusätzliche Metadaten
    metadata = {
        'timestamp': datetime.now().isoformat(),
        'epoch': epoch,
        'loss': float(loss),
        'signal': float(signal)
    }
    # Füge dt zu den Metadaten hinzu
    if dtp_rf is not None:
        metadata['dt'] = float(dtp_rf)
    
    metadata_path = os.path.join(checkpoint_dir, 'SE_training_metadata.json')
    with open(metadata_path, 'w') as f:
        json.dump(metadata, f, indent=4)
    
    return checkpoint_path

def load_checkpoint(checkpoint_path, optimizer=None):
    """
    Lädt einen Checkpoint und stellt den Trainingszustand wieder her.
    """
    if not os.path.exists(checkpoint_path):
        raise FileNotFoundError(f"Checkpoint-Datei {checkpoint_path} wurde nicht gefunden.")
    
    checkpoint = torch.load(checkpoint_path)
    
    # RF-Parameter laden
    rf_parameters = checkpoint['rf_parameters']
    
    # Optimierer-Zustand laden, falls vorhanden
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    
    return rf_parameters, checkpoint['epoch'], checkpoint['loss'], checkpoint['signal']

def plot_progress(epochs, losses, signals, save_path=None):
    """
    Plottet den Fortschritt des Trainings.
    """
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8), sharex=True)
    
    # Plot für Verlust
    ax1.plot(epochs, losses, 'b-', marker='o')
    ax1.set_ylabel('Verlust')
    ax1.set_title('Trainingsverlauf')
    ax1.grid(True)
    
    # Plot für Signal
    ax2.plot(epochs, signals, 'r-', marker='o')
    ax2.set_xlabel('Epoche')
    ax2.set_ylabel('Signal')
    ax2.grid(True)
    
    plt.tight_layout()
    
    if save_path:
        plt.savefig(save_path)
    
    return fig

# %% [markdown]
# ## Initialisierung der Parameter und Simulationsumgebung
#
# Wir verwenden die Sequenzdatei "SE.seq" für unsere Optimierung. Diese enthält zwei Pulse: einen 90°-Puls gefolgt von einem 180°-Puls, die typisch für eine Spin-Echo-Sequenz sind.

# %%
def get_params():
    """
    Initialisiert die Parameter für das Training.
    """
    base_dir = Path().resolve().parent.parent.parent
    config_file = base_dir / "sim_lib" / "config_1pool.yaml"
    seq_file = base_dir / "seq_lib" / "SE.seq"  # Hier verwenden wir die SE.seq Datei

    if not Path(config_file).exists():
        raise FileNotFoundError(f"Konfigurationsdatei {config_file} nicht gefunden.")

    if not Path(seq_file).exists():
        raise FileNotFoundError(f"Sequenzdatei {seq_file} nicht gefunden.")
    
    print(f"Verwende Sequenzdatei: {seq_file}")
    print(f"Verwende Konfigurationsdatei: {config_file}")
    
    sim_params = load_params(config_file)

    # Erstelle Positionen für die Simulation mit 500 Isochromaten
    low = -1e-3
    high = 1e-3
    n_iso = 500  # Erhöht auf 500 Isochromaten für bessere Genauigkeit
    z_pos = np.linspace(low, high, n_iso)
    z_pos = torch.tensor(z_pos)
    z_pos = torch.cat((z_pos, torch.tensor([0.0]))) 
    
    print(f"Anzahl der Isochromaten: {len(z_pos)}")

    # Initialisiere Simulationsengine mit n_backlog=0 für Signal am Beginn des ADC
    sim_engine_instance = BMCSim(adc_time=50e-3,
                                params=sim_params,
                                seq_file=seq_file,
                                z_positions=z_pos,
                                n_backlog=0,  # Signal am Beginn des ADC
                                verbose=True,
                                webhook=False)
    
    # Verwende den SingleSimBMCWrapper
    diff_sim = SingleSimBMCWrapper(sim_engine_instance)
    
    # Extrahiere RF-Parameter aus der Sequenz (beide Pulse)
    rf_parameters = []  # Liste für [amp, phase] Paare
    dtp_rf = None
    
    for i, block_event in enumerate(diff_sim.sim_engine.seq.block_events, start=1):
        block = sim_engine_instance.seq.get_block(block_event)
        if block.rf:
            if hasattr(block, "block_duration") and block.block_duration != "0":
                amp_, ph_, dtp_rf, delay_after_pulse = prep_rf_simulation(
                    block, sim_engine_instance.params.options["max_pulse_samples"])
                print(f"RF-Block {i}: Form mit {len(amp_)} Samples, dtp_rf: {dtp_rf}")
                
                # Die originalen Phasenwerte beibehalten
                # ph_ enthält bereits die korrekten Phasenwerte aus prep_rf_simulation
                
                # Aktiviere Gradienten für Amplituden
                amp_.requires_grad_(True)
                
                # Füge das [amp, phase] Paar zur Liste hinzu
                rf_parameters.append([amp_, ph_])

    if not rf_parameters:
        raise ValueError("Keine RF-Blöcke in der Sequenz gefunden.")
    elif len(rf_parameters) < 2:
        raise ValueError("Weniger als 2 RF-Pulse in der SE-Sequenz gefunden. Die SE-Sequenz sollte 2 Pulse enthalten.")
    
    print(f"Anzahl der RF-Pulse: {len(rf_parameters)}")
    print(f"RF-Puls 1 Amplitude Form: {rf_parameters[0][0].shape}")
    print(f"RF-Puls 2 Amplitude Form: {rf_parameters[1][0].shape}")
    
    return rf_parameters, sim_params, seq_file, z_pos, diff_sim, dtp_rf

# Parameter holen
rf_parameters, sim_params, seq_file, z_pos, diff_sim, dtp_rf = get_params()
# Out:
# Verwende Sequenzdatei: /Users/danielmiksch/JupyterLab/optim/seq_lib/SE.seq
# Verwende Konfigurationsdatei: /Users/danielmiksch/JupyterLab/optim/sim_lib/config_1pool.yaml
# Anzahl der Isochromaten: 501
# RF-Block 2: Form mit 286 Samples, dtp_rf: 7.000000000000001e-06
# RF-Block 4: Form mit 286 Samples, dtp_rf: 7.000000000000001e-06
# Anzahl der RF-Pulse: 2
# RF-Puls 1 Amplitude Form: torch.Size([286])
# RF-Puls 2 Amplitude Form: torch.Size([286])

# %% [markdown]
# ## Visualisierung der ursprünglichen Pulse
#
# Bevor wir mit der Optimierung beginnen, wollen wir uns die aktuelle Form der RF-Pulse ansehen.

# %%
def visualize_pulses(parameters, dtp, title="RF-Pulse"):
    """
    Visualisiert mehrere RF-Pulse.
    """
    plt.figure(figsize=(12, 8))
    
    # Für jeden Puls in den Parametern
    for i, [amp, _] in enumerate(parameters):
        pulse = amp.detach().cpu().numpy()
        time_axis = np.arange(len(pulse)) * dtp * 1000  # Umrechnung in ms
        
        plt.subplot(len(parameters), 1, i+1)
        plt.plot(time_axis, pulse, linewidth=2)
        plt.title(f"{title} {i+1}" + (" (90°)" if i == 0 else " (180°)" if i == 1 else ""))
        plt.xlabel('Zeit (ms)')
        plt.ylabel('Amplitude')
        plt.grid(True)
    
    plt.tight_layout()

# Original-Pulse visualisieren
visualize_pulses(rf_parameters, dtp_rf, "Originaler Puls")

# %% [markdown]
# ## Simulieren des ursprünglichen Signals
#
# Bevor wir mit der Optimierung beginnen, wollen wir das aktuelle Signal messen.

# %%
with torch.no_grad():
    # RF-Parameter direkt an diff_sim übergeben
    original_signal = diff_sim(rf_parameters)

print(f"Signal der Original-Pulse: {original_signal.item():.6f}")

# Die ursprünglichen Pulse für späteren Vergleich speichern
original_pulse_parameters = []
for amp, phase in rf_parameters:
    original_pulse_parameters.append([amp.detach().clone(), phase.detach().clone()])
# Out:
# Signal der Original-Pulse: 0.022125

# %% [markdown]
# ## Training der RF-Pulse
#
# Jetzt führen wir das Training durch, um beide Pulse der Spin-Echo-Sequenz zu optimieren.

# %%
def initialize_custom_rf_pulse(original_rf_parameters, init_method='random', scaling_factor=0.5):
    """
    Initialisiert RF-Pulse mit verschiedenen Methoden, um dem Optimierer mehr Freiheit zu geben.
    
    Args:
        original_rf_parameters: Die ursprünglichen RF-Parameter als Liste von [amp, phase] Paaren
        init_method: Methode zur Initialisierung ('random', 'flat', 'sine', 'mixed', 'original')
        scaling_factor: Skalierungsfaktor für die Amplitude (für 'random', 'sine', 'mixed')
        
    Returns:
        Neue RF-Parameter mit initialisierter Pulsform
    """
    custom_rf_parameters = []
    
    for i, [amp, phase] in enumerate(original_rf_parameters):
        # Behalte die ursprüngliche Phase bei
        new_phase = phase.clone().detach()
        
        # Hole die Dimensionen des originalen Pulses
        pulse_length = len(amp)
        max_amp_value = torch.max(amp).item()
        
        # Initialisierung je nach gewählter Methode
        if init_method == 'random':
            # Zufällige Initialisierung (gleichmäßig verteilt)
            new_amp = torch.rand_like(amp) * max_amp_value * scaling_factor
            
        elif init_method == 'flat':
            # Flache Initialisierung (konstante Amplitude)
            mean_amp = torch.mean(amp).item()
            new_amp = torch.ones_like(amp) * mean_amp
            
        elif init_method == 'sine':
            # Sinus-Initialisierung (eine andere Form als Gauß)
            x = torch.linspace(0, 2*torch.pi, pulse_length, device=amp.device, dtype=amp.dtype)
            new_amp = torch.sin(x) * max_amp_value * scaling_factor
            # Stelle sicher, dass die Werte positiv sind
            new_amp = torch.abs(new_amp)
            
        elif init_method == 'mixed':
            # Mischung aus Original und Zufälligkeit
            random_component = torch.rand_like(amp) * max_amp_value * scaling_factor
            # Das Original detachen, um den Berechnungsgraph zu trennen
            original_component = amp.clone().detach() * (1 - scaling_factor)
            new_amp = random_component + original_component
            
        else:  # 'original' oder andere Werte
            # Behalte die ursprüngliche Form bei
            new_amp = amp.clone().detach()
        
        # Stelle sicher, dass wir ein Blatt-Tensor haben (detach)
        # und eine neue Kopie erstellen (clone)
        new_amp = new_amp.detach().clone()
        # Dann erst kann requires_grad aktiviert werden
        new_amp.requires_grad_(True)
        
        # Füge das neue Paar zur Liste hinzu
        custom_rf_parameters.append([new_amp, new_phase])
    
    return custom_rf_parameters

def train(rf_parameters, diff_sim, num_epochs=50, learning_rate=0.1, 
          edge_penalty_weight=0.0001, smoothness_weight=0.0001, negative_penalty_weight=0.0001,
          checkpoint_dir='checkpoints/SE_optimization', checkpoint_frequency=5,
          init_method='original', custom_init_scaling=0.5, lr_decay=0.995,
          momentum=0.9, use_scheduler=True, use_adam=True):
    """
    Führt das Training für die RF-Puls-Optimierung durch mit erweiterten Optionen.
    Bei der SE-Sequenz werden beide Pulse (90° und 180°) gleichzeitig optimiert.
    
    Args:
        rf_parameters: Liste von [amp, phase] Paaren
        diff_sim: Simulationsinstanz (SingleSimBMCWrapper)
        num_epochs: Anzahl der Trainingsepochen
        learning_rate: Lernrate für den Optimierer
        edge_penalty_weight: Gewichtung der Strafe für Nicht-Null-Enden des Pulses
        smoothness_weight: Gewichtung der Strafe für glatte Übergänge
        negative_penalty_weight: Gewichtung der Strafe für negative Amplitudenwerte
        checkpoint_dir: Verzeichnis für Checkpoints
        checkpoint_frequency: Nach wievielen Epochen ein Checkpoint gespeichert wird
        init_method: Methode zur Initialisierung des RF-Pulses
        custom_init_scaling: Skalierungsfaktor für die benutzerdefinierte Initialisierung
        lr_decay: Faktor für die Lernratenabnahme bei Verwendung eines Schedulers
        momentum: Momentum für SGD-Optimierer (falls use_adam=False)
        use_scheduler: Ob ein Lernraten-Scheduler verwendet werden soll
        use_adam: Ob Adam statt SGD verwendet werden soll
    """
    # Initialisiere RF-Parameter mit der gewählten Methode, falls nicht 'original'
    if init_method != 'original':
        rf_parameters = initialize_custom_rf_pulse(rf_parameters, init_method, custom_init_scaling)
        print(f"RF-Pulse mit Methode '{init_method}' neu initialisiert, Skalierungsfaktor: {custom_init_scaling}")
    
    # Extrahiere optimierbare Parameter aus der Liste von [amp, phase] Paaren
    optimizable_params = []
    
    for i, [amp, phase] in enumerate(rf_parameters):
        # Sicherstellen, dass amp ein Blatt-Tensor ist
        optimizable_params.append(amp)
    
    # Checkpoint-Verzeichnis erstellen
    os.makedirs(checkpoint_dir, exist_ok=True)
    
    # Initialisiere den Optimierer
    if use_adam:
        optimizer = torch.optim.Adam(optimizable_params, lr=learning_rate)
    else:
        optimizer = torch.optim.SGD(optimizable_params, lr=learning_rate, momentum=momentum)
    
    # Optional: Lernraten-Scheduler
    scheduler = None
    if use_scheduler:
        scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=lr_decay)
    
    # Variablen für Tracking
    best_signal = float('-inf')
    best_parameters = None
    epochs_list = []
    losses_list = []
    signals_list = []
    learning_rates = []
    
    # Trainingsschleife
    for epoch in range(num_epochs):
        # Führe die Simulation mit aktuellen Parametern durch
        signal = diff_sim(rf_parameters)
        
        # Berechne den Verlust mit der angepassten Verlustfunktion
        loss = signal_objective_function(signal, rf_parameters, edge_penalty_weight, smoothness_weight, negative_penalty_weight)
        
        # Führe Backpropagation durch
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Signal (negierter Verlust ohne Strafe) für die Ausgabe
        pure_signal_value = torch.abs(signal).item()
        
        # Tracking
        epochs_list.append(epoch)
        losses_list.append(loss.item())
        signals_list.append(pure_signal_value)
        current_lr = optimizer.param_groups[0]['lr']
        learning_rates.append(current_lr)
        
        # Ausgabe
        print(f"Epoche {epoch}/{num_epochs - 1} - Signal: {pure_signal_value:.6f}, Verlust: {loss.item():.6f}, LR: {current_lr:.6f}")
        
        # Speichere den besten Zustand (basierend auf dem reinen Signal)
        if pure_signal_value > best_signal:
            best_signal = pure_signal_value
            # Klonen der aktuellen Parameter
            best_parameters = []
            for amp, phase in rf_parameters:
                best_parameters.append([amp.detach().clone(), phase.detach().clone()])
            
            save_checkpoint(
                checkpoint_dir, 
                best_parameters, 
                optimizer, 
                epoch, 
                loss.item(), 
                pure_signal_value,
                checkpoint_name="best_checkpoint.pt",
                dtp_rf=dtp_rf  # Übergebe die Sampling-Zeit
            )
            print(f"  Neuer Bestwert gefunden und gespeichert!")
        
        # Speichere regelmäßige Checkpoints
        if epoch % checkpoint_frequency == 0 or epoch == num_epochs - 1:
            current_parameters = []
            for amp, phase in rf_parameters:
                current_parameters.append([amp.detach().clone(), phase.detach().clone()])
                
            save_checkpoint(
                checkpoint_dir, 
                current_parameters, 
                optimizer, 
                epoch, 
                loss.item(), 
                pure_signal_value,
                dtp_rf=dtp_rf  # Übergebe die Sampling-Zeit
            )
            
        # Update des Schedulers, falls verwendet
        if scheduler and epoch < num_epochs - 1:  # Nicht im letzten Epoch aktualisieren
            scheduler.step()
    
    # Speichere den finalen Zustand
    final_parameters = []
    for amp, phase in rf_parameters:
        final_parameters.append([amp.detach().clone(), phase.detach().clone()])
        
    final_path = save_checkpoint(
        checkpoint_dir, 
        final_parameters, 
        optimizer, 
        num_epochs - 1, 
        losses_list[-1], 
        signals_list[-1],
        checkpoint_name="final_checkpoint.pt"
    )
    
    # Plotte den Fortschritt
    fig = plot_progress(
        epochs_list, 
        losses_list, 
        signals_list,
        save_path=os.path.join(checkpoint_dir, "training_progress.png")
    )
    
    # Zusätzlichen Plot für die Lernraten erstellen
    plt.figure(figsize=(10, 5))
    plt.plot(epochs_list, learning_rates, 'g-')
    plt.title('Lernratenentwicklung')
    plt.xlabel('Epoche')
    plt.ylabel('Lernrate')
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(os.path.join(checkpoint_dir, "learning_rate_progress.png"))
    
    print("\nTraining abgeschlossen!")
    print(f"Bestes Signal: {best_signal:.6f}")
    
    return best_parameters, best_signal, final_path, fig

# Training ausführen für die SE-Sequenz mit beiden Pulsen
best_parameters, best_signal, final_checkpoint_path, progress_plot = train(
    rf_parameters, diff_sim, 
    num_epochs=300,
    learning_rate=15,
    edge_penalty_weight=0.0001,
    smoothness_weight=0.00001,
    negative_penalty_weight=0.001,  # Gewichtung für die Bestrafung negativer Amplitudenwerte
    checkpoint_dir='checkpoints/SE_optimization_163_8',  # Eigenes Verzeichnis für die SE-Optimierung
    init_method='original',  # Starte mit der ursprünglichen Form
    custom_init_scaling=1.0,  # Volle Amplitude für maximale Änderung
    lr_decay=0.998,
    # lr_decay=0.998,
    use_scheduler=True,
    use_adam=True,
    checkpoint_frequency=10
)
# Out:
# Epoche 0/299 - Signal: 0.022125, Verlust: 0.233481, LR: 15.000000
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 1/299 - Signal: 0.024453, Verlust: 20.854258, LR: 14.970000
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 2/299 - Signal: 0.025078, Verlust: 1.249308, LR: 14.940060
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 3/299 - Signal: 0.030529, Verlust: 0.379958, LR: 14.910180
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 4/299 - Signal: 0.032854, Verlust: 0.634714, LR: 14.880360
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 5/299 - Signal: 0.032516, Verlust: 0.430616, LR: 14.850599
# Epoche 6/299 - Signal: 0.032045, Verlust: 0.599262, LR: 14.820898
# Epoche 7/299 - Signal: 0.031808, Verlust: 0.619005, LR: 14.791256
# Epoche 8/299 - Signal: 0.032693, Verlust: 0.506383, LR: 14.761673
# Epoche 9/299 - Signal: 0.033486, Verlust: 0.478220, LR: 14.732150
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 10/299 - Signal: 0.034120, Verlust: 0.505956, LR: 14.702686
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 11/299 - Signal: 0.034579, Verlust: 0.456198, LR: 14.673280
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 12/299 - Signal: 0.034896, Verlust: 0.359544, LR: 14.643934
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 13/299 - Signal: 0.035092, Verlust: 0.316052, LR: 14.614646
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 14/299 - Signal: 0.035228, Verlust: 0.312341, LR: 14.585417
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 15/299 - Signal: 0.035352, Verlust: 0.320253, LR: 14.556246
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 16/299 - Signal: 0.035461, Verlust: 0.279140, LR: 14.527133
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 17/299 - Signal: 0.035566, Verlust: 0.243068, LR: 14.498079
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 18/299 - Signal: 0.035654, Verlust: 0.244828, LR: 14.469083
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 19/299 - Signal: 0.035740, Verlust: 0.260125, LR: 14.440145
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 20/299 - Signal: 0.035822, Verlust: 0.267144, LR: 14.411264
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 21/299 - Signal: 0.035905, Verlust: 0.250587, LR: 14.382442
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 22/299 - Signal: 0.035996, Verlust: 0.230089, LR: 14.353677
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 23/299 - Signal: 0.036095, Verlust: 0.224063, LR: 14.324970
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 24/299 - Signal: 0.036207, Verlust: 0.216077, LR: 14.296320
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 25/299 - Signal: 0.036333, Verlust: 0.193538, LR: 14.267727
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 26/299 - Signal: 0.036456, Verlust: 0.177700, LR: 14.239192
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 27/299 - Signal: 0.036568, Verlust: 0.174431, LR: 14.210713
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 28/299 - Signal: 0.036667, Verlust: 0.173961, LR: 14.182292
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 29/299 - Signal: 0.036757, Verlust: 0.168192, LR: 14.153927
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 30/299 - Signal: 0.036842, Verlust: 0.160909, LR: 14.125619
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 31/299 - Signal: 0.036930, Verlust: 0.155084, LR: 14.097368
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 32/299 - Signal: 0.037024, Verlust: 0.151961, LR: 14.069173
#   Neuer Bestwert gefunden und gespeichert!
# Epoche
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 286/299 - Signal: 0.678850, Verlust: -0.533651, LR: 8.461085
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 287/299 - Signal: 0.679230, Verlust: -0.534134, LR: 8.444163
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 288/299 - Signal: 0.679589, Verlust: -0.534599, LR: 8.427275
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 289/299 - Signal: 0.679928, Verlust: -0.535048, LR: 8.410420
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 290/299 - Signal: 0.680247, Verlust: -0.535481, LR: 8.393599
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 291/299 - Signal: 0.680549, Verlust: -0.535899, LR: 8.376812
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 292/299 - Signal: 0.680835, Verlust: -0.536303, LR: 8.360058
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 293/299 - Signal: 0.681105, Verlust: -0.536694, LR: 8.343338
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 294/299 - Signal: 0.681361, Verlust: -0.537073, LR: 8.326652
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 295/299 - Signal: 0.681603, Verlust: -0.537440, LR: 8.309998
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 296/299 - Signal: 0.681833, Verlust: -0.537796, LR: 8.293378
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 297/299 - Signal: 0.682051, Verlust: -0.538141, LR: 8.276792
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 298/299 - Signal: 0.682259, Verlust: -0.538477, LR: 8.260238
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 299/299 - Signal: 0.682456, Verlust: -0.538804, LR: 8.243718
#   Neuer Bestwert gefunden und gespeichert!
#
# Training abgeschlossen!
# Bestes Signal: 0.682456

# %% [markdown]
# ## Visualisierung der Ergebnisse
#
# Nach Abschluss des Trainings können wir die optimierten Parameter laden und visualisieren.

# %%
# Prüfen, ob optimierte Parameter vorhanden sind (nach dem Training)
if 'best_parameters' in locals():
    # Visualisieren der optimierten Pulse
    visualize_pulses(best_parameters, dtp_rf, f"Optimierter Puls")
    
    # Vergleich mit Original
    with torch.no_grad():
        original_signal = diff_sim(original_pulse_parameters)
        optimized_signal = diff_sim(best_parameters)
        
    print(f"Original-Signal: {original_signal.item():.6f}")
    print(f"Optimiertes Signal: {optimized_signal.item():.6f}")
    
    if abs(original_signal.item()) > 0:
        improvement = (optimized_signal.item() - original_signal.item()) / abs(original_signal.item()) * 100
        print(f"Verbesserung: {improvement:.2f}%")
    
    # Vergleichsplot der Pulsformen
    plt.figure(figsize=(14, 10))
    
    # Für jeden Puls einen eigenen Plot
    for i in range(len(best_parameters)):
        plt.subplot(len(best_parameters), 1, i+1)
        
        # Original-Puls
        pulse_orig = original_pulse_parameters[i][0].detach().cpu().numpy()  # Extrahiere Amplituden des Pulses
        time_axis = np.arange(len(pulse_orig)) * dtp_rf * 1000  # Umrechnung in ms
        plt.plot(time_axis, pulse_orig, 'b-', linewidth=1.5, alpha=0.7, label='Original')
        
        # Optimierter Puls
        pulse_opt = best_parameters[i][0].detach().cpu().numpy()  # Extrahiere Amplituden des Pulses
        plt.plot(time_axis, pulse_opt, 'r-', linewidth=1.5, alpha=0.7, label='Optimiert')
        
        plt.title(f"Vergleich Puls {i+1}" + (" (90°)" if i == 0 else " (180°)" if i == 1 else ""))
        plt.xlabel('Zeit (ms)')
        plt.ylabel('Amplitude')
        plt.grid(True)
        plt.legend()
    
    plt.tight_layout()
else:
    print("Keine optimierten Parameter gefunden. Bitte führe zuerst das Training aus.")
# Out:
# Original-Signal: 0.022125
# Optimiertes Signal: 0.682643
# Verbesserung: 2985.36%

# %% [markdown]
# ## Training von einem Checkpoint fortsetzen
#
# Mit der folgenden Zelle kannst du das Training von einem zuvor gespeicherten Checkpoint aus fortsetzen. Dadurch kannst du ein bereits begonnenes Training weiterlaufen lassen, ohne von vorne beginnen zu müssen.

# %%
def resume_training_from_checkpoint(checkpoint_path, additional_epochs=100):
    """
    Setzt das Training von einem vorhandenen Checkpoint fort.
    
    Args:
        checkpoint_path: Pfad zum Checkpoint-File
        additional_epochs: Anzahl der zusätzlichen Trainingsepochen
    """
    # Parameter und Engine neu initialisieren
    rf_parameters, sim_params, seq_file, z_pos, diff_sim, dtp_rf = get_params()
    
    # Lade die Parameter aus dem Checkpoint
    checkpoint = torch.load(checkpoint_path)
    loaded_parameters = checkpoint['rf_parameters']
    
    # Konvertiere die geladenen Parameter in trainierbare Parameter
    trainable_parameters = []
    for i, [amp, phase] in enumerate(loaded_parameters):
        trainable_amp = amp.detach().clone()
        trainable_amp.requires_grad_(True)
        trainable_parameters.append([trainable_amp, phase.detach().clone()])
    
    # Extrahiere optimierbare Parameter
    optimizable_params = []
    for amp, _ in trainable_parameters:
        optimizable_params.append(amp)
    
    # Initialisiere den Optimizer
    optimizer = torch.optim.Adam(optimizable_params, lr=0.5)
    
    # Optional: Lade den Optimizer-Zustand, falls vorhanden
    if 'optimizer_state_dict' in checkpoint:
        try:
            optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
            print("Optimizer-Zustand erfolgreich geladen")
        except:
            print("Konnte Optimizer-Zustand nicht laden, verwende neu initialisierten Optimizer")
    
    # Lernrate optional anpassen
    for param_group in optimizer.param_groups:
        param_group['lr'] = 20  # Hier kannst du die Lernrate anpassen
    
    # Lernraten-Scheduler
    scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.998)
    
    # Checkpoint-Info ausgeben
    start_epoch = checkpoint['epoch'] + 1
    checkpoint_signal = checkpoint['signal'] if 'signal' in checkpoint else -checkpoint['loss']
    print(f"Training wird fortgesetzt von Epoch {start_epoch} mit Signal: {checkpoint_signal:.6f}")
    
    # Ausgangssignal messen
    with torch.no_grad():
        signal = diff_sim(trainable_parameters)
        print(f"Aktuelles Signal vor Fortsetzung des Trainings: {signal.item():.6f}")
    
    # Erstelle Verzeichnis für die fortgesetzten Checkpoints
    checkpoint_dir = os.path.dirname(checkpoint_path) + '_continued'
    os.makedirs(checkpoint_dir, exist_ok=True)
    
    # Tracking-Variablen
    best_signal = float(signal)
    best_parameters = None
    epochs_list = []
    losses_list = []
    signals_list = []
    learning_rates = []
    
    # Training fortsetzen
    for epoch in range(start_epoch, start_epoch + additional_epochs):
        # Führe die Simulation mit aktuellen Parametern durch
        signal = diff_sim(trainable_parameters)
        
        # Berechne den Verlust mit der angepassten Verlustfunktion
        loss = signal_objective_function(signal, trainable_parameters, 
                                      edge_penalty_weight=0.0001, 
                                      smoothness_weight=0.00001, 
                                      negative_penalty_weight=0.0005)
        
        # Führe Backpropagation durch
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Signal (negierter Verlust ohne Strafe) für die Ausgabe
        pure_signal_value = torch.abs(signal).item()
        
        # Tracking
        epochs_list.append(epoch)
        losses_list.append(loss.item())
        signals_list.append(pure_signal_value)
        current_lr = optimizer.param_groups[0]['lr']
        learning_rates.append(current_lr)
        
        # Ausgabe
        print(f"Epoche {epoch}/{start_epoch + additional_epochs - 1} - Signal: {pure_signal_value:.6f}, ",
              f"Verlust: {loss.item():.6f}, LR: {current_lr:.6f}")
        
        # Speichere den besten Zustand (basierend auf dem reinen Signal)
        if pure_signal_value > best_signal:
            best_signal = pure_signal_value
            best_parameters = []
            for amp, phase in trainable_parameters:
                best_parameters.append([amp.detach().clone(), phase.detach().clone()])
            
            save_checkpoint(
                checkpoint_dir, 
                best_parameters, 
                optimizer, 
                epoch, 
                loss.item(), 
                pure_signal_value,
                checkpoint_name="best_checkpoint.pt",
                dtp_rf=dtp_rf
            )
            print(f"  Neuer Bestwert gefunden und gespeichert!")
        
        # Speichere regelmäßige Checkpoints
        if epoch % 10 == 0 or epoch == start_epoch + additional_epochs - 1:
            current_parameters = []
            for amp, phase in trainable_parameters:
                current_parameters.append([amp.detach().clone(), phase.detach().clone()])
                
            save_checkpoint(
                checkpoint_dir, 
                current_parameters, 
                optimizer, 
                epoch, 
                loss.item(), 
                pure_signal_value,
                dtp_rf=dtp_rf
            )
        
        # Update des Schedulers
        scheduler.step()
    
    # Speichere den finalen Zustand
    final_parameters = []
    for amp, phase in trainable_parameters:
        final_parameters.append([amp.detach().clone(), phase.detach().clone()])
        
    final_path = save_checkpoint(
        checkpoint_dir, 
        final_parameters, 
        optimizer, 
        start_epoch + additional_epochs - 1, 
        losses_list[-1], 
        signals_list[-1],
        checkpoint_name="final_checkpoint.pt"
    )
    
    # Plotte den Fortschritt
    fig = plot_progress(
        epochs_list, 
        losses_list, 
        signals_list,
        save_path=os.path.join(checkpoint_dir, "continued_training_progress.png")
    )
    
    # Visualisiere optimierte Pulse
    visualize_pulses(best_parameters, dtp_rf, "Optimierter Puls (fortgesetzt)")
    
    return best_parameters, best_signal, final_path

# %%
# Um das Training von einem Checkpoint fortzusetzen, führe die folgende Zeile aus
# und passe den Pfad zur Checkpoint-Datei und die Anzahl der zusätzlichen Epochen an

# Beispiel für die Verwendung:
checkpoint_path = 'checkpoints/SE_optimization_163_8_continued/best_checkpoint.pt'  # Pfad zum Checkpoint anpassen

# Das Training mit 200 zusätzlichen Epochen fortsetzen
best_continued_parameters, best_continued_signal, final_continued_path = resume_training_from_checkpoint(checkpoint_path, additional_epochs=200)
# Out:
# Verwende Sequenzdatei: /Users/danielmiksch/JupyterLab/optim/seq_lib/SE.seq
# Verwende Konfigurationsdatei: /Users/danielmiksch/JupyterLab/optim/sim_lib/config_1pool.yaml
# Anzahl der Isochromaten: 501
# RF-Block 2: Form mit 286 Samples, dtp_rf: 7.000000000000001e-06
# RF-Block 4: Form mit 286 Samples, dtp_rf: 7.000000000000001e-06
# Anzahl der RF-Pulse: 2
# RF-Puls 1 Amplitude Form: torch.Size([286])
# RF-Puls 2 Amplitude Form: torch.Size([286])
# Optimizer-Zustand erfolgreich geladen
# Training wird fortgesetzt von Epoch 400 mit Signal: 0.690469
# Aktuelles Signal vor Fortsetzung des Trainings: 0.690500
# Epoche 400/599 - Signal: 0.690500,  Verlust: -0.562699, LR: 20.000000
# Epoche 401/599 - Signal: 0.690554,  Verlust: -0.562927, LR: 19.960000
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 402/599 - Signal: 0.690608,  Verlust: -0.563097, LR: 19.920080
#   Neuer Bestwert gefunden und gespeichert!
# Epoche
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 567/599 - Signal: 0.694159,  Verlust: -0.584135, LR: 14.316287
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 568/599 - Signal: 0.694170,  Verlust: -0.584210, LR: 14.287654
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 569/599 - Signal: 0.694180,  Verlust: -0.584285, LR: 14.259079
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 570/599 - Signal: 0.694191,  Verlust: -0.584359, LR: 14.230561
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 571/599 - Signal: 0.694201,  Verlust: -0.584434, LR: 14.202100
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 572/599 - Signal: 0.694211,  Verlust: -0.584507, LR: 14.173695
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 573/599 - Signal: 0.694221,  Verlust: -0.584581, LR: 14.145348
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 574/599 - Signal: 0.694231,  Verlust: -0.584654, LR: 14.117057
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 575/599 - Signal: 0.694241,  Verlust: -0.584726, LR: 14.088823
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 576/599 - Signal: 0.694251,  Verlust: -0.584798, LR: 14.060646
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 577/599 - Signal: 0.694261,  Verlust: -0.584870, LR: 14.032524
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 578/599 - Signal: 0.694271,  Verlust: -0.584942, LR: 14.004459
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 579/599 - Signal: 0.694281,  Verlust: -0.585013, LR: 13.976450
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 580/599 - Signal: 0.694291,  Verlust: -0.585084, LR: 13.948497
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 581/599 - Signal: 0.694300,  Verlust: -0.585155, LR: 13.920600
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 582/599 - Signal: 0.694310,  Verlust: -0.585225, LR: 13.892759
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 583/599 - Signal: 0.694320,  Verlust: -0.585295, LR: 13.864974
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 584/599 - Signal: 0.694329,  Verlust: -0.585364, LR: 13.837244
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 585/599 - Signal: 0.694339,  Verlust: -0.585433, LR: 13.809569
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 586/599 - Signal: 0.694348,  Verlust: -0.585502, LR: 13.781950
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 587/599 - Signal: 0.694357,  Verlust: -0.585571, LR: 13.754386
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 588/599 - Signal: 0.694367,  Verlust: -0.585639, LR: 13.726877
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 589/599 - Signal: 0.694376,  Verlust: -0.585707, LR: 13.699424
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 590/599 - Signal: 0.694385,  Verlust: -0.585774, LR: 13.672025
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 591/599 - Signal: 0.694394,  Verlust: -0.585841, LR: 13.644681
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 592/599 - Signal: 0.694403,  Verlust: -0.585908, LR: 13.617391
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 593/599 - Signal: 0.694412,  Verlust: -0.585975, LR: 13.590157
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 594/599 - Signal: 0.694421,  Verlust: -0.586041, LR: 13.562976
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 595/599 - Signal: 0.694430,  Verlust: -0.586107, LR: 13.535850
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 596/599 - Signal: 0.694439,  Verlust: -0.586173, LR: 13.508779
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 597/599 - Signal: 0.694447,  Verlust: -0.586238, LR: 13.481761
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 598/599 - Signal: 0.694456,  Verlust: -0.586303, LR: 13.454798
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 599/599 - Signal: 0.694465,  Verlust: -0.586368, LR: 13.427888
#   Neuer Bestwert gefunden und gespeichert!

# %%
from bmc.utils.eval import calculate_flip_angle
calculated_flip_angle_1 = calculate_flip_angle(best_parameters[0][0], dtp_rf)
calculated_flip_angle_2 = calculate_flip_angle(best_parameters[1][0], dtp_rf)

print(f"Calculated Flip angle Pulse 1: {calculated_flip_angle_1:.2f}°")
print(f"Calculated Flip angle Pulse 2: {calculated_flip_angle_2:.2f}°")
# Out:
# Calculated Flip angle Pulse 1: 261.77°
# Calculated Flip angle Pulse 2: 168.87°
