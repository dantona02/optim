# %% [markdown]
# # Sinc-Puls-Optimierung
#
# Dieses Notebook implementiert eine vereinfachte Version der Pulsoptimierung für einen Sinc-Puls in der Sequenzdatei "sinc.seq". Im Gegensatz zur ursprünglichen `training.py` optimieren wir hier direkt das Signal zu Beginn des ADC-Events (`n_backlog=0`) anstelle einer Signaldifferenz.

# %% [markdown]
# ## Importieren der erforderlichen Bibliotheken

# %%
import os
import json
import torch
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from datetime import datetime

from bmc.fid.engine import BMCSim
# Importiere den neuen SingleSimBMCWrapper statt des DifferentiableBMCSimWrapper
from bmc.optimize.gauss_optimization.single_sim_optimizer import SingleSimBMCWrapper
from bmc.bmc_tool import prep_rf_simulation, prep_grad_simulation
from bmc.set_params import load_params
from bmc.utils.global_device import GLOBAL_DEVICE

# Aktiviere interaktive Plots

# %% [markdown]
# ## Hilfsfunktionen definieren

# %%
def signal_objective_function(signal, rf_parameters=None, edge_penalty_weight=0.0, smoothness_weight=0.0, negative_penalty_weight=0.0):
    """
    Berechnet den Zielwert für die Optimierung des Signals.
    Wir maximieren das Signal, also ist das Ziel, den negativen Signalwert zu minimieren.
    Mit optionaler Strafe für Nicht-Null-Werte an den Enden des Pulses.
    
    Args:
        signal: Signal-Tensor
        rf_parameters: Liste der RF-Parameter [amp, phase] (optional)
        edge_penalty_weight: Gewichtung für die Strafe auf Nicht-Null-Enden (0.0 = deaktiviert)
        smoothness_weight: Gewichtung für die Glättung der Pulsform (0.0 = deaktiviert)
        negative_penalty_weight: Gewichtung für die Bestrafung negativer Amplitudenwerte (0.0 = deaktiviert)
        
    Returns:
        Verlust: Negatives Signal (+ ggf. Strafen)
    """
    # Bei der Optimierung wollen wir den Betrag des Signals maximieren
    signal_loss = -torch.abs(signal)
    
    total_penalty = 0.0
    
    # Wenn rf_parameters übergeben wurden, Strafen anwenden
    if rf_parameters is not None:
        # Strafe für Nicht-Null-Enden
        if edge_penalty_weight > 0:
            edge_penalty = 0.0
            for amp, _ in rf_parameters:
                # Berechne Strafe für die ersten und letzten N Samples
                n_samples = 10  # Anzahl der Samples am Anfang und Ende, die nahe bei 0 sein sollen
                first_samples = amp[:n_samples]  # Erste N Samples
                last_samples = amp[-n_samples:]  # Letzte N Samples
                
                # Strafe berechnen (quadratisch, um größere Abweichungen stärker zu bestrafen)
                edge_penalty += torch.sum(first_samples**2) + torch.sum(last_samples**2)
            
            total_penalty += edge_penalty_weight * edge_penalty
        
        # Strafe für nicht-glatte Übergänge
        if smoothness_weight > 0:
            smoothness_penalty = 0.0
            for amp, _ in rf_parameters:
                # Berechne die Differenzen zwischen aufeinanderfolgenden Samples
                diffs = amp[1:] - amp[:-1]
                
                # Bestrafe große Unterschiede (quadratisch)
                smoothness_penalty += torch.sum(diffs**2)
            
            total_penalty += smoothness_weight * smoothness_penalty
        
        # NEU: Strafe für negative Amplitudenwerte
        if negative_penalty_weight > 0:
            negative_penalty = 0.0
            for amp, _ in rf_parameters:
                # Finde alle negativen Werte (ReLU negiert)
                negative_values = torch.nn.functional.relu(-amp)
                # Quadratische Strafe für negative Werte
                negative_penalty += torch.sum(negative_values**2)
            
            total_penalty += negative_penalty_weight * negative_penalty
    
    return signal_loss + total_penalty

def save_checkpoint(checkpoint_dir, rf_parameters, optimizer, epoch, loss, signal, 
                  checkpoint_name=None, dtp_rf=None):
    """
    Speichert einen Checkpoint mit allen relevanten Trainingsparametern.
    
    Args:
        checkpoint_dir: Verzeichnis zum Speichern des Checkpoints
        rf_parameters: Liste der RF-Parameter [amp, phase]
        optimizer: Der Optimierer
        epoch: Aktuelle Epoche
        loss: Aktueller Verlustwert
        signal: Aktuelles Signal
        checkpoint_name: Optional, Name des Checkpoint-Files
        dtp_rf: Sampling-Zeit des RF-Pulses (wichtig für korrekte Rekonstruktion)
    """
    if checkpoint_name is None:
        checkpoint_name = f"checkpoint_epoch_{epoch}.pt"
    
    # Erstelle Checkpoint-Verzeichnis, falls es nicht existiert
    os.makedirs(checkpoint_dir, exist_ok=True)
    
    # Bereite RF-Parameter für die Speicherung vor
    rf_param_state = []
    for amp, phase in rf_parameters:
        rf_param_state.append([amp.detach().clone(), phase.detach().clone()])
    
    # Erstelle Checkpoint-Dictionary
    checkpoint = {
        'epoch': epoch,
        'rf_parameters': rf_param_state,
        'optimizer_state_dict': optimizer.state_dict(),
        'loss': loss,
        'signal': signal
    }
    
    # Speichere die Puls-Parameter, wenn vorhanden
    if dtp_rf is not None:
        checkpoint['parameters'] = {
            'dt': float(dtp_rf),  # Sampling-Zeit (sehr wichtig für die korrekte Verwendung des Pulses)
            'num_samples': len(rf_parameters[0][0]) if rf_parameters else 0  # Anzahl der Samples im Puls
        }
    
    # Speichere Checkpoint
    checkpoint_path = os.path.join(checkpoint_dir, checkpoint_name)
    torch.save(checkpoint, checkpoint_path)
    
    # Speichere zusätzliche Metadaten
    metadata = {
        'timestamp': datetime.now().isoformat(),
        'epoch': epoch,
        'loss': float(loss),
        'signal': float(signal)
    }
    # Füge dt zu den Metadaten hinzu
    if dtp_rf is not None:
        metadata['dt'] = float(dtp_rf)
    
    metadata_path = os.path.join(checkpoint_dir, 'sinc_training_metadata.json')
    with open(metadata_path, 'w') as f:
        json.dump(metadata, f, indent=4)
    
    return checkpoint_path

def load_checkpoint(checkpoint_path, optimizer=None):
    """
    Lädt einen Checkpoint und stellt den Trainingszustand wieder her.
    """
    if not os.path.exists(checkpoint_path):
        raise FileNotFoundError(f"Checkpoint-Datei {checkpoint_path} wurde nicht gefunden.")
    
    checkpoint = torch.load(checkpoint_path)
    
    # RF-Parameter laden
    rf_parameters = checkpoint['rf_parameters']
    
    # Optimierer-Zustand laden, falls vorhanden
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    
    return rf_parameters, checkpoint['epoch'], checkpoint['loss'], checkpoint['signal']

def plot_progress(epochs, losses, signals, save_path=None):
    """
    Plottet den Fortschritt des Trainings.
    """
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8), sharex=True)
    
    # Plot für Verlust
    ax1.plot(epochs, losses, 'b-', marker='o')
    ax1.set_ylabel('Verlust')
    ax1.set_title('Trainingsverlauf')
    ax1.grid(True)
    
    # Plot für Signal
    ax2.plot(epochs, signals, 'r-', marker='o')
    ax2.set_xlabel('Epoche')
    ax2.set_ylabel('Signal')
    ax2.grid(True)
    
    plt.tight_layout()
    
    if save_path:
        plt.savefig(save_path)
    
    return fig

# %% [markdown]
# ## Initialisierung der Parameter und Simulationsumgebung
#
# Wir verwenden die Sequenzdatei "sinc.seq" für unsere Optimierung. Diese enthält einen Sinc-Puls mit einem Flipwinkel von 30°.

# %%
def get_params():
    """
    Initialisiert die Parameter für das Training.
    """
    base_dir = Path().resolve().parent.parent.parent
    config_file = base_dir / "sim_lib" / "config_1pool.yaml"
    seq_file = base_dir / "seq_lib" / "sinc.seq"  # Hier verwenden wir die sinc.seq Datei

    if not Path(config_file).exists():
        raise FileNotFoundError(f"Konfigurationsdatei {config_file} nicht gefunden.")

    if not Path(seq_file).exists():
        raise FileNotFoundError(f"Sequenzdatei {seq_file} nicht gefunden.")
    
    print(f"Verwende Sequenzdatei: {seq_file}")
    print(f"Verwende Konfigurationsdatei: {config_file}")
    
    sim_params = load_params(config_file)

    # Erstelle Positionen für die Simulation
    low = -1e-3
    high = 1e-3
    n_iso = 100
    z_pos = np.linspace(low, high, n_iso)
    z_pos = torch.tensor(z_pos)
    z_pos = torch.cat((z_pos, torch.tensor([0.0]))) 
    
    print(f"Anzahl der Isochromaten: {len(z_pos)}")

    # Initialisiere Simulationsengine mit n_backlog=0 für Signal am Beginn des ADC
    sim_engine_instance = BMCSim(adc_time=5e-3,
                                params=sim_params,
                                seq_file=seq_file,
                                z_positions=z_pos,
                                n_backlog=0,  # Wichtig: Signal am Beginn des ADC
                                verbose=True,
                                webhook=False)
    
    # Verwende den neuen SingleSimBMCWrapper
    diff_sim = SingleSimBMCWrapper(sim_engine_instance)
    
    # Extrahiere RF-Parameter aus der Sequenz
    rf_parameters = []  # Liste für [amp, phase] Paare
    dtp_rf = None
    
    for i, block_event in enumerate(diff_sim.sim_engine.seq.block_events, start=1):
        block = sim_engine_instance.seq.get_block(block_event)
        if block.rf:
            if hasattr(block, "block_duration") and block.block_duration != "0":
                amp_, ph_, dtp_rf, delay_after_pulse = prep_rf_simulation(
                    block, sim_engine_instance.params.options["max_pulse_samples"])
                print(f"RF-Block {i}: Form mit {len(amp_)} Samples, dtp_rf: {dtp_rf}")
                
                # Wichtig: Die originalen Phasenwerte beibehalten!
                # ph_ enthält bereits die korrekten Phasenwerte aus prep_rf_simulation
                
                # Aktiviere Gradienten für Amplituden
                amp_.requires_grad_(True)
                
                # Füge das [amp, phase] Paar zur Liste hinzu
                rf_parameters.append([amp_, ph_])

    if not rf_parameters:
        raise ValueError("Keine RF-Blöcke in der Sequenz gefunden.")
    
    print(f"Anzahl der RF-Pulse: {len(rf_parameters)}")
    print(f"RF-Puls 1 Amplitude Form: {rf_parameters[0][0].shape}")
    print(f"RF-Puls 1 Phase Form: {rf_parameters[0][1].shape}")
    
    return rf_parameters, sim_params, seq_file, z_pos, diff_sim, dtp_rf

# Parameter holen
rf_parameters, sim_params, seq_file, z_pos, diff_sim, dtp_rf = get_params()
# Out:
# Verwende Sequenzdatei: /Users/danielmiksch/JupyterLab/optim/seq_lib/sinc.seq
# Verwende Konfigurationsdatei: /Users/danielmiksch/JupyterLab/optim/sim_lib/config_1pool.yaml
# Anzahl der Isochromaten: 101
# RF-Block 2: Form mit 286 Samples, dtp_rf: 7.000000000000001e-06
# Anzahl der RF-Pulse: 1
# RF-Puls 1 Amplitude Form: torch.Size([286])
# RF-Puls 1 Phase Form: torch.Size([286])

# %% [markdown]
# ## Visualisierung des ursprünglichen Sinc-Pulses
#
# Bevor wir mit der Optimierung beginnen, wollen wir uns die aktuelle Form des RF-Pulses ansehen.

# %%
def visualize_pulse(parameters, dtp, title="RF-Puls"):
    """
    Visualisiert einen RF-Puls.
    """
    # Nehmen wir an, dass der RF-Puls im ersten Block ist
    # Extrahiere nur die Amplituden aus den Parametern (erstes Element des ersten Pulses)
    pulse = parameters[0][0].detach().cpu().numpy()
    time_axis = np.arange(len(pulse)) * dtp * 1000  # Umrechnung in ms
    
    plt.figure(figsize=(10, 5))
    plt.plot(time_axis, pulse, 'b-', linewidth=2)
    plt.title(title)
    plt.xlabel('Zeit (ms)')
    plt.ylabel('Amplitude')
    plt.grid(True)
    plt.tight_layout()
    # return plt.gcf()

# Original-Puls visualisieren
visualize_pulse(rf_parameters, dtp_rf, "Originaler Sinc-Puls (sinc.seq)")

# %% [markdown]
# ## Simulieren des ursprünglichen Signals
#
# Bevor wir mit der Optimierung beginnen, wollen wir das aktuelle Signal messen.

# %%
with torch.no_grad():
    # RF-Parameter direkt an diff_sim übergeben
    original_signal = diff_sim(rf_parameters)

print(f"Signal des Original-Pulses: {original_signal.item():.6f}")

# Den ursprünglichen Puls für späteren Vergleich speichern
original_pulse_parameters = []
for amp, phase in rf_parameters:
    original_pulse_parameters.append([amp.detach().clone(), phase.detach().clone()])
# Out:
# Signal des Original-Pulses: 0.633630

# %% [markdown]
# ## Training des RF-Pulses
#
# Jetzt führen wir das Training durch, um den Sinc-Puls zu optimieren.

# %%
def initialize_custom_rf_pulse(original_rf_parameters, init_method='random', scaling_factor=0.5):
    """
    Initialisiert einen RF-Puls mit verschiedenen Methoden, um dem Optimierer mehr Freiheit zu geben.
    
    Args:
        original_rf_parameters: Die ursprünglichen RF-Parameter als Liste von [amp, phase] Paaren
        init_method: Methode zur Initialisierung ('random', 'flat', 'sine', 'mixed', 'original')
        scaling_factor: Skalierungsfaktor für die Amplitude (für 'random', 'sine', 'mixed')
        
    Returns:
        Neue RF-Parameter mit initialisierter Pulsform
    """
    custom_rf_parameters = []
    
    for i, [amp, phase] in enumerate(original_rf_parameters):
        # Behalte die ursprüngliche Phase bei
        new_phase = phase.clone().detach()
        
        # Hole die Dimensionen des originalen Pulses
        pulse_length = len(amp)
        max_amp_value = torch.max(amp).item()
        
        # Initialisierung je nach gewählter Methode
        if init_method == 'random':
            # Zufällige Initialisierung (gleichmäßig verteilt)
            new_amp = torch.rand_like(amp) * max_amp_value * scaling_factor
            
        elif init_method == 'flat':
            # Flache Initialisierung (konstante Amplitude)
            mean_amp = torch.mean(amp).item()
            new_amp = torch.ones_like(amp) * mean_amp
            
        elif init_method == 'sine':
            # Sinus-Initialisierung (eine andere Form als Gauß)
            x = torch.linspace(0, 2*torch.pi, pulse_length, device=amp.device, dtype=amp.dtype)
            new_amp = torch.sin(x) * max_amp_value * scaling_factor
            # Stelle sicher, dass die Werte positiv sind
            new_amp = torch.abs(new_amp)
            
        elif init_method == 'mixed':
            # Mischung aus Original und Zufälligkeit
            random_component = torch.rand_like(amp) * max_amp_value * scaling_factor
            # Das Original detachen, um den Berechnungsgraph zu trennen
            original_component = amp.clone().detach() * (1 - scaling_factor)
            new_amp = random_component + original_component
            
        else:  # 'original' oder andere Werte
            # Behalte die ursprüngliche Form bei
            new_amp = amp.clone().detach()
        
        # WICHTIG: Stellen Sie sicher, dass wir ein Blatt-Tensor haben (detach)
        # und eine neue Kopie erstellen (clone)
        new_amp = new_amp.detach().clone()
        # Dann erst kann requires_grad aktiviert werden
        new_amp.requires_grad_(True)
        
        # Füge das neue Paar zur Liste hinzu
        custom_rf_parameters.append([new_amp, new_phase])
    
    return custom_rf_parameters

def train(rf_parameters, diff_sim, num_epochs=50, learning_rate=0.1, 
          edge_penalty_weight=0.0001, smoothness_weight=0.0001, negative_penalty_weight=0.0001,
          checkpoint_dir='checkpoints/sinc_30seq', checkpoint_frequency=5,
          init_method='original', custom_init_scaling=0.5, lr_decay=0.995,
          momentum=0.9, use_scheduler=True, use_adam=True):
    """
    Führt das Training für die RF-Puls-Optimierung durch mit erweiterten Optionen.
    
    Args:
        rf_parameters: Liste von [amp, phase] Paaren
        diff_sim: Simulationsinstanz (SingleSimBMCWrapper)
        num_epochs: Anzahl der Trainingsepochen
        learning_rate: Lernrate für den Optimierer
        edge_penalty_weight: Gewichtung der Strafe für Nicht-Null-Enden des Pulses
        smoothness_weight: Gewichtung der Strafe für glatte Übergänge
        negative_penalty_weight: Gewichtung der Strafe für negative Amplitudenwerte
        checkpoint_dir: Verzeichnis für Checkpoints
        checkpoint_frequency: Nach wievielen Epochen ein Checkpoint gespeichert wird
        init_method: Methode zur Initialisierung des RF-Pulses
        custom_init_scaling: Skalierungsfaktor für die benutzerdefinierte Initialisierung
        lr_decay: Faktor für die Lernratenabnahme bei Verwendung eines Schedulers
        momentum: Momentum für SGD-Optimierer (falls use_adam=False)
        use_scheduler: Ob ein Lernraten-Scheduler verwendet werden soll
        use_adam: Ob Adam statt SGD verwendet werden soll
    """
    # Initialisiere RF-Parameter mit der gewählten Methode, falls nicht 'original'
    if init_method != 'original':
        rf_parameters = initialize_custom_rf_pulse(rf_parameters, init_method, custom_init_scaling)
        print(f"RF-Puls mit Methode '{init_method}' neu initialisiert, Skalierungsfaktor: {custom_init_scaling}")
    
    # Extrahiere optimierbare Parameter aus der Liste von [amp, phase] Paaren
    optimizable_params = []
    
    for i, [amp, phase] in enumerate(rf_parameters):
        # Sicherstellen, dass amp ein Blatt-Tensor ist
        optimizable_params.append(amp)
    
    # Checkpoint-Verzeichnis erstellen
    os.makedirs(checkpoint_dir, exist_ok=True)
    
    # Initialisiere den Optimierer
    if use_adam:
        optimizer = torch.optim.Adam(optimizable_params, lr=learning_rate)
    else:
        optimizer = torch.optim.SGD(optimizable_params, lr=learning_rate, momentum=momentum)
    
    # Optional: Lernraten-Scheduler
    scheduler = None
    if use_scheduler:
        scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=lr_decay)
    
    # Variablen für Tracking
    best_signal = float('-inf')
    best_parameters = None
    epochs_list = []
    losses_list = []
    signals_list = []
    learning_rates = []
    
    # Trainingsschleife
    for epoch in range(num_epochs):
        # Führe die Simulation mit aktuellen Parametern durch
        signal = diff_sim(rf_parameters)
        
        # Berechne den Verlust mit der angepassten Verlustfunktion
        loss = signal_objective_function(signal, rf_parameters, edge_penalty_weight, smoothness_weight, negative_penalty_weight)
        
        # Führe Backpropagation durch
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Signal (negierter Verlust ohne Strafe) für die Ausgabe
        pure_signal_value = torch.abs(signal).item()
        
        # Tracking
        epochs_list.append(epoch)
        losses_list.append(loss.item())
        signals_list.append(pure_signal_value)
        current_lr = optimizer.param_groups[0]['lr']
        learning_rates.append(current_lr)
        
        # Ausgabe
        print(f"Epoche {epoch}/{num_epochs - 1} - Signal: {pure_signal_value:.6f}, Verlust: {loss.item():.6f}, LR: {current_lr:.6f}")
        
        # Speichere den besten Zustand (basierend auf dem reinen Signal)
        if pure_signal_value > best_signal:
            best_signal = pure_signal_value
            # Klonen der aktuellen Parameter
            best_parameters = []
            for amp, phase in rf_parameters:
                best_parameters.append([amp.detach().clone(), phase.detach().clone()])
            
            save_checkpoint(
                checkpoint_dir, 
                best_parameters, 
                optimizer, 
                epoch, 
                loss.item(), 
                pure_signal_value,
                checkpoint_name="best_checkpoint.pt",
                dtp_rf=dtp_rf  # Übergebe die Sampling-Zeit
            )
            print(f"  Neuer Bestwert gefunden und gespeichert!")
        
        # Speichere regelmäßige Checkpoints
        if epoch % checkpoint_frequency == 0 or epoch == num_epochs - 1:
            current_parameters = []
            for amp, phase in rf_parameters:
                current_parameters.append([amp.detach().clone(), phase.detach().clone()])
                
            save_checkpoint(
                checkpoint_dir, 
                current_parameters, 
                optimizer, 
                epoch, 
                loss.item(), 
                pure_signal_value,
                dtp_rf=dtp_rf  # Übergebe die Sampling-Zeit
            )
            
        # Update des Schedulers, falls verwendet
        if scheduler and epoch < num_epochs - 1:  # Nicht im letzten Epoch aktualisieren
            scheduler.step()
    
    # Speichere den finalen Zustand
    final_parameters = []
    for amp, phase in rf_parameters:
        final_parameters.append([amp.detach().clone(), phase.detach().clone()])
        
    final_path = save_checkpoint(
        checkpoint_dir, 
        final_parameters, 
        optimizer, 
        num_epochs - 1, 
        losses_list[-1], 
        signals_list[-1],
        checkpoint_name="final_checkpoint.pt"
    )
    
    # Plotte den Fortschritt
    fig = plot_progress(
        epochs_list, 
        losses_list, 
        signals_list,
        save_path=os.path.join(checkpoint_dir, "training_progress.png")
    )
    
    # Zusätzlichen Plot für die Lernraten erstellen
    plt.figure(figsize=(10, 5))
    plt.plot(epochs_list, learning_rates, 'g-')
    plt.title('Lernratenentwicklung')
    plt.xlabel('Epoche')
    plt.ylabel('Lernrate')
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(os.path.join(checkpoint_dir, "learning_rate_progress.png"))
    
    print("\nTraining abgeschlossen!")
    print(f"Bestes Signal: {best_signal:.6f}")
    
    return best_parameters, best_signal, final_path, fig

# Training ausführen mit den neuen freieren Parametern
# Versuchen wir jetzt mit einer völlig anderen Initialisierung
best_parameters, best_signal, final_checkpoint_path, progress_plot = train(
    rf_parameters, diff_sim, 
    num_epochs=500,
    learning_rate=1.0,
    edge_penalty_weight=0.0005,
    smoothness_weight=0.0001,
    negative_penalty_weight=0.0005,  # Gewichtung für die Bestrafung negativer Amplitudenwerte
    init_method='original',  # Starte mit der ursprünglichen Form
    custom_init_scaling=1.0,  # Volle Amplitude für maximale Änderung
    lr_decay=0.998,
    use_scheduler=True,
    use_adam=True,
    checkpoint_frequency=10
)
# Out:
# Epoche 0/499 - Signal: 0.633630, Verlust: 0.616239, LR: 1.000000
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 1/499 - Signal: 0.642876, Verlust: 0.442328, LR: 0.998000
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 1/499 - Signal: 0.642876, Verlust: 0.442328, LR: 0.998000
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 2/499 - Signal: 0.651945, Verlust: 0.287211, LR: 0.996004
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 2/499 - Signal: 0.651945, Verlust: 0.287211, LR: 0.996004
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 3/499 - Signal: 0.660751, Verlust: 0.150954, LR: 0.994012
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 3/499 - Signal: 0.660751, Verlust: 0.150954, LR: 0.994012
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 4/499 - Signal: 0.669055, Verlust: 0.033821, LR: 0.992024
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 4/499 - Signal: 0.669055, Verlust: 0.033821, LR: 0.992024
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 5/499 - Signal: 0.676834, Verlust: -0.068962, LR: 0.990040
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 5/499 - Signal: 0.676834, Verlust: -0.068962, LR: 0.990040
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 6/499 - Signal: 0.684212, Verlust: -0.156420, LR: 0.988060
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 6/499 - Signal: 0.684212, Verlust: -0.156420, LR: 0.988060
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 7/499 - Signal: 0.691283, Verlust: -0.230874, LR: 0.986084
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 7/499 - Signal: 0.691283, Verlust: -0.230874, LR: 0.986084
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 8/499 - Signal: 0.698103, Verlust: -0.293507, LR: 0.984112
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 8/499 - Signal: 0.698103, Verlust: -0.293507, LR: 0.984112
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 9/499 - Signal: 0.704586, Verlust: -0.345324, LR: 0.982143
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 9/499 - Signal: 0.704586, Verlust: -0.345324, LR: 0.982143
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 10/499 - Signal: 0.710818, Verlust: -0.388103, LR: 0.980179
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 10/499 - Signal: 0.710818, Verlust: -0.388103, LR: 0.980179
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 11/499 - Signal: 0.716807, Verlust: -0.422761, LR: 0.978219
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 11/499 - Signal: 0.716807, Verlust: -0.422761, LR: 0.978219
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 12/499 - Signal: 0.722607, Verlust: -0.450744, LR: 0.976262
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 12/499 - Signal: 0.722607, Verlust: -0.450744, LR: 0.976262
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 13/499 - Signal: 0.728223, Verlust: -0.473120, LR: 0.974310
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 13/499 - Signal: 0.728223, Verlust: -0.473120, LR: 0.974310
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 14/499 - Signal: 0.733637, Verlust: -0.490641, LR: 0.972361
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 14/499 - Signal: 0.733637, Verlust: -0.490641, LR: 0.972361
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 15/499 - Signal: 0.738848, Verlust: -0.504384, LR: 0.970416
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 15/499 - Signal: 0.738848, Verlust: -0.504384, LR: 0.970416
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 16/499 - Signal: 0.743867, Verlust: -0.515267, LR: 0.968476
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 16/499 - Signal: 0.743867, Verlust: -0.515267, LR: 0.968476
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 17/499 - Signal: 0.748715, Verlust: -0.524033, LR: 0.966539
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 17/499 - Signal: 0.748715, Verlust: -0.524033, LR: 0.966539
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 18/499 - Signal: 0.753394, Verlust: -0.531078, LR: 0.964606
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 18/499 - Signal: 0.753394, Verlust: -0.531078, LR: 0.964606
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 19/499 - Signal: 0.757912, Verlust: -0.536893, LR: 0.962676
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 19/499 - Signal: 0.757912, Verlust: -0.536893, LR: 0.962676
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 20/499 - Signal: 0.762275, Verlust: -0.542012, LR: 0.960751
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 20/499 - Signal: 0.762275, Verlust: -0.542012, LR: 0.960751
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 21/499 - Signal: 0.766494, Verlust: -0.546894, LR: 0.958829
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 21/499 - Signal: 0.766494, Verlust: -0.546894, LR: 0.958829
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 22/499 - Signal: 0.770574, Verlust: -0.551671, LR: 0.956912
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 22/499 - Signal: 0.770574, Verlust: -0.551671, LR: 0.956912
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 23/499 - Signal: 0.774498, Verlust: -0.556619, LR: 0.954998
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 23/499 - Signal: 0.774498, Verlust: -0.556619, LR: 0.954998
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 24/499 - Signal: 0.778270, Verlust: -0.561894, LR: 0.953088
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 24/499 - Signal: 0.778270, Verlust: -0.561894, LR: 0.953088
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 25/499 - Signal: 0.781910, Verlust: -0.567675, LR: 0.951182
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 25/499 - Signal: 0.781910, Verlust: -0.567675, LR: 0.951182
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 26/499 - Signal: 0.785403, Verlust: -0.573953, LR: 0.949279
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 26/499 - Signal: 0.785403, Verlust: -0.573953, LR: 0.949279
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 27/499 - Signal: 0.788763, Verlust: -0.580693, LR: 0.947381
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 27/499 - Signal: 0.788763, Verlust: -0.580693, LR: 0.947381
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 28/499 - Signal: 0.792003, Verlust: -0.587775, LR: 0.945486
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 28/499 - Signal: 0.792003, Verlust: -0.587775, LR: 0.945486
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 29/499 - Signal: 0.795137, Verlust: -0.595025, LR: 0.943595
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 29/499 - Signal: 0.795137, Verlust: -0.595025, LR: 0.943595
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 30/499 - Signal: 0.798168, Verlust: -0.602265, LR: 0.941708
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 30/499 - Signal: 0.798168, Verlust: -0.602265, LR: 0.941708
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 31/499 - Signal: 0.801099, Verlust: -0.609315, LR: 0.939825
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 31/499 - Signal: 0.801099, Verlust: -0.609315, LR: 0.939825
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 32/499 - Signal: 0.803941, Verlust: -0.616025, LR: 0.937945
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 32/499 - Signal: 0.803941, Verlust: -0.616025, LR: 0.937945
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 33/499 - Signal: 0.806705, Verlust: -0.622294, LR: 0.936069
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 33/499 - Signal: 0.806705, Verlust: -0.622294, LR: 0.936069
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 34/499 - Signal: 0.809394, Verlust: -0.628042, LR: 0.934197
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 34/499 - Signal: 0.809394, Verlust: -0.628042, LR: 0.934197
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 35/499 - Signal: 0.812001, Verlust: -0.633272, LR: 0.932328
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 35/499 - Signal: 0.812001, Verlust: -0.633272, LR: 0.932328
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 36/499 - Signal: 0.814528, Verlust: -0.637944, LR: 0.930464
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 36/499 - Signal: 0.814528, Verlust: -0.637944, LR: 0.930464
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 37/499 - Signal: 0.816988, Verlust: -0.642072, LR: 0.928603
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 37/499 - Signal: 0.816988, Verlust: -0.642072, LR: 0.928603
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 38/499 - Signal: 0.819383, Verlust: -0.645738, LR: 0.926746
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 38/499 - Signal: 0.819383, Verlust: -0.645738, LR: 0.926746
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 39/499 - Signal: 0.821715, Verlust: -0.649101, LR: 0.924892
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 39/499 - Signal: 0.821715, Verlust: -0.649101, LR: 0.924892
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 40/499 - Signal: 0.823983, Verlust: -0.652210, LR: 0.923042
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 40/499 - Signal: 0.823983, Verlust: -0.652210, LR: 0.923042
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 41/499 - Signal: 0.826188, Verlust: -0.655103, LR: 0.921196
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 41/499 - Signal: 0.826188, Verlust: -0.655103, LR: 0.921196
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 42/499 - Signal: 0.828332, Verlust: -0.657830, LR: 0.919354
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 42/499 - Signal: 0.828332, Verlust: -0.657830, LR: 0.919354
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 43/499 - Signal: 0.830407, Verlust: -0.660461, LR: 0.917515
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 43/499 - Signal: 0.830407, Verlust: -0.660461, LR: 0.917515
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 44/499 - Signal: 0.832405, Verlust: -0.663044, LR: 0.915680
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 44/499 - Signal: 0.832405, Verlust: -0.663044, LR: 0.915680
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 45/499 - Signal: 0.834348, Verlust: -0.665540, LR: 0.913849
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 45/499 - Signal: 0.834348, Verlust: -0.665540, LR: 0.913849
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 46/499 - Signal: 0.836247, Verlust: -0.667994, LR: 0.912021
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 46/499 - Signal: 0.836247, Verlust: -0.667994, LR: 0.912021
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 47/499 - Signal: 0.838095, Verlust: -0.670401, LR: 0.910197
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 47/499 - Signal: 0.838095, Verlust: -0.670401, LR: 0.910197
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 48/499 - Signal: 0.839891, Verlust: -0.672738, LR: 0.908377
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 48/499 - Signal: 0.839891, Verlust: -0.672738, LR: 0.908377
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 49/499 - Signal: 0.841624, Verlust: -0.674980, LR: 0.906560
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 49/499 - Signal: 0.841624, Verlust: -0.674980, LR: 0.906560
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 50/499 - Signal: 0.843287, Verlust: -0.677164, LR: 0.904747
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 50/499 - Signal: 0.843287, Verlust: -0.677164, LR: 0.904747
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 51/499 - Signal: 0.844880, Verlust: -0.679302, LR: 0.902937
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 51/499 - Signal: 0.844880, Verlust: -0.679302, LR: 0.902937
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 52/499 - Signal: 0.846413, Verlust: -0.681322, LR: 0.901131
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 52/499 - Signal: 0.846413, Verlust: -0.681322, LR: 0.901131
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 53/499 - Signal: 0.847892, Verlust: -0.683216, LR: 0.899329
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 53/499 - Signal: 0.847892, Verlust: -0.683216, LR: 0.899329
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 54/499 - Signal: 0.849315, Verlust: -0.684968, LR: 0.897531
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 54/499 - Signal: 0.849315, Verlust: -0.684968, LR: 0.897531
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 55/499 - Signal: 0.850670, Verlust: -0.686833, LR: 0.895735
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 55/499 - Signal: 0.850670, Verlust: -0.686833, LR: 0.895735
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 56/499 - Signal: 0.851954, Verlust: -0.688368, LR: 0.893944
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 56/499 - Signal: 0.851954, Verlust: -0.688368, LR: 0.893944
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 57/499 - Signal: 0.853162, Verlust: -0.689606, LR: 0.892156
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 57/499 - Signal: 0.853162, Verlust: -0.689606, LR: 0.892156
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 58/499 - Signal: 0.854281, Verlust: -0.690892, LR: 0.890372
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 58/499 - Signal: 0.854281, Verlust: -0.690892, LR: 0.890372
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 59/499 - Signal: 0.855292, Verlust: -0.692144, LR: 0.888591
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 59/499 - Signal: 0.855292, Verlust: -0.692144, LR: 0.888591
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 60/499 - Signal: 0.856203, Verlust: -0.693231, LR: 0.886814
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 60/499 - Signal: 0.856203, Verlust: -0.693231, LR: 0.886814
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 61/499 - Signal: 0.857039, Verlust: -0.694169, LR: 0.885040
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 61/499 - Signal: 0.857039, Verlust: -0.694169, LR: 0.885040
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 62/499 - Signal: 0.857821, Verlust: -0.695249, LR: 0.883270
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 62/499 - Signal: 0.857821, Verlust: -0.695249, LR: 0.883270
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 63/499 - Signal: 0.858553, Verlust: -0.696095, LR: 0.881504
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 63/499 - Signal: 0.858553, Verlust: -0.696095, LR: 0.881504
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 64/499 - Signal: 0.859244, Verlust: -0.696789, LR: 0.879741
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 64/499 - Signal: 0.859244, Verlust: -0.696789, LR: 0.879741
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 65/499 - Signal: 0.859918, Verlust: -0.697525, LR: 0.877981
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 65/499 - Signal: 0.859918, Verlust: -0.697525, LR: 0.877981
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 66/499 - Signal: 0.860572, Verlust: -0.698283, LR: 0.876225
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 66/499 - Signal: 0.860572, Verlust: -0.698283, LR: 0.876225
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 67/499 - Signal: 0.861207, Verlust: -0.698955, LR: 0.874473
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 67/499 - Signal: 0.861207, Verlust: -0.698955, LR: 0.874473
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 68/499 - Signal: 0.861846, Verlust: -0.699586, LR: 0.872724
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 68/499 - Signal: 0.861846, Verlust: -0.699586, LR: 0.872724
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 69/499 - Signal: 0.862489, Verlust: -0.700213, LR: 0.870978
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 69/499 - Signal: 0.862489, Verlust: -0.700213, LR: 0.870978
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 70/499 - Signal: 0.863124, Verlust: -0.700889, LR: 0.869236
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 70/499 - Signal: 0.863124, Verlust: -0.700889, LR: 0.869236
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 71/499 - Signal: 0.863759, Verlust: -0.701564, LR: 0.867498
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 71/499 - Signal: 0.863759, Verlust: -0.701564, LR: 0.867498
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 72/499 - Signal: 0.864380, Verlust: -0.702276, LR: 0.865763
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 72/499 - Signal: 0.864380, Verlust: -0.702276, LR: 0.865763
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 73/499 - Signal: 0.865000, Verlust: -0.702983, LR: 0.864031
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 73/499 - Signal: 0.865000, Verlust: -0.702983, LR: 0.864031
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 74/499 - Signal: 0.865626, Verlust: -0.703701, LR: 0.862303
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 74/499 - Signal: 0.865626, Verlust: -0.703701, LR: 0.862303
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 75/499 - Signal: 0.866250, Verlust: -0.704408, LR: 0.860579
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 75/499 - Signal: 0.866250, Verlust: -0.704408, LR: 0.860579
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 76/499 - Signal: 0.866853, Verlust: -0.705106, LR: 0.858858
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 76/499 - Signal: 0.866853, Verlust: -0.705106, LR: 0.858858
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 77/499 - Signal: 0.867439, Verlust: -0.705783, LR: 0.857140
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 77/499 - Signal: 0.867439, Verlust: -0.705783, LR: 0.857140
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 78/499 - Signal: 0.868015, Verlust: -0.706463, LR: 0.855426
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 78/499 - Signal: 0.868015, Verlust: -0.706463, LR: 0.855426
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 79/499 - Signal: 0.868581, Verlust: -0.707112, LR: 0.853715
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 79/499 - Signal: 0.868581, Verlust: -0.707112, LR: 0.853715
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 80/499 - Signal: 0.869136, Verlust: -0.707742, LR: 0.852007
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 80/499 - Signal: 0.869136, Verlust: -0.707742, LR: 0.852007
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 81/499 - Signal: 0.869674, Verlust: -0.708315, LR: 0.850303
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 81/499 - Signal: 0.869674, Verlust: -0.708315, LR: 0.850303
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 82/499 - Signal: 0.870189, Verlust: -0.708919, LR: 0.848603
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 82/499 - Signal: 0.870189, Verlust: -0.708919, LR: 0.848603
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 83/499 - Signal: 0.870681, Verlust: -0.709477, LR: 0.846905
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 83/499 - Signal: 0.870681, Verlust: -0.709477, LR: 0.846905
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 84/499 - Signal: 0.871149, Verlust: -0.709972, LR: 0.845212
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 84/499 - Signal: 0.871149, Verlust: -0.709972, LR: 0.845212
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 85/499 - Signal: 0.871594, Verlust: -0.710483, LR: 0.843521
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 85/499 - Signal: 0.871594, Verlust: -0.710483, LR: 0.843521
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 86/499 - Signal: 0.872011, Verlust: -0.711054, LR: 0.841834
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 86/499 - Signal: 0.872011, Verlust: -0.711054, LR: 0.841834
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 87/499 - Signal: 0.872411, Verlust: -0.711550, LR: 0.840151
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 87/499 - Signal: 0.872411, Verlust: -0.711550, LR: 0.840151
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 88/499 - Signal: 0.872802, Verlust: -0.712038, LR: 0.838470
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 88/499 - Signal: 0.872802, Verlust: -0.712038, LR: 0.838470
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 89/499 - Signal: 0.873190, Verlust: -0.712497, LR: 0.836793
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 89/499 - Signal: 0.873190, Verlust: -0.712497, LR: 0.836793
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 90/499 - Signal: 0.873574, Verlust: -0.712974, LR: 0.835120
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 90/499 - Signal: 0.873574, Verlust: -0.712974, LR: 0.835120
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 91/499 - Signal: 0.873957, Verlust: -0.713459, LR: 0.833449
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 91/499 - Signal: 0.873957, Verlust: -0.713459, LR: 0.833449
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 92/499 - Signal: 0.874344, Verlust: -0.713946, LR: 0.831783
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 92/499 - Signal: 0.874344, Verlust: -0.713946, LR: 0.831783
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 93/499 - Signal: 0.874726, Verlust: -0.714433, LR: 0.830119
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 93/499 - Signal: 0.874726, Verlust: -0.714433, LR: 0.830119
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 94/499 - Signal: 0.875099, Verlust: -0.714922, LR: 0.828459
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 94/499 - Signal: 0.875099, Verlust: -0.714922, LR: 0.828459
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 95/499 - Signal: 0.875466, Verlust: -0.715417, LR: 0.826802
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 95/499 - Signal: 0.875466, Verlust: -0.715417, LR: 0.826802
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 96/499 - Signal: 0.875833, Verlust: -0.715863, LR: 0.825148
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 96/499 - Signal: 0.875833, Verlust: -0.715863, LR: 0.825148
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 97/499 - Signal: 0.876188, Verlust: -0.716314, LR: 0.823498
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 97/499 - Signal: 0.876188, Verlust: -0.716314, LR: 0.823498
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 98/499 - Signal: 0.876529, Verlust: -0.716736, LR: 0.821851
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 98/499 - Signal: 0.876529, Verlust: -0.716736, LR: 0.821851
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 99/499 - Signal: 0.876854, Verlust: -0.717189, LR: 0.820207
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 99/499 - Signal: 0.876854, Verlust: -0.717189, LR: 0.820207
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 100/499 - Signal: 0.877169, Verlust: -0.717620, LR: 0.818567
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 100/499 - Signal: 0.877169, Verlust: -0.717620, LR: 0.818567
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 101/499 - Signal: 0.877486, Verlust: -0.718026, LR: 0.816930
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 101/499 - Signal: 0.877486, Verlust: -0.718026, LR: 0.816930
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 102/499 - Signal: 0.877806, Verlust: -0.718433, LR: 0.815296
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 102/499 - Signal: 0.877806, Verlust: -0.718433, LR: 0.815296
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 103/499 - Signal: 0.878130, Verlust: -0.718846, LR: 0.813665
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 103/499 - Signal: 0.878130, Verlust: -0.718846, LR: 0.813665
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 104/499 - Signal: 0.878452, Verlust: -0.719257, LR: 0.812038
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 104/499 - Signal: 0.878452, Verlust: -0.719257, LR: 0.812038
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 105/499 - Signal: 0.878777, Verlust: -0.719656, LR: 0.810414
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 105/499 - Signal: 0.878777, Verlust: -0.719656, LR: 0.810414
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 106/499 - Signal: 0.879103, Verlust: -0.720061, LR: 0.808793
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 106/499 - Signal: 0.879103, Verlust: -0.720061, LR: 0.808793
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 107/499 - Signal: 0.879431, Verlust: -0.720446, LR: 0.807175
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 107/499 - Signal: 0.879431, Verlust: -0.720446, LR: 0.807175
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 108/499 - Signal: 0.879752, Verlust: -0.720834, LR: 0.805561
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 108/499 - Signal: 0.879752, Verlust: -0.720834, LR: 0.805561
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 109/499 - Signal: 0.880069, Verlust: -0.721219, LR: 0.803950
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 109/499 - Signal: 0.880069, Verlust: -0.721219, LR: 0.803950
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 110/499 - Signal: 0.880384, Verlust: -0.721600, LR: 0.802342
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 110/499 - Signal: 0.880384, Verlust: -0.721600, LR: 0.802342
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 111/499 - Signal: 0.880703, Verlust: -0.721969, LR: 0.800737
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 111/499 - Signal: 0.880703, Verlust: -0.721969, LR: 0.800737
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 112/499 - Signal: 0.881019, Verlust: -0.722343, LR: 0.799136
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 112/499 - Signal: 0.881019, Verlust: -0.722343, LR: 0.799136
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 113/499 - Signal: 0.881327, Verlust: -0.722709, LR: 0.797538
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 113/499 - Signal: 0.881327, Verlust: -0.722709, LR: 0.797538
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 114/499 - Signal: 0.881635, Verlust: -0.723068, LR: 0.795943
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 114/499 - Signal: 0.881635, Verlust: -0.723068, LR: 0.795943
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 115/499 - Signal: 0.881944, Verlust: -0.723430, LR: 0.794351
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 115/499 - Signal: 0.881944, Verlust: -0.723430, LR: 0.794351
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 116/499 - Signal: 0.882251, Verlust: -0.723777, LR: 0.792762
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 116/499 - Signal: 0.882251, Verlust: -0.723777, LR: 0.792762
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 117/499 - Signal: 0.882549, Verlust: -0.724129, LR: 0.791176
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 117/499 - Signal: 0.882549, Verlust: -0.724129, LR: 0.791176
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 118/499 - Signal: 0.882846, Verlust: -0.724470, LR: 0.789594
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 118/499 - Signal: 0.882846, Verlust: -0.724470, LR: 0.789594
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 119/499 - Signal: 0.883141, Verlust: -0.724812, LR: 0.788015
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 119/499 - Signal: 0.883141, Verlust: -0.724812, LR: 0.788015
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 120/499 - Signal: 0.883434, Verlust: -0.725149, LR: 0.786439
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 120/499 - Signal: 0.883434, Verlust: -0.725149, LR: 0.786439
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 121/499 - Signal: 0.883720, Verlust: -0.725485, LR: 0.784866
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 121/499 - Signal: 0.883720, Verlust: -0.725485, LR: 0.784866
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 122/499 - Signal: 0.884002, Verlust: -0.725813, LR: 0.783296
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 122/499 - Signal: 0.884002, Verlust: -0.725813, LR: 0.783296
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 123/499 - Signal: 0.884284, Verlust: -0.726139, LR: 0.781730
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 123/499 - Signal: 0.884284, Verlust: -0.726139, LR: 0.781730
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 124/499 - Signal: 0.884564, Verlust: -0.726463, LR: 0.780166
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 124/499 - Signal: 0.884564, Verlust: -0.726463, LR: 0.780166
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 125/499 - Signal: 0.884841, Verlust: -0.726782, LR: 0.778606
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 125/499 - Signal: 0.884841, Verlust: -0.726782, LR: 0.778606
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 126/499 - Signal: 0.885114, Verlust: -0.727099, LR: 0.777049
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 126/499 - Signal: 0.885114, Verlust: -0.727099, LR: 0.777049
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 127/499 - Signal: 0.885387, Verlust: -0.727411, LR: 0.775495
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 127/499 - Signal: 0.885387, Verlust: -0.727411, LR: 0.775495
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 128/499 - Signal: 0.885657, Verlust: -0.727721, LR: 0.773944
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 128/499 - Signal: 0.885657, Verlust: -0.727721, LR: 0.773944
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 129/499 - Signal: 0.885925, Verlust: -0.728026, LR: 0.772396
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 129/499 - Signal: 0.885925, Verlust: -0.728026, LR: 0.772396
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 130/499 - Signal: 0.886191, Verlust: -0.728329, LR: 0.770851
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 130/499 - Signal: 0.886191, Verlust: -0.728329, LR: 0.770851
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 131/499 - Signal: 0.886457, Verlust: -0.728629, LR: 0.769309
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 131/499 - Signal: 0.886457, Verlust: -0.728629, LR: 0.769309
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 132/499 - Signal: 0.886721, Verlust: -0.728925, LR: 0.767771
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 132/499 - Signal: 0.886721, Verlust: -0.728925, LR: 0.767771
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 133/499 - Signal: 0.886983, Verlust: -0.729219, LR: 0.766235
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 133/499 - Signal: 0.886983, Verlust: -0.729219, LR: 0.766235
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 134/499 - Signal: 0.887243, Verlust: -0.729509, LR: 0.764703
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 134/499 - Signal: 0.887243, Verlust: -0.729509, LR: 0.764703
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 135/499 - Signal: 0.887502, Verlust: -0.729796, LR: 0.763173
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 135/499 - Signal: 0.887502, Verlust: -0.729796, LR: 0.763173
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 136/499 - Signal: 0.887760, Verlust: -0.730081, LR: 0.761647
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 136/499 - Signal: 0.887760, Verlust: -0.730081, LR: 0.761647
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 137/499 - Signal: 0.888015, Verlust: -0.730362, LR: 0.760123
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 137/499 - Signal: 0.888015, Verlust: -0.730362, LR: 0.760123
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 138/499 - Signal: 0.888271, Verlust: -0.730641, LR: 0.758603
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 138/499 - Signal: 0.888271, Verlust: -0.730641, LR: 0.758603
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 139/499 - Signal: 0.888525, Verlust: -0.730917, LR: 0.757086
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 139/499 - Signal: 0.888525, Verlust: -0.730917, LR: 0.757086
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 140/499 - Signal: 0.888776, Verlust: -0.731190, LR: 0.755572
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 140/499 - Signal: 0.888776, Verlust: -0.731190, LR: 0.755572
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 141/499 - Signal: 0.889025, Verlust: -0.731460, LR: 0.754061
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 141/499 - Signal: 0.889025, Verlust: -0.731460, LR: 0.754061
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 142/499 - Signal: 0.889273, Verlust: -0.731728, LR: 0.752553
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 142/499 - Signal: 0.889273, Verlust: -0.731728, LR: 0.752553
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 143/499 - Signal: 0.889518, Verlust: -0.731993, LR: 0.751047
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 143/499 - Signal: 0.889518, Verlust: -0.731993, LR: 0.751047
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 144/499 - Signal: 0.889762, Verlust: -0.732255, LR: 0.749545
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 144/499 - Signal: 0.889762, Verlust: -0.732255, LR: 0.749545
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 145/499 - Signal: 0.890005, Verlust: -0.732514, LR: 0.748046
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 145/499 - Signal: 0.890005, Verlust: -0.732514, LR: 0.748046
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 146/499 - Signal: 0.890246, Verlust: -0.732772, LR: 0.746550
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 146/499 - Signal: 0.890246, Verlust: -0.732772, LR: 0.746550
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 147/499 - Signal: 0.890485, Verlust: -0.733026, LR: 0.745057
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 147/499 - Signal: 0.890485, Verlust: -0.733026, LR: 0.745057
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 148/499 - Signal: 0.890722, Verlust: -0.733278, LR: 0.743567
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 148/499 - Signal: 0.890722, Verlust: -0.733278, LR: 0.743567
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 149/499 - Signal: 0.890958, Verlust: -0.733528, LR: 0.742080
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 149/499 - Signal: 0.890958, Verlust: -0.733528, LR: 0.742080
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 150/499 - Signal: 0.891191, Verlust: -0.733775, LR: 0.740596
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 150/499 - Signal: 0.891191, Verlust: -0.733775, LR: 0.740596
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 151/499 - Signal: 0.891424, Verlust: -0.734020, LR: 0.739115
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 151/499 - Signal: 0.891424, Verlust: -0.734020, LR: 0.739115
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 152/499 - Signal: 0.891655, Verlust: -0.734262, LR: 0.737636
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 152/499 - Signal: 0.891655, Verlust: -0.734262, LR: 0.737636
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 153/499 - Signal: 0.891884, Verlust: -0.734502, LR: 0.736161
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 153/499 - Signal: 0.891884, Verlust: -0.734502, LR: 0.736161
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 154/499 - Signal: 0.892111, Verlust: -0.734740, LR: 0.734689
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 154/499 - Signal: 0.892111, Verlust: -0.734740, LR: 0.734689
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 155/499 - Signal: 0.892337, Verlust: -0.734975, LR: 0.733219
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 155/499 - Signal: 0.892337, Verlust: -0.734975, LR: 0.733219
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 156/499 - Signal: 0.892562, Verlust: -0.735208, LR: 0.731753
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 156/499 - Signal: 0.892562, Verlust: -0.735208, LR: 0.731753
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 157/499 - Signal: 0.892785, Verlust: -0.735439, LR: 0.730289
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 157/499 - Signal: 0.892785, Verlust: -0.735439, LR: 0.730289
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 158/499 - Signal: 0.893007, Verlust: -0.735668, LR: 0.728829
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 158/499 - Signal: 0.893007, Verlust: -0.735668, LR: 0.728829
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 159/499 - Signal: 0.893227, Verlust: -0.735895, LR: 0.727371
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 159/499 - Signal: 0.893227, Verlust: -0.735895, LR: 0.727371
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 160/499 - Signal: 0.893446, Verlust: -0.736119, LR: 0.725916
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 160/499 - Signal: 0.893446, Verlust: -0.736119, LR: 0.725916
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 161/499 - Signal: 0.893662, Verlust: -0.736341, LR: 0.724465
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 161/499 - Signal: 0.893662, Verlust: -0.736341, LR: 0.724465
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 162/499 - Signal: 0.893878, Verlust: -0.736562, LR: 0.723016
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 162/499 - Signal: 0.893878, Verlust: -0.736562, LR: 0.723016
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 163/499 - Signal: 0.894093, Verlust: -0.736780, LR: 0.721570
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 163/499 - Signal: 0.894093, Verlust: -0.736780, LR: 0.721570
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 164/499 - Signal: 0.894306, Verlust: -0.736996, LR: 0.720126
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 164/499 - Signal: 0.894306, Verlust: -0.736996, LR: 0.720126
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 165/499 - Signal: 0.894517, Verlust: -0.737210, LR: 0.718686
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 165/499 - Signal: 0.894517, Verlust: -0.737210, LR: 0.718686
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 166/499 - Signal: 0.894727, Verlust: -0.737423, LR: 0.717249
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 166/499 - Signal: 0.894727, Verlust: -0.737423, LR: 0.717249
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 167/499 - Signal: 0.894937, Verlust: -0.737633, LR: 0.715814
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 167/499 - Signal: 0.894937, Verlust: -0.737633, LR: 0.715814
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 168/499 - Signal: 0.895144, Verlust: -0.737841, LR: 0.714383
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 168/499 - Signal: 0.895144, Verlust: -0.737841, LR: 0.714383
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 169/499 - Signal: 0.895351, Verlust: -0.738048, LR: 0.712954
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 169/499 - Signal: 0.895351, Verlust: -0.738048, LR: 0.712954
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 170/499 - Signal: 0.895557, Verlust: -0.738252, LR: 0.711528
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 170/499 - Signal: 0.895557, Verlust: -0.738252, LR: 0.711528
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 171/499 - Signal: 0.895761, Verlust: -0.738455, LR: 0.710105
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 171/499 - Signal: 0.895761, Verlust: -0.738455, LR: 0.710105
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 172/499 - Signal: 0.895964, Verlust: -0.738656, LR: 0.708685
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 172/499 - Signal: 0.895964, Verlust: -0.738656, LR: 0.708685
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 173/499 - Signal: 0.896165, Verlust: -0.738855, LR: 0.707267
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 173/499 - Signal: 0.896165, Verlust: -0.738855, LR: 0.707267
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 174/499 - Signal: 0.896366, Verlust: -0.739052, LR: 0.705853
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 174/499 - Signal: 0.896366, Verlust: -0.739052, LR: 0.705853
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 175/499 - Signal: 0.896565, Verlust: -0.739248, LR: 0.704441
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 175/499 - Signal: 0.896565, Verlust: -0.739248, LR: 0.704441
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 176/499 - Signal: 0.896763, Verlust: -0.739441, LR: 0.703032
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 176/499 - Signal: 0.896763, Verlust: -0.739441, LR: 0.703032
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 177/499 - Signal: 0.896961, Verlust: -0.739633, LR: 0.701626
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 177/499 - Signal: 0.896961, Verlust: -0.739633, LR: 0.701626
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 178/499 - Signal: 0.897157, Verlust: -0.739824, LR: 0.700223
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 178/499 - Signal: 0.897157, Verlust: -0.739824, LR: 0.700223
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 179/499 - Signal: 0.897351, Verlust: -0.740012, LR: 0.698823
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 179/499 - Signal: 0.897351, Verlust: -0.740012, LR: 0.698823
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 180/499 - Signal: 0.897545, Verlust: -0.740199, LR: 0.697425
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 180/499 - Signal: 0.897545, Verlust: -0.740199, LR: 0.697425
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 181/499 - Signal: 0.897738, Verlust: -0.740384, LR: 0.696030
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 181/499 - Signal: 0.897738, Verlust: -0.740384, LR: 0.696030
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 182/499 - Signal: 0.897929, Verlust: -0.740568, LR: 0.694638
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 182/499 - Signal: 0.897929, Verlust: -0.740568, LR: 0.694638
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 183/499 - Signal: 0.898120, Verlust: -0.740750, LR: 0.693249
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 183/499 - Signal: 0.898120, Verlust: -0.740750, LR: 0.693249
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 184/499 - Signal: 0.898309, Verlust: -0.740931, LR: 0.691862
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 184/499 - Signal: 0.898309, Verlust: -0.740931, LR: 0.691862
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 185/499 - Signal: 0.898497, Verlust: -0.741110, LR: 0.690478
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 185/499 - Signal: 0.898497, Verlust: -0.741110, LR: 0.690478
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 186/499 - Signal: 0.898684, Verlust: -0.741287, LR: 0.689098
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 186/499 - Signal: 0.898684, Verlust: -0.741287, LR: 0.689098
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 187/499 - Signal: 0.898869, Verlust: -0.741463, LR: 0.687719
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 187/499 - Signal: 0.898869, Verlust: -0.741463, LR: 0.687719
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 188/499 - Signal: 0.899054, Verlust: -0.741637, LR: 0.686344
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 188/499 - Signal: 0.899054, Verlust: -0.741637, LR: 0.686344
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 189/499 - Signal: 0.899238, Verlust: -0.741810, LR: 0.684971
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 189/499 - Signal: 0.899238, Verlust: -0.741810, LR: 0.684971
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 190/499 - Signal: 0.899420, Verlust: -0.741981, LR: 0.683601
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 190/499 - Signal: 0.899420, Verlust: -0.741981, LR: 0.683601
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 191/499 - Signal: 0.899602, Verlust: -0.742151, LR: 0.682234
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 191/499 - Signal: 0.899602, Verlust: -0.742151, LR: 0.682234
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 192/499 - Signal: 0.899783, Verlust: -0.742320, LR: 0.680870
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 192/499 - Signal: 0.899783, Verlust: -0.742320, LR: 0.680870
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 193/499 - Signal: 0.899963, Verlust: -0.742487, LR: 0.679508
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 193/499 - Signal: 0.899963, Verlust: -0.742487, LR: 0.679508
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 194/499 - Signal: 0.900142, Verlust: -0.742652, LR: 0.678149
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 194/499 - Signal: 0.900142, Verlust: -0.742652, LR: 0.678149
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 195/499 - Signal: 0.900320, Verlust: -0.742816, LR: 0.676793
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 195/499 - Signal: 0.900320, Verlust: -0.742816, LR: 0.676793
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 196/499 - Signal: 0.900496, Verlust: -0.742979, LR: 0.675439
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 196/499 - Signal: 0.900496, Verlust: -0.742979, LR: 0.675439
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 197/499 - Signal: 0.900672, Verlust: -0.743141, LR: 0.674088
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 197/499 - Signal: 0.900672, Verlust: -0.743141, LR: 0.674088
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 198/499 - Signal: 0.900847, Verlust: -0.743301, LR: 0.672740
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 198/499 - Signal: 0.900847, Verlust: -0.743301, LR: 0.672740
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 199/499 - Signal: 0.901021, Verlust: -0.743460, LR: 0.671394
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 199/499 - Signal: 0.901021, Verlust: -0.743460, LR: 0.671394
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 200/499 - Signal: 0.901194, Verlust: -0.743617, LR: 0.670052
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 200/499 - Signal: 0.901194, Verlust: -0.743617, LR: 0.670052
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 201/499 - Signal: 0.901366, Verlust: -0.743773, LR: 0.668712
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 201/499 - Signal: 0.901366, Verlust: -0.743773, LR: 0.668712
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 202/499 - Signal: 0.901537, Verlust: -0.743928, LR: 0.667374
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 202/499 - Signal: 0.901537, Verlust: -0.743928, LR: 0.667374
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 203/499 - Signal: 0.901707, Verlust: -0.744082, LR: 0.666039
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 203/499 - Signal: 0.901707, Verlust: -0.744082, LR: 0.666039
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 204/499 - Signal: 0.901876, Verlust: -0.744234, LR: 0.664707
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 204/499 - Signal: 0.901876, Verlust: -0.744234, LR: 0.664707
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 205/499 - Signal: 0.902045, Verlust: -0.744385, LR: 0.663378
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 205/499 - Signal: 0.902045, Verlust: -0.744385, LR: 0.663378
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 206/499 - Signal: 0.902212, Verlust: -0.744534, LR: 0.662051
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 206/499 - Signal: 0.902212, Verlust: -0.744534, LR: 0.662051
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 207/499 - Signal: 0.902379, Verlust: -0.744683, LR: 0.660727
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 207/499 - Signal: 0.902379, Verlust: -0.744683, LR: 0.660727
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 208/499 - Signal: 0.902545, Verlust: -0.744830, LR: 0.659406
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 208/499 - Signal: 0.902545, Verlust: -0.744830, LR: 0.659406
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 209/499 - Signal: 0.902710, Verlust: -0.744976, LR: 0.658087
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 209/499 - Signal: 0.902710, Verlust: -0.744976, LR: 0.658087
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 210/499 - Signal: 0.902874, Verlust: -0.745121, LR: 0.656771
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 210/499 - Signal: 0.902874, Verlust: -0.745121, LR: 0.656771
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 211/499 - Signal: 0.903038, Verlust: -0.745265, LR: 0.655457
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 211/499 - Signal: 0.903038, Verlust: -0.745265, LR: 0.655457
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 212/499 - Signal: 0.903200, Verlust: -0.745408, LR: 0.654146
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 212/499 - Signal: 0.903200, Verlust: -0.745408, LR: 0.654146
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 213/499 - Signal: 0.903361, Verlust: -0.745550, LR: 0.652838
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 213/499 - Signal: 0.903361, Verlust: -0.745550, LR: 0.652838
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 214/499 - Signal: 0.903522, Verlust: -0.745690, LR: 0.651532
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 214/499 - Signal: 0.903522, Verlust: -0.745690, LR: 0.651532
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 215/499 - Signal: 0.903682, Verlust: -0.745829, LR: 0.650229
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 215/499 - Signal: 0.903682, Verlust: -0.745829, LR: 0.650229
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 216/499 - Signal: 0.903841, Verlust: -0.745968, LR: 0.648929
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 216/499 - Signal: 0.903841, Verlust: -0.745968, LR: 0.648929
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 217/499 - Signal: 0.903999, Verlust: -0.746105, LR: 0.647631
#   Neuer Bestwert gefunden und gespeichert!
# ...
# Epoche 428/499 - Signal: 0.924789, Verlust: -0.761282, LR: 0.424494
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 429/499 - Signal: 0.924847, Verlust: -0.761318, LR: 0.423645
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 429/499 - Signal: 0.924847, Verlust: -0.761318, LR: 0.423645
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 430/499 - Signal: 0.924905, Verlust: -0.761353, LR: 0.422798
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 430/499 - Signal: 0.924905, Verlust: -0.761353, LR: 0.422798
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 431/499 - Signal: 0.924962, Verlust: -0.761388, LR: 0.421952
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 431/499 - Signal: 0.924962, Verlust: -0.761388, LR: 0.421952
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 432/499 - Signal: 0.925019, Verlust: -0.761423, LR: 0.421108
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 432/499 - Signal: 0.925019, Verlust: -0.761423, LR: 0.421108
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 433/499 - Signal: 0.925076, Verlust: -0.761457, LR: 0.420266
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 433/499 - Signal: 0.925076, Verlust: -0.761457, LR: 0.420266
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 434/499 - Signal: 0.925133, Verlust: -0.761492, LR: 0.419426
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 434/499 - Signal: 0.925133, Verlust: -0.761492, LR: 0.419426
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 435/499 - Signal: 0.925190, Verlust: -0.761526, LR: 0.418587
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 435/499 - Signal: 0.925190, Verlust: -0.761526, LR: 0.418587
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 436/499 - Signal: 0.925246, Verlust: -0.761560, LR: 0.417750
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 436/499 - Signal: 0.925246, Verlust: -0.761560, LR: 0.417750
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 437/499 - Signal: 0.925302, Verlust: -0.761594, LR: 0.416914
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 437/499 - Signal: 0.925302, Verlust: -0.761594, LR: 0.416914
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 438/499 - Signal: 0.925358, Verlust: -0.761628, LR: 0.416080
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 438/499 - Signal: 0.925358, Verlust: -0.761628, LR: 0.416080
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 439/499 - Signal: 0.925413, Verlust: -0.761661, LR: 0.415248
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 439/499 - Signal: 0.925413, Verlust: -0.761661, LR: 0.415248
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 440/499 - Signal: 0.925468, Verlust: -0.761695, LR: 0.414418
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 440/499 - Signal: 0.925468, Verlust: -0.761695, LR: 0.414418
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 441/499 - Signal: 0.925523, Verlust: -0.761728, LR: 0.413589
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 441/499 - Signal: 0.925523, Verlust: -0.761728, LR: 0.413589
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 442/499 - Signal: 0.925578, Verlust: -0.761761, LR: 0.412762
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 442/499 - Signal: 0.925578, Verlust: -0.761761, LR: 0.412762
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 443/499 - Signal: 0.925632, Verlust: -0.761794, LR: 0.411936
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 443/499 - Signal: 0.925632, Verlust: -0.761794, LR: 0.411936
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 444/499 - Signal: 0.925687, Verlust: -0.761826, LR: 0.411112
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 444/499 - Signal: 0.925687, Verlust: -0.761826, LR: 0.411112
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 445/499 - Signal: 0.925741, Verlust: -0.761859, LR: 0.410290
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 445/499 - Signal: 0.925741, Verlust: -0.761859, LR: 0.410290
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 446/499 - Signal: 0.925795, Verlust: -0.761891, LR: 0.409469
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 446/499 - Signal: 0.925795, Verlust: -0.761891, LR: 0.409469
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 447/499 - Signal: 0.925848, Verlust: -0.761923, LR: 0.408650
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 447/499 - Signal: 0.925848, Verlust: -0.761923, LR: 0.408650
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 448/499 - Signal: 0.925902, Verlust: -0.761955, LR: 0.407833
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 448/499 - Signal: 0.925902, Verlust: -0.761955, LR: 0.407833
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 449/499 - Signal: 0.925955, Verlust: -0.761987, LR: 0.407017
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 449/499 - Signal: 0.925955, Verlust: -0.761987, LR: 0.407017
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 450/499 - Signal: 0.926008, Verlust: -0.762019, LR: 0.406203
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 450/499 - Signal: 0.926008, Verlust: -0.762019, LR: 0.406203
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 451/499 - Signal: 0.926060, Verlust: -0.762050, LR: 0.405391
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 451/499 - Signal: 0.926060, Verlust: -0.762050, LR: 0.405391
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 452/499 - Signal: 0.926113, Verlust: -0.762082, LR: 0.404580
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 452/499 - Signal: 0.926113, Verlust: -0.762082, LR: 0.404580
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 453/499 - Signal: 0.926165, Verlust: -0.762113, LR: 0.403771
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 453/499 - Signal: 0.926165, Verlust: -0.762113, LR: 0.403771
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 454/499 - Signal: 0.926217, Verlust: -0.762144, LR: 0.402964
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 454/499 - Signal: 0.926217, Verlust: -0.762144, LR: 0.402964
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 455/499 - Signal: 0.926269, Verlust: -0.762175, LR: 0.402158
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 455/499 - Signal: 0.926269, Verlust: -0.762175, LR: 0.402158
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 456/499 - Signal: 0.926321, Verlust: -0.762205, LR: 0.401353
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 456/499 - Signal: 0.926321, Verlust: -0.762205, LR: 0.401353
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 457/499 - Signal: 0.926372, Verlust: -0.762236, LR: 0.400551
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 457/499 - Signal: 0.926372, Verlust: -0.762236, LR: 0.400551
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 458/499 - Signal: 0.926423, Verlust: -0.762266, LR: 0.399749
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 458/499 - Signal: 0.926423, Verlust: -0.762266, LR: 0.399749
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 459/499 - Signal: 0.926474, Verlust: -0.762296, LR: 0.398950
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 459/499 - Signal: 0.926474, Verlust: -0.762296, LR: 0.398950
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 460/499 - Signal: 0.926525, Verlust: -0.762327, LR: 0.398152
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 460/499 - Signal: 0.926525, Verlust: -0.762327, LR: 0.398152
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 461/499 - Signal: 0.926576, Verlust: -0.762356, LR: 0.397356
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 461/499 - Signal: 0.926576, Verlust: -0.762356, LR: 0.397356
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 462/499 - Signal: 0.926626, Verlust: -0.762386, LR: 0.396561
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 462/499 - Signal: 0.926626, Verlust: -0.762386, LR: 0.396561
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 463/499 - Signal: 0.926676, Verlust: -0.762416, LR: 0.395768
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 463/499 - Signal: 0.926676, Verlust: -0.762416, LR: 0.395768
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 464/499 - Signal: 0.926726, Verlust: -0.762445, LR: 0.394976
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 464/499 - Signal: 0.926726, Verlust: -0.762445, LR: 0.394976
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 465/499 - Signal: 0.926776, Verlust: -0.762475, LR: 0.394186
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 465/499 - Signal: 0.926776, Verlust: -0.762475, LR: 0.394186
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 466/499 - Signal: 0.926825, Verlust: -0.762504, LR: 0.393398
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 466/499 - Signal: 0.926825, Verlust: -0.762504, LR: 0.393398
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 467/499 - Signal: 0.926874, Verlust: -0.762533, LR: 0.392611
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 467/499 - Signal: 0.926874, Verlust: -0.762533, LR: 0.392611
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 468/499 - Signal: 0.926923, Verlust: -0.762562, LR: 0.391826
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 468/499 - Signal: 0.926923, Verlust: -0.762562, LR: 0.391826
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 469/499 - Signal: 0.926972, Verlust: -0.762590, LR: 0.391042
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 469/499 - Signal: 0.926972, Verlust: -0.762590, LR: 0.391042
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 470/499 - Signal: 0.927021, Verlust: -0.762619, LR: 0.390260
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 470/499 - Signal: 0.927021, Verlust: -0.762619, LR: 0.390260
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 471/499 - Signal: 0.927069, Verlust: -0.762647, LR: 0.389480
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 471/499 - Signal: 0.927069, Verlust: -0.762647, LR: 0.389480
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 472/499 - Signal: 0.927117, Verlust: -0.762675, LR: 0.388701
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 472/499 - Signal: 0.927117, Verlust: -0.762675, LR: 0.388701
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 473/499 - Signal: 0.927165, Verlust: -0.762704, LR: 0.387923
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 473/499 - Signal: 0.927165, Verlust: -0.762704, LR: 0.387923
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 474/499 - Signal: 0.927213, Verlust: -0.762732, LR: 0.387148
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 474/499 - Signal: 0.927213, Verlust: -0.762732, LR: 0.387148
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 475/499 - Signal: 0.927261, Verlust: -0.762759, LR: 0.386373
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 475/499 - Signal: 0.927261, Verlust: -0.762759, LR: 0.386373
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 476/499 - Signal: 0.927308, Verlust: -0.762787, LR: 0.385601
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 476/499 - Signal: 0.927308, Verlust: -0.762787, LR: 0.385601
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 477/499 - Signal: 0.927355, Verlust: -0.762815, LR: 0.384829
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 477/499 - Signal: 0.927355, Verlust: -0.762815, LR: 0.384829
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 478/499 - Signal: 0.927402, Verlust: -0.762842, LR: 0.384060
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 478/499 - Signal: 0.927402, Verlust: -0.762842, LR: 0.384060
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 479/499 - Signal: 0.927449, Verlust: -0.762869, LR: 0.383292
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 479/499 - Signal: 0.927449, Verlust: -0.762869, LR: 0.383292
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 480/499 - Signal: 0.927495, Verlust: -0.762897, LR: 0.382525
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 480/499 - Signal: 0.927495, Verlust: -0.762897, LR: 0.382525
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 481/499 - Signal: 0.927542, Verlust: -0.762924, LR: 0.381760
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 481/499 - Signal: 0.927542, Verlust: -0.762924, LR: 0.381760
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 482/499 - Signal: 0.927588, Verlust: -0.762950, LR: 0.380996
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 482/499 - Signal: 0.927588, Verlust: -0.762950, LR: 0.380996
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 483/499 - Signal: 0.927634, Verlust: -0.762977, LR: 0.380234
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 483/499 - Signal: 0.927634, Verlust: -0.762977, LR: 0.380234
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 484/499 - Signal: 0.927680, Verlust: -0.763004, LR: 0.379474
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 484/499 - Signal: 0.927680, Verlust: -0.763004, LR: 0.379474
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 485/499 - Signal: 0.927726, Verlust: -0.763030, LR: 0.378715
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 485/499 - Signal: 0.927726, Verlust: -0.763030, LR: 0.378715
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 486/499 - Signal: 0.927771, Verlust: -0.763057, LR: 0.377958
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 486/499 - Signal: 0.927771, Verlust: -0.763057, LR: 0.377958
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 487/499 - Signal: 0.927816, Verlust: -0.763083, LR: 0.377202
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 487/499 - Signal: 0.927816, Verlust: -0.763083, LR: 0.377202
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 488/499 - Signal: 0.927862, Verlust: -0.763109, LR: 0.376447
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 488/499 - Signal: 0.927862, Verlust: -0.763109, LR: 0.376447
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 489/499 - Signal: 0.927907, Verlust: -0.763135, LR: 0.375694
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 489/499 - Signal: 0.927907, Verlust: -0.763135, LR: 0.375694
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 490/499 - Signal: 0.927951, Verlust: -0.763161, LR: 0.374943
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 490/499 - Signal: 0.927951, Verlust: -0.763161, LR: 0.374943
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 491/499 - Signal: 0.927996, Verlust: -0.763186, LR: 0.374193
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 491/499 - Signal: 0.927996, Verlust: -0.763186, LR: 0.374193
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 492/499 - Signal: 0.928040, Verlust: -0.763212, LR: 0.373445
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 492/499 - Signal: 0.928040, Verlust: -0.763212, LR: 0.373445
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 493/499 - Signal: 0.928085, Verlust: -0.763237, LR: 0.372698
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 493/499 - Signal: 0.928085, Verlust: -0.763237, LR: 0.372698
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 494/499 - Signal: 0.928129, Verlust: -0.763263, LR: 0.371952
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 494/499 - Signal: 0.928129, Verlust: -0.763263, LR: 0.371952
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 495/499 - Signal: 0.928172, Verlust: -0.763288, LR: 0.371209
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 495/499 - Signal: 0.928172, Verlust: -0.763288, LR: 0.371209
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 496/499 - Signal: 0.928216, Verlust: -0.763313, LR: 0.370466
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 496/499 - Signal: 0.928216, Verlust: -0.763313, LR: 0.370466
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 497/499 - Signal: 0.928260, Verlust: -0.763338, LR: 0.369725
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 497/499 - Signal: 0.928260, Verlust: -0.763338, LR: 0.369725
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 498/499 - Signal: 0.928303, Verlust: -0.763363, LR: 0.368986
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 498/499 - Signal: 0.928303, Verlust: -0.763363, LR: 0.368986
#   Neuer Bestwert gefunden und gespeichert!
# Epoche 499/499 - Signal: 0.928346, Verlust: -0.763387, LR: 0.368248
#   Neuer Bestwert gefunden und gespeichert!
#
# Training abgeschlossen!
# Bestes Signal: 0.928346
# Epoche 499/499 - Signal: 0.928346, Verlust: -0.763387, LR: 0.368248
#   Neuer Bestwert gefunden und gespeichert!
#
# Training abgeschlossen!
# Bestes Signal: 0.928346

# %% [markdown]
# ## Visualisierung der Ergebnisse
#
# Nach Abschluss des Trainings können wir die optimierten Parameter laden und visualisieren.

# %%
# Prüfen, ob optimierte Parameter vorhanden sind (nach dem Training)
if 'best_parameters' in locals():
    # Visualisieren des optimierten Pulses
    visualize_pulse(best_parameters, dtp_rf, f"Optimierter Sinc-Puls")
    
    # Vergleich mit Original
    with torch.no_grad():
        original_signal = diff_sim(original_pulse_parameters)
        optimized_signal = diff_sim(best_parameters)
        
    print(f"Original-Signal: {original_signal.item():.6f}")
    print(f"Optimiertes Signal: {optimized_signal.item():.6f}")
    
    if abs(original_signal.item()) > 0:
        improvement = (optimized_signal.item() - original_signal.item()) / abs(original_signal.item()) * 100
        print(f"Verbesserung: {improvement:.2f}%")
    
    # Vergleichsplot der Pulsformen
    plt.figure(figsize=(12, 6))
    
    # Original-Puls
    pulse_orig = original_pulse_parameters[0][0].detach().cpu().numpy()  # Extrahiere Amplituden des ersten Pulses
    time_axis = np.arange(len(pulse_orig)) * dtp_rf * 1000  # Umrechnung in ms
    plt.plot(time_axis, pulse_orig, 'b-', linewidth=1.5, alpha=0.7, label='Original')
    
    # Optimierter Puls
    pulse_opt = best_parameters[0][0].detach().cpu().numpy()  # Extrahiere Amplituden des ersten Pulses
    plt.plot(time_axis, pulse_opt, 'r-', linewidth=1.5, alpha=0.7, label='Optimiert')
    
    plt.title("Vergleich: Original vs. Optimierter Sinc-Puls")
    plt.xlabel('Zeit (ms)')
    plt.ylabel('Amplitude')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
else:
    print("Keine optimierten Parameter gefunden. Bitte führe zuerst das Training aus.")
# Out:
# Original-Signal: 0.633630
# Optimiertes Signal: 0.928389
# Verbesserung: 46.52%
